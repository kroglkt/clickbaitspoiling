# %%
from transformers import BloomForCausalLM
from transformers import BloomTokenizerFast
import nltk
import json
import requests
import pandas as pd

from os.path import exists
from os.path import isdir

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/ucloud/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/ucloud/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
model = BloomForCausalLM.from_pretrained("bigscience/bloom-7b1") #remove -1b7 for whole modelb
tokenizer = BloomTokenizerFast.from_pretrained("bigscience/bloom-7b1")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/739 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/27.5k [00:00<?, ?B/s]
# Downloading (…)00001-of-00002.bin";:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)00002-of-00002.bin";:   0%|          | 0.00/4.16G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/222 [00:00<?, ?B/s]
# Downloading (…)"tokenizer.json";:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %%
#prompt = "The train drove directly down in"
#result_length = 20
#inputs = tokenizer(prompt, return_tensors="pt") #??

name = 'bloom_API_test1'

# %%
# Greedy Search
print(tokenizer.decode(model.generate(inputs["input_ids"], 
                       max_length=result_length
                      )[0]))

# %% [markdown]
# # Load train and validation data

# %%
def error(msg):
    print('  [\033[91mx\033[0m] ' + msg)
    exit(1)

def success(msg):
    print('  [\033[92mo\033[0m] ' + msg)
    
def load_json_lines(f):
    if not exists(f):
        error('The file "' + f + '" does not exist.')

    ret = []
    num = 1
    
    if isdir(f):
        f = glob(f + '/*.json*')
        
        if len(f) != 1:
            error('The input is an directory that contains multiple json files. Please create only a single json file. Got ' + str(f))
        
        f = f[0]
    
    with open(f, 'r') as inp:
        for l in inp:
            try:
                ret += [json.loads(l)]
            except:
                error('Invalid line ' + str(num) + ' in "' + f + '" with content: ' + l.strip())
            num += 1

    success('The file ' + f + ' is in JSONL format.')
    return ret

# %%
train = load_json_lines('train.jsonl')
validation = load_json_lines('validation.jsonl')
test = load_json_lines('input.jsonl')
# Out:
#   [o] The file train.jsonl is in JSONL format.
#   [o] The file validation.jsonl is in JSONL format.
#   [o] The file input.jsonl is in JSONL format.

# %%
validation[130]['targetDescription'][-3:]

# %%
i = 2
validation[i]['targetTitle'], validation[i]['postText'], validation[i]['targetDescription'], validation[i]['targetKeywords']

# %%
len(' '.join(validation[3]['targetParagraphs']))

# %%
"abcdefghijkl"[-5:]

# %%
#Function for creating prompt from entry

def make_prompt(entry):
    article = ' '.join(entry['targetParagraphs'])
    title = entry['targetTitle']
    description = entry['targetDescription']
    tags = entry['targetKeywords']
    clickbait = entry['postText'][0]
    
    words = ['what', 'why']
    
    if len(article) > 4000:
        article = article[:2500] + article[-1000:]
    
    if title.lower() == clickbait.lower():
        title = ''
    else:
        title = f"\n\nArticle title: {title}"
    
    if tags:
        tags = f"\n\nTags: {', '.join(tags.split(','))}"
    else:
        tags = ''
    
    if description and description[-3:] != '...':
        description = f"\n\nDescription: {description}"
    else:
        description = ''
    
    if '?' in clickbait:
        clickbait = f"\n\nQuestion: {clickbait}\n\nAnswer:"
    elif [x for x in words if x in clickbait.lower()]:
        clickbait = f"\n\n{clickbait}:"
    else:
        clickbait = f"\n\nStatement to be answered: {clickbait}\n\nAnswer:"
    
    
    prompt = f"{title}{description}\n\nArticle: {article}{tags}{clickbait}"
    return prompt.strip()

print(make_prompt(validation[3]))
# Out:
# Article title: Alan Rickman & Rupert Grint On 'CBGB,' Reuniting Post-'Potter' And Favorite Halloween Costumes
#
# Article: The mythology of punk music's evolution can be traced back, more or less, to one singular staple: CBGB. Opened in 1973 in downtown Manhattan's East Village, the nightclub that originally intended to house country, bluegrass and blues music (hint its acronym) quickly became a breeding ground for bands like The Ramones, Talking Heads and The Police, among countless others. The legacy of the club, which closed in 2006 over a rent dispute, is on display in a new movie that stars Alan Rickman as bemused owner Hilly Kristal. It's a bit of a departure for anyone more accustomed to seeing Rickman, 67, play sinister Severus Snape in "Harry Potter" or Judge Turpin in "Sweeney Todd." The movie also afforded him the opportunity to reunite with fellow Hogwarts alum Rupert Grint, who portrays one-third of derriere-bearing punk band The Dead Boys, alongside Justin Bartha and Bronson Adams. They're joined by a revolving door of notable faces, including Malin Akerman as Debbie Harry, Taylor Hawkins as Iggy Pop, Johnny Galecki as Terry Ork and Ashley Greene as Hilly's daughter Lisa. HuffPost Entertainment snagged some phone time with Rickman and Grint, who were candid about their unfamiliarity with CBGB's legacy but effusive about the excitement that came with reconvening for the project. Plus, Grint talks about his own punk phase and Rickman explains what Halloween used to mean for him. What are you up to today? Rickman: I'm in New York. I'm just here for three or four days for "CBGB" in New York and then back to work in England. Grint: I'm rehearsing a play that will start [in London] in a couple of weeks. Yeah, so that's it. Are you enjoying the theater work? Are you more of a theater guy or a film guy? Grint: I don’t know, really. This is my first theater experience, and it’s very different. I wanted to just try it; it’s something I’ve always wanted to do. Just the thought of it scares me. I’ve kind of put it off for a long time, and I just thought it was a good time to do it. And it’s a great play and a really great cast with a great director, and it was just, yeah, I’m enjoying it. Were you familiar with the legacy of CBGB as a breeding ground for the punk-rock scene prior to taking your roles in the movie? Rickman: I wasn’t familiar with CBGB at all. I didn’t know about it and didn’t know its history. I hadn’t even really heard those four letters put together because at that time I was very much in England as a drama student and an art student, so it’s all been a newand you’d have apple bobbing in it, and you’d get apples out of a bowl of water. To me it just means a soaking wet shirt. Grint: I liked Halloween. It never used to be a big thing when I was kid. We never really did it. But I actually had a good costume not that long ago. The last one, I dressed as a Play-Doh can that I made. You know Play-Doh? Of course. Grint: Well, literally, I actually made it. It was a yellow bin. I cut the bottom out and I just wore a yellow bin with a Play-Doh logo. With a yellow hat. It’s not very practical. Do you have a favorite Halloween candy? Rickman: I don’t even know what that means. The word "chocolate" would loom large. Grint: A favorite Halloween candy? I don’t really know. I never trick-or-treated when I was younger because we lived on a block of houses that were all just kind of elderly people who were just scared to answer the door. But yeah, candy corn, that’s a big thing. I’ve tried that. That’s pretty great. "CBGB" is out in limited release now.
#
# Tags: Alan Rickman, Hilly Kristal, new rupert grint movie, rupert grint harry potter, new alan rickman movie, Alan Rickman Snape, alan rickman rupert grint, The Dead Boys, cbgb, Malin Akerman, cbgb movie, alan rickman cbgb, rupert grint cbgb, Rupert Grint, Taylor Hawkins, ashley greene
#
# Statement to be answered: "Harry Potter" alums reunite for new movie
#
# Answer:

# %%
prompt = make_prompt(validation[50])
inputs = tokenizer(prompt, return_tensors="pt") #??
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 prompt = make_prompt(validation[50])
# ----> 2 inputs = tokenizer(prompt, return_tensors="pt") #??
#
# NameError: name 'tokenizer' is not defined

# %%
pred = tokenizer.decode(model.generate(inputs["input_ids"], 
                       max_new_tokens=result_length
                      )[0])

# %%
# Beam Search
#print(tokenizer.decode(model.generate(inputs["input_ids"],
#                       max_new_tokens=result_length, 
#                       num_beams=2, 
#                       no_repeat_ngram_size=2,
#                       early_stopping=True
#                      )[0]))

# %%
text_generate(make_prompt(validation[3]))
# Out:
# [{"generated_text":"Article title: Alan Rickman & Rupert Grint On 'CBGB,' Reuniting Post-'Potter' And Favorite Halloween Costumes\n\nArticle: The mythology of punk music's evolution can be traced back, more or less, to one singular staple: CBGB. Opened in 1973 in downtown Manhattan's East Village, the nightclub that originally intended to house country, bluegrass and blues music (hint its acronym) quickly became a breeding ground for bands like The Ramones, Talking Heads and The Police, among countless others. The legacy of the club, which closed in 2006 over a rent dispute, is on display in a new movie that stars Alan Rickman as bemused owner Hilly Kristal. It's a bit of a departure for anyone more accustomed to seeing Rickman, 67, play sinister Severus Snape in \"Harry Potter\" or Judge Turpin in \"Sweeney Todd.\" The movie also afforded him the opportunity to reunite with fellow Hogwarts alum Rupert Grint, who portrays one-third of derriere-bearing punk band The Dead Boys, alongside Justin Bartha and Bronson Adams. They're joined by a revolving door of notable faces, including Malin Akerman as Debbie Harry, Taylor Hawkins as Iggy Pop, Johnny Galecki as Terry Ork and Ashley Greene as Hilly's daughter Lisa. HuffPost Entertainment snagged some phone time with Rickman and Grint, who were candid about their unfamiliarity with CBGB's legacy but effusive about the excitement that came with reconvening for the project. Plus, Grint talks about his own punk phase and Rickman explains what Halloween used to mean for him. What are you up to today? Rickman: I'm in New York. I'm just here for three or four days for \"CBGB\" in New York and then back to work in England. Grint: I'm rehearsing a play that will start [in London] in a couple of weeks. Yeah, so that's it. Are you enjoying the theater work? Are you more of a theater guy or a film guy? Grint: I don’t know, really. This is my first theater experience, and it’s very different. I wanted to just try it; it’s something I’ve always wanted to do. Just the thought of it scares me. I’ve kind of put it off for a long time, and I just thought it was a good time to do it. And it’s a great play and a really great cast with a great director, and it was just, yeah, I’m enjoying it. Were you familiar with the legacy of CBGB as a breeding ground for the punk-rock scene prior to taking your roles in the movie? Rickman: I wasn’t familiar with CBGB at all. I didn’t know about it and didn’t know its history. I hadn’t even really heard those four letters put together because at that time I was very much in England as a drama student and an art student, so it’s all been a newand you’d have apple bobbing in it, and you’d get apples out of a bowl of water. To me it just means a soaking wet shirt. Grint: I liked Halloween. It never used to be a big thing when I was kid. We never really did it. But I actually had a good costume not that long ago. The last one, I dressed as a Play-Doh can that I made. You know Play-Doh? Of course. Grint: Well, literally, I actually made it. It was a yellow bin. I cut the bottom out and I just wore a yellow bin with a Play-Doh logo. With a yellow hat. It’s not very practical. Do you have a favorite Halloween candy? Rickman: I don’t even know what that means. The word \"chocolate\" would loom large. Grint: A favorite Halloween candy? I don’t really know. I never trick-or-treated when I was younger because we lived on a block of houses that were all just kind of elderly people who were just scared to answer the door. But yeah, candy corn, that’s a big thing. I’ve tried that. That’s pretty great. \"CBGB\" is out in limited release now.\n\nTags: Alan Rickman, Hilly Kristal, new rupert grint movie, rupert grint harry potter, new alan rickman movie, Alan Rickman Snape, alan rickman rupert grint, The Dead Boys, cbgb, Malin Akerman, cbgb movie, alan rickman cbgb, rupert grint cbgb, Rupert Grint, Taylor Hawkins, ashley greene\n\nStatement to be answered: \"Harry Potter\" alums reuni ...
# 'Article title: Alan Rickman & Rupert Grint On \'CBGB,\' Reuniting Post-\'Potter\' And Favorite Halloween Costumes\n\nArticle: The mythology of punk music\'s evolution can be traced back, more or less, to one singular staple: CBGB. Opened in 1973 in downtown Manhattan\'s East Village, the nightclub that originally intended to house country, bluegrass and blues music (hint its acronym) quickly became a breeding ground for bands like The Ramones, Talking Heads and The Police, among countless others. The legacy of the club, which closed in 2006 over a rent dispute, is on display in a new movie that stars Alan Rickman as bemused owner Hilly Kristal. It\'s a bit of a departure for anyone more accustomed to seeing Rickman, 67, play sinister Severus Snape in "Harry Potter" or Judge Turpin in "Sweeney Todd." The movie also afforded him the opportunity to reunite with fellow Hogwarts alum Rupert Grint, who portrays one-third of derriere-bearing punk band The Dead Boys, alongside Justin Bartha and Bronson Adams. They\'re joined by a revolving door of notable faces, including Malin Akerman as Debbie Harry, Taylor Hawkins as Iggy Pop, Johnny Galecki as Terry Ork and Ashley Greene as Hilly\'s daughter Lisa. HuffPost Entertainment snagged some phone time with Rickman and Grint, who were candid about their unfamiliarity with CBGB\'s legacy but effusive about the excitement that came with reconvening for the project. Plus, Grint talks about his own punk phase and Rickman explains what Halloween used to mean for him. What are you up to today? Rickman: I\'m in New York. I\'m just here for three or four days for "CBGB" in New York and then back to work in England. Grint: I\'m rehearsing a play that will start [in London] in a couple of weeks. Yeah, so that\'s it. Are you enjoying the theater work? Are you more of a theater guy or a film guy? Grint: I don’t know, really. This is my first theater experience, and it’s very different. I wanted to just try it; it’s something I’ve always wanted to do. Just the thought of it scares me. I’ve kind of put it off for a long time, and I just thought it was a good time to do it. And it’s a great play and a really great cast with a great director, and it was just, yeah, I’m enjoying it. Were you familiar with the legacy of CBGB as a breeding ground for the punk-rock scene prior to taking your roles in the movie? Rickman: I wasn’t familiar with CBGB at all. I didn’t know about it and didn’t know its history. I hadn’t even really heard those four letters put together because at that time I was very much in England as a drama student and an art student, so it’s all been a newand you’d have apple bobbing in it, and you’d get apples out of a bowl of water. To me it just means a soaking wet shirt. Grint: I liked Halloween. It never used to be a big thing when I was kid. We never really did it. But I actually had a good costume not that long ago. The last one, I dressed as a Play-Doh can that I made. You know Play-Doh? Of course. Grint: Well, literally, I actually made it. It was a yellow bin. I cut the bottom out and I just wore a yellow bin with a Play-Doh logo. With a yellow hat. It’s not very practical. Do you have a favorite Halloween candy? Rickman: I don’t even know what that means. The word "chocolate" would loom large. Grint: A favorite Halloween candy? I don’t really know. I never trick-or-treated when I was younger because we lived on a block of houses that were all just kind of elderly people who were just scared to answer the door. But yeah, candy corn, that’s a big thing. I’ve tried that. That’s pretty great. "CBGB" is out in limited release now.\n\nTags: Alan Rickman, Hilly Kristal, new rupert grint movie, rupert grint harry potter, new alan rickman movie, Alan Rickman Snape, alan rickman rupert grint, The Dead Boys, cbgb, Malin Akerman, cbgb movie, alan rickman cbgb, rupert grint cbgb, Rupert Grint, Taylor Hawkins, ashley greene\n\nStatement to be answered: "Harry Potter" alums reunite for new movie\ ...

# %%
API_URL = "https://api-inference.huggingface.co/models/bigscience/bloom"
HF_TOKEN = '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'
headers = {"Authorization": f"Bearer {HF_TOKEN}"}

import time
def text_generate(prompt):
    p = prompt
    json_ = {"inputs": p,
            "parameters":
            {
          "max_new_tokens": 20,
          "return_full_text": True,
                "do_sample": False
          }, "options": 
              {
              "use_cache": True,
              "wait_for_model":True
              },}
    response = requests.post(API_URL, headers=headers, json=json_)
    try:
        output = response.json()
    except:
        return ""
    if output == {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}:
        print("Reached hourly limit")
        for i in range(25):
            print(i/25)
            time.sleep(60*60)
        return text_generate(prompt)
    output_tmp = output[0]['generated_text']
    solution = output_tmp.split("\nQ:")[0]
    return solution

# %%
predictions_from_prompts = []
prompts = [make_prompt(x) for x in test]

for i, prompt in enumerate(prompts[880:]):
    print(i+880,"/",len(prompts))
    #inputs = tokenizer(prompt, return_tensors="pt")
    #prediction = tokenizer.decode(model.generate(inputs["input_ids"], 
    #                       max_length=len(inputs['input_ids'][0])+20
    #                      )[0])
    prediction = text_generate(prompt)
    anchor = prompt[-15:]
    pred = prediction[prediction.find(anchor)+15:].strip('</s>').strip()
    if '\n' in pred:
        #pred = pred.replace('\n', ' ')
        pred = [x.strip() for x in pred.split('\n') if len(x)!=0]
    predictions_from_prompts.append(pred)
    print('prediction:',pred)
# Out:
# 880 / 1000
# prediction: The puppy is a coyote.
# 881 / 1000
# prediction: ['Kohl’s unusual plan for Christmas is to stay open for 107 hours straight before Christmas.', 'A:']
# 882 / 1000
# prediction: The script is a fake. The Star Wars Twitter account has confirmed that the leaked script i
# 883 / 1000
# prediction: The answer is no. The article is talking about the brain's ability to map numbers, not
# 884 / 1000
# prediction: Kristin Cavallari was arrested in Illinois for driving with a California license.
# 885 / 1000
# prediction: She’s dressed as a Ghostbuster.
# 886 / 1000
# prediction: ["Scarlett Johansson like you've never seen her before", 'A:', 'I think the answer is']
# 887 / 1000
# prediction: ["Americans are eating more meals at home, which is hurting McDonald's.", 'A:', 'The answer is']
# 888 / 1000
# prediction: We asked the filmmakers if the couple depicted onscreen is indeed a lesbian couple. They neither
# 889 / 1000
# prediction: ['Article title: Find Out Why This Pittsburgh Steelers Player Left a 75 Cent Tip', 'Description: DeAng']
# 890 / 1000
# prediction: ['A:', 'The answer is', 'The Democrats are not going to nominate Hillary Clinton for president in']
# 891 / 1000
# prediction: The transmissions, broadcast by the C-Span network, technically break House rules, but one Democrat
# 892 / 1000
# prediction: ["As if we didn't love beer and sandwiches enough.", 'A:', 'I think the answer is', 'As if']
# 893 / 1000
# prediction: ['A:', 'The answer is', 'Michael Douglas', 'Because', 'The tattoo is a picture of Michael']
# 894 / 1000
# prediction: The Senate confirmed Keith Harper as ambassador to the United Nations Human Rights Council Tuesday, making him the first
# 895 / 1000
# prediction: The water in the hose was at least 150 degrees Fahrenheit, which is hot enough to cause second
# 896 / 1000
# prediction: ['1. Window Coverings', '2. Linens and Towels', '3. Uphol']
# 897 / 1000
# prediction: Christian Lunsford, son of alleged mugger, returns stolen money to victim, gets a nice
# 898 / 1000
# prediction: Europeans do this so much better than us because they have more money and they can afford to buy
# 899 / 1000
# prediction: ['Elite Dangerous: Horizons Xbox One Release Date Announced', 'A:', 'The answer is in']
# 900 / 1000
# prediction: ["Apple Makes Big iPhone Announcement And It's Bad News For Rivals", 'A:', 'The answer']
# 901 / 1000
# prediction: ['A vibrator', 'A:', 'The answer is', 'A vibrator', 'Explanation:', 'The first']
# 902 / 1000
# prediction: No, it doesn't. The article is about the new study that reveals that the app's users are
# 903 / 1000
# prediction: No, it is not true. The article says that the synchronisation of periods is a popular belief
# 904 / 1000
# prediction: ['Yes, he has seen the trailer.', 'A:', 'Yes, he has seen the trailer.', 'From']
# 905 / 1000
# prediction: ['Busy', 'A:', 'I think the answer is', 'Busy', 'Because', 'The word busy i']
# 906 / 1000
# prediction: The article is a news report about North Korea's latest threat to the United States. The article
# 907 / 1000
# prediction: ["Old Navy Under Fire For 'Offensive' Father's Day T-Shirt", 'A:', 'I']
# 908 / 1000
# prediction:
# 909 / 1000
# prediction: The Apple Watch is a beta product. It is a beta product because it is a new product
# 910 / 1000
# prediction: Sick days are a thing of the past. In fact, many companies are getting rid of
# 911 / 1000
# prediction: ['Ask This One Question to Get Past Awkward Small Talk and Make a Real Connection', 'A:']
# 912 / 1000
# prediction: ['A cool blue', 'A:', 'I think the answer is a bit more complicated than that. The color']
# 913 / 1000
# prediction: He has been busy doing voice work for video games, animated films, and cartoons, which
# 914 / 1000
# prediction: No, but it is a new technique that has not been tested on a large scale.
# 915 / 1000
# prediction: ['Scientists have found a human protein that blocks Zika virus replication and prevents brain cell death', 'Answer']
# 916 / 1000
# prediction: Indulgent food, drinks, parties, travelling and presents make Christmas an expensive time of year
# 917 / 1000
# prediction: ['Hong Kong', 'A:', 'The city that may soon lose its "skyskraper crown"']
# 918 / 1000
# prediction: The site's comeback has been fraught with problems from the get-go. In the days before it
# 919 / 1000
# prediction: George Clooney is a pretty great movie star who also happened to be a pretty bad Batman.
# 920 / 1000
# prediction: Cats are natural predators, and they have a tendency to practice their hunting skills. They
# 921 / 1000
# prediction: The song is called "Discovery of the Camp" and is featured in the TV show Band of Brother
# 922 / 1000
# prediction: You're not going to like the latest changes coming to Instagram. The company's director of business operation
# 923 / 1000
# prediction: A Shockingly Easy Way to Avoid Wasting Thousands of Gallons of Water a Year
# 924 / 1000
# prediction: ['Bill Clinton never expected to get this disease!', 'A:', 'The answer is', 'Bill Clinton never expected']
# 925 / 1000
# prediction: Anne Hathaway is a very talented actress, but she is also very annoying. She
# 926 / 1000
# prediction: ['Gillian Anderson', 'Explanation:', 'The answer is Gillian Anderson, the actress who played']
# 927 / 1000
# prediction: The Michigan Attorney General's office has released a statement in response to the Michigan Supreme Court's ruling that
# 928 / 1000
# prediction: ['Yes, it could limit mass animal extinctions.', 'A:', 'The article is a bit misleading.']
# 929 / 1000
# prediction: Chick Fil A did what after the gay club shooting? They gave out free food to the people
# 930 / 1000
# prediction: ['Yes, he is a racist.', 'A:', 'I think the question is a bit too broad, but']
# 931 / 1000
# prediction: The video in question contains footage of his landlord calling him a "faggot," which
# 932 / 1000
# prediction: Summaries that are way too long; overused résumé jargon; and appearing too formal
# 933 / 1000
# prediction: The statement is false. The dispensaries are not losing money. They are operating at a lo
# 934 / 1000
# prediction: Don't let your spouse be your everything. No one person can be your everything. No,
# 935 / 1000
# prediction: ['Mark Zuckerberg has 5 bodyguards when he goes jogging.', 'A:', 'The answer is']
# 936 / 1000
# prediction: ['September 11, 2016', 'A:', 'I think the answer is', 'September 11, 2016', 'Because']
# 937 / 1000
# prediction: The reason why Zlatan Ibrahimovic has delayed Manchester United move is because he wants to get a large
# 938 / 1000
# prediction: ['@TheEllenShow gives a grateful formerly homeless man check for huge amount', 'A:', 'The']
# 939 / 1000
# prediction: No, she doesn't hate water. She just doesn't like it.
# 940 / 1000
# prediction: ['Farrah Abraham', 'A:', 'I think the answer is', 'Farrah Abraham', 'Reasoning:', 'The']
# 941 / 1000
# prediction: ['Kevin James would be a bat boy for the Mets', 'A:', 'The answer is', 'Kevin Jame']
# 942 / 1000
# prediction: ['Rachel McAdams\' favorite "Mean Girls" quote is not trying to make fetch happen', 'A:']
# 943 / 1000
# prediction: ["Michelle Obama's movie request might surprise you", 'A:', 'I think the answer is', "Michelle Obama'"]
# 944 / 1000
# prediction: ['1. Apple', '2. Google', '3. Amazon', '4. Microsoft', '5. Samsung']
# 945 / 1000
# prediction: Yes, you can sue your employer for excessive business travel.
# 946 / 1000
# prediction: ['Singapore beats NYC Paris for this distinction', 'A:', 'I think the answer is', 'Singapore beats NY']
# 947 / 1000
# prediction: Yes! In fact, North America, including United States, Canada, Mexico, and Greenland, could
# 948 / 1000
# prediction: The man on the other end of the phone, who calls himself "Kevin Smith", ask
# 949 / 1000
# prediction: They were expecting triplets. But the girl was having her oxygen supply cut off by the two
# 950 / 1000
# prediction: The Tesla Model S's Summon feature is in "beta" (development) mode, so it
# 951 / 1000
# prediction: ['Netherlands', 'A:', 'The Netherlands has the most plentiful, healthy food: Oxfam', 'The']
# 952 / 1000
# prediction: ['The weather', 'Reasoning:', 'The article says that the showrunners are delaying the season']
# 953 / 1000
# prediction: ['Hawaii', 'A:', 'The healthiest state in America is...', 'Hawaii', 'Because...', 'The state of Hawaii']
# 954 / 1000
# prediction: The Samsung Galaxy Note 7 is a phone to be reckoned with. However, it was yet
# 955 / 1000
# prediction: Article title: Better Call Saul Team on the Challenges of Making a Prequel -- Vulture
# 956 / 1000
# prediction: ["University's alumni freak out over attempt to force them into a new social network", 'A:', 'I']
# 957 / 1000
# prediction: ['Fuck you', 'A:', 'I think the answer is', 'Fuck you', 'Because', 'The article is about']
# 958 / 1000
# prediction:
# 959 / 1000
# prediction: ['Microsoft', 'A:', 'The answer is', 'Microsoft', 'Because', 'The title of the article is Apple reveal']
# 960 / 1000
# prediction: The survey results suggest that people are more likely to sacrifice the lives of pedestrians than their own
# 961 / 1000
# prediction: ['Ugg boots', 'A:', 'The answer is', 'Ugg boots', 'Because', 'The top trending']
# 962 / 1000
# prediction: ['Love saves us all.', 'A:', 'The answer is', 'Love saves us all.', 'The reason i']
# 963 / 1000
# prediction: ['A:', 'The inductor is a coil of wire, and the capacitor is a block of some']
# 964 / 1000
# prediction: ['Social connections make us happier and healthier while loneliness kills', 'A:', 'The answer i']
# 965 / 1000
# prediction: ['Starbucks is testing a new latte you probably want to know about', 'A:', 'I think the problem']
# 966 / 1000
# prediction: She responded by giving him a dose of his own medicine. It's a familiar tale for many young
# 967 / 1000
# prediction: The 'walk of shame' is a form of punishment for theft in Indonesia. The punishment is carried
# 968 / 1000
# prediction: ['Malala Yousafzai', 'A:', 'I think the answer is', 'Malala Yousaf']
# 969 / 1000
# prediction: Homework could have an impact on kids' health. Should schools ban it? The answer is no
# 970 / 1000
# prediction: ['Jennifer Lopez, Harry Connick Jr., Keith Urban', 'A:', 'The answer is', 'Jennifer Lopez,']
# 971 / 1000
# prediction: Fred Armisen will guest star on "House Of Lies," Showtime's Golden Globe-n
# 972 / 1000
# prediction: ['Lithuania', "Question: What country joined the euro zone on New Year's Day?", 'A:', 'Lithuan']
# 973 / 1000
# prediction: The power of simple life changes to prevent heart disease is that they can be done by anyone,
# 974 / 1000
# prediction: Yes, Meryl Streep was approached to play Susan Boyle in the upcoming biopic about her
# 975 / 1000
# prediction: ['No, the man killed his wife because she wanted to die.', 'A:', 'The article is a bit']
# 976 / 1000
# prediction: Mary Shelley was a woman of many talents. She was a writer, a feminist,
# 977 / 1000
# prediction: ['People regularly use to have two periods of sleep and do tasks in between', 'Description: Professor Roger Ekirch of Virginia Polytechnic and State University claims people used to have a first sleep and a second sleep and it was a normal practice until the late 1800s.', 'Article: It may bring some comfort to those who go to bed, only to wake up in the middle of the night frustratedly unable to get back to sleep. While today this is seen as insomnia, until the end of the 19th century people did it on purpose. Well after the Industrial Revolution, many people in Britain still swore by the health benefits of a ‘first sleep’ and ‘second sleep’. For centuries, according to a sleep historian, they would use the time when they woke up at night to do household chores, visit friends - or make love to their spouse. Sleeping through the night is by comparison a ‘modern invention’, according to Professor Roger Ekirch of Virginia Polytechnic and State University. Speaking yesterday at the Royal Society of Medicine, he said: ‘Middle of the night insomnia was a rare problem before the late 1800s. As early as in the 16th century it was utterly normal, unworthy of comment.’ Bedtime was historically around 10pm, after which, he added: ‘Most individuals awakened shortly past midnight to an hour or so of consciousness, in which they meditated, they conversed and made love - not necessarily in that order. ‘A 16th century physician said making love was better after the first sleep, when people have more enjoyment and do it better.’ People used the gap between their first and second sleep to wash clothes, have a conversation or even to steal the neighbour’s firewood, historical records show. It was thought that lovemaking between the two sleep phases was responsible for large families, with labourers able to conceive several children because they waited until after their energy-giving first sleep to do it. It was also thought to aid digestion, if people turned from lying on their right to their left when they woke up during the night. References to two phases of sleep go back to Chaucer, with a character in The Squire’s Tale, in the Canterbury Tales, deciding to go back to bed after her ‘firste sleep’. Unless kept awake by a cold house, bed bugs or worry, most people were unconcerned about getting up in the night. It was not seen as insomnia, and ‘sleeplessness’ referred only to failing to fall asleep in the first place. But the practice of having a first and second sleep fell out of favour in the decades following the Industrial Revolution, when people increasingly worked long hours as machine manufacturing dominated British industry. The sleep historian said the shift came at the end of the 19th century, as the end of the first sleep crept later to around 3am, before it was jettisoned altogether. Suddenly sleeping in two phases was seen as inefficient and people were warned that indulging would lead to headaches and constipation. It was even feared that it might, in young men and women, cause ‘lustful thoughts’. Speaking at a Royal society event in London on the subject of sleep, Prof Ekirch said: ‘Sleep represented a necessary evil best confined to a single interval, thus allowing someone to steal the march on the day and on one’s fellow human beings who were still enjoying their second sleep.’ As a result, today, the history professor said, many people who wake at night think they are ‘abnormal’. However research suggests this may be a normal sleeping pattern when people are away from artificial lights and the blue light from electronic devices. Prof Erich said: ‘Rather than the product of an implacable disorder, their sleep, viewed from the high ground of history, may just be natural.’', 'Tags: Why, waking, night, natural', 'Why waking up in the night is natural: People regularly use to have two periods of sleep and do tasks in between', 'A:', 'The article i']
# 978 / 1000
# prediction: The name of the game is to bring autonomous driving to urbanites who don't own cars — and don't
# 979 / 1000
# prediction: ['Corsica, Germany, Italy, New Zealand, and San Francisco', 'A:', 'The answer']
# 980 / 1000
# prediction: The year 2016 is likely to be the hottest year on record, according to the Met
# 981 / 1000
# prediction: She went, 'Oh, wonderful!' I felt like I wanted to cry. It wa
# 982 / 1000
# prediction: The body-positive Instagram is going viral for all the right reasons because it is a powerful and inspirational
# 983 / 1000
# prediction: ['A:', 'The answer is', 'The Piano Guys', 'Because', 'The Piano Guy']
# 984 / 1000
# prediction: They're cheap. You can get a really great Chromebook for around $200, or about one
# 985 / 1000
# prediction: ['Cheyenne Jackson is engaged to his boyfriend', 'A:', 'You can use the following regex:', '\\b']
# 986 / 1000
# prediction: This baby starts crying. Watch what the dog does!
# 987 / 1000
# prediction: ['Cornell University', 'Question: What is the name of the Ivy League university that appointed its first female president']
# 988 / 1000
# prediction: Saying "done" is a simple way to train your brain to be more productive. It create
# 989 / 1000
# prediction: Carbonated water is good for you.
# 990 / 1000
# prediction:
# 991 / 1000
# prediction: The Great Pyramid of Giza is not perfectly square, but it is not lopsided either
# 992 / 1000
# prediction: ['Beheadings, impalement, and smoking', 'A:', 'I think the answer is']
# 993 / 1000
# prediction: Statement to be answered: Inside our three-month effort to attend Apple's iPhone 7 launch party
# 994 / 1000
# prediction: The SAS sniper shot the leader of the Islamic State contingent, flanked by several guards with
# 995 / 1000
# prediction: ['All Along the Watchtower', 'Reasoning:', 'The song is a cover of a song by']
# 996 / 1000
# prediction: ['A:', 'I think the answer is that the article is a satire. The article is written']
# 997 / 1000
# prediction: ['A "blood moon" is coming Oct. 8 -- and here\'s how to see it', 'A:']
# 998 / 1000
# prediction: ['Tami Erin', 'A:', 'I think the answer is', 'Tami Erin', 'Because']
# 999 / 1000
# prediction: I think the answer is celery.

# %%
with open(f"{name}.txt", 'w') as f:
    f.writelines([str(x)+'\n' for x in predictions_from_prompts])

# %%
prompts[880:][0]
# Out:
# 'Description: A family adopted a baby coyote when it was in need, and now it\'s a member of the family.\n\nArticle: What would you do if you spotted a sick, injured, or otherwise helpless animal? We’d all like to think that we’d do the right thing and rush to help, but sometimes fear or concern for our own safety makes us take pause. For California resident Sharon Bertozzi, however, that protective instinct came without hesitation. When she saw a weak animal on her front porch, she immediately sprung into action. Little did she know, this creature had quite a surprise in store for her... One afternoon, Sharon discovered a small fur ball curled up behind a vase on her front porch. She assumed the animal was a very sick dog and quickly decided to help. Sharon placed the poor creature inside a small cage that she had in her garage. Though she knew the dog couldn’t be kept in there for long, it was clearly better than nothing. The tiny pup desperately needed help - fortunately, Sharon had the phone number of a local animal rescue team on hand and dialed immediately. Sharon had called the City of Folsom Animal Services. Thinking things were about wrapped up, Sharon was told something by rescuer Cindy Walden that she could not believe. The sick dog Sharon rescued was actually a female coyote who was suffering from a particularly bad case of mange. "She had such soft eyes, that relayed the message of ‘help me if you can,\'" Cindy said. Gold Country Wildlife Rescue (GCWR) came soon enough and took the coyote to their shelter, later naming the animal Princess. Luckily, GCWR was specialized in providing care and rehabilitation for coyotes. Princess was eventually taken to Sierra Wildlife Rescue in Placerville, California, when she was feeling well enough. There, workers continued to care for her so she could make a full recovery. Here she was able to interact with other coyotes, which came as a huge relief it had obviously been a while since Princess was able to spend time in the company of her own species... Princess soon became friends with the two coyotes that she was placed with. Both were around her age and eager to get to know her. The three of them seemed to get along well, much to the relief of the rescue workers. Princess and her new coyote buddies developed a close bond while they were at the wildlife rescue. Workers knew that it wouldn’t be long until they were released back into the wild. That day finally came, and the bonded — healthy — coyotes left the comfort of the sanctuary to learn to fend for themselves. Thanks to Sharon’s kindhearted gesture, Princess became the adult everyone had hoped she would.\n\nStatement to be answered: Her Dad Brought Home A Strange Puppy. But Look Closely... Because That’s NOT A Regular Dog.\n\nAnswer:'

# %%
#Fjern gentagelser fra predictions
#Fjern overskrifter fra predictions
#Fjern A: fra predictions
#Fjern Explanation: fra predictions
#Fjern Reasoning: fra predictions

# %%
df = pd.read_json('input.jsonl', lines=True)

# %%
spoilers = df[["uuid","postId"]]
spoilers['spoiler'] = clean_preds

json_output = spoilers.to_json(orient='records', lines=True)

with open(f"{name}.jsonl", 'w') as f:
    f.write(json_output)
# Out:
# /tmp/ipykernel_393/742884195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spoilers['spoiler'] = clean_preds

# %%
# !python3 evaluation.py --input_run test_output.jsonl --task 2 --ground_truth_spoilers validation.jsonl --output_prototext output.txt

# %%
# Out:
#                                      uuid              postId  \
# 0    2f3e30d7-972c-4812-b727-6b582de52137  420585068076101633
# 1    45425f74-4c0e-420c-aea8-6337ea91e107              4km87q
# 2    2fb84020-cfdb-4b7f-9cfc-b891c306c946              4s4f3b
# 3    7cc8b816-a3fe-4b3f-9568-b353f87a3161  429398501613895680
# 4    b90a7343-ab27-4750-8e12-43f3f03fc9e5  828292353706176512
# ..                                    ...                 ...
# 995  9615b028-fa90-4bb6-9708-9d59d3cee08b              54zmeg
# 996  74e4c92c-3583-4c80-b726-36f1fe63f8c9  738816406091923456
# 997  c5ec6cc8-46b6-4ac6-a7ee-d891fb8938b7  518772848010461184
# 998  a202e079-0fae-4fde-8d89-ed6be2adc17a  412608279760879616
# 999  2c8ce9f1-8571-4bc5-9ede-a86f14dbb16f  705553853236781056
#
#                                                spoiler
# 0    [The simple household item that saves lives is...
# 1    [Gwyneth Paltrow,  I think the answer is,  Gwy...
# 2    [The new theory on Hiddleswifts romance is biz...
# 3                        [JaVale McGee,  JaVale McGee]
# 4    [Alex Owens-Sarno,  The title of the article i...
# ..                                                 ...
# 995  [All Along the Watchtower,  The song is a cove...
# 996  [I think the answer is that the article is a s...
# 997  [A blood moon is coming Oct. 8 -- and heres ho...
# 998  [Tami Erin,  I think the answer is,  Tami Erin...
# 999                    [I think the answer is celery.]
#
# [1000 rows x 3 columns]

# %%
with open("BLOOM_API_test_predictions.txt", 'r', encoding='utf-8') as f:
    predictions = [line.strip('\n').strip('[]"\'').split(',') for line in f]

clean_preds = []
for preds in predictions:
    tmp_preds = []
    for pred in preds:
        pred = pred.replace('"','')
        pred = pred.replace("'",'')
        pred = pred.replace("\\",'')
        tmp_preds.append(pred)
    clean_preds.append(tmp_preds)
# Out:
# [['The simple household item that saves lives is soap. The soap that Zaikis makes is sol'],
#  ['Gwyneth Paltrow', ' I think the answer is', ' Gwyneth Palt'],
#  ['The new theory on Hiddleswifts romance is bizarre but strangely compelling.'],
#  ['JaVale McGee', ' JaVale McGee'],
#  ['Alex Owens-Sarno', ' The title of the article is The Little Girl'],
#  ['The first love is the one that sticks with us the most. It is the one that w'],
#  ['The reason is that the paper is a breeding ground for bacteria. The paper is moist and warm'],
#  ['Description: She Puts Chicken Nuggets on the Waffle Iron. What She Does Next Will'],
#  ['Ratan Tata is heartbroken because of the ongoing tussle between him and Cyrus Mistry.'],
#  ['The Jungle Book (2016) - Netflix', ' The Invitation (2015) - Netflix'],
#  ['The iPhone 6s Plus has a 2',
#   ' 750 mAh battery',
#   ' which is actually smaller than'],
#  ['Loch Ness Monster Found Dead',
#   ' The answer is',
#   ' Loch Ness Monster Found'],
#  ['Chicago',
#   ' The article says that the most profitable of all? Chicago. In Chicago'],
#  ['The coals were not hot enough. The coals were not hot enough. The coal'],
#  ['@wearephoenix cancel big gig after Thomas Mars falls ill',
#   ' You can use the'],
#  ['Former President Bill Clinton delivers a sharp message to Donald Trump and his base'],
#  ['The XFL was only around for one year but these are seven reasons why as ridiculous as'],
#  ['The movie is about a blue tang fish named Dory',
#   ' who has short-term memory loss. She'],
#  ['The inhaler was the problem. Downs and her husband insisted that was the cause f'],
#  ['Former Los Angeles Laker Chris Duhon was injured in a hit-and-run accident in Florida over th'],
#  ['The doctor suspects that the teen is hiding pregnancy when he sees her belly because he thinks tha'],
#  ['The owner built a model train track around his property.',
#   ' The answer is',
#   ' The Gardener'],
#  ['She is a fashion designer and the founder of the fashion label Ronson.',
#   ' I'],
#  ['Catholics', ' The answer is', ' Catholics', ' The article say'],
#  ['Aus',
#   ' Texas',
#   ' I think the answer is',
#   ' Austin',
#   ' Texas',
#   ' Because',
#   ' The article'],
#  ['He’ll Pay You $180', ' 000', ' 000 To Marry His Daughter... But There’'],
#  ['The article is about the Pakistani government renaming a department of the Quaid-e-Azam University'],
#  ['The door is a jok',
#   ' and the secret behind it is that there is no secret behind it'],
#  ['Yes',
#   ' it is possible to kill someone with farts. It would take some doing',
#   ' but it'],
#  ['They dropped him.', ' The answer is', ' They dropped him.', ' The title'],
#  ['Apple’s new iPhone 7 and iPhone 7 Plus will be packed full of all sorts of technology wh'],
#  ['1. Hillary Clinton’s Nomination Is A Victory For The Smart Girls Jill Filipov'],
#  ['The article is a joke. The title is a joke. The article is written in'],
#  ['We Are Men Canceled By CBS',
#   ' Mike And Molly To Return In November',
#   ' Nov. 4',
#   ' the network announced Wednesday. From Mon.',
#   ' Oct. 14',
#   ' 2 Broke Girls will move to 8:30 p.m. ET to replace We Are Men',
#   '  while repeats of The Big Bang Theory will air at 9 p.m. until Nov. 4',
#   ' when Mike and Molly will take over the timeslot. Men had an inauspicious start despite the lead-in from How I Met Your Mother',
#   '  earning only 6.4 million viewers and a 2.0 rating in the adults 18-49 demo in its premiere',
#   ' slipping to 5.4 million and a 1.8 rating in its second episode. Will you miss We Are Men? CBS New Shows 2013-2014',
#   ' Tags: TV Canada',
#   ' we are men canceled',
#   ' fall TV 2013',
#   ' Mike and Molly',
#   ' we are men cancelled',
#   ' we are men',
#   ' we are men cbs',
#   ' Mike And Molly CBS',
#   ' cbs',
#   ' reality-free',
#   ' Fall TV',
#   ' Statement to be answered: The latest show to be canceled this season is...',
#   ' The answer is',
#   ' We Are Men',
#   ' The title of'],
#  ['Mercury(II) thiocyanate (Hg(SCN)2', ' The answer i'],
#  ['The most successful scams are carried out on women between the ages of 40 and 60',
#   ' say'],
#  ['Nice try',
#   ' #Microsoft! Microsoft may be over-exaggerating Windows 7’s problems after all'],
#  ['Walter White is dead.'],
#  ['Kevin Love',
#   ' I think the answer is',
#   ' Kevin Love',
#   ' Because',
#   ' The first sentence i'],
#  ['$25 million',
#   ' The answer is $25 million.',
#   ' The article you linked to say'],
#  ['Peter King: Isolationist GOP Members Damaging To The Nation', ' The'],
#  ['1. Tallulah Bankhead (1902–68) Tallulah Bankhead was an American b'],
#  ['David Schwimmer helped NYPD solve alleged stabbing',
#   ' I think the answer is',
#   ' David Schw'],
#  ['Photographer Takes Clearest Ever Photo Of ‘Loch Ness Monster’'],
#  ['Queens Of The Stone Ages Josh Homme: Jay Z Should F--k Off'],
#  ['1. They slow down to appreciate lifes little pleasures.',
#   ' 2. They exercise.',
#   ' 3'],
#  ['This Rapper Almost Quit Hip-Hop For Good...And you wont believe why'],
#  ['‘I Know I’m Not Supposed To Be Up Here’'],
#  ['He is an inspiration to many! 😃👍', ' I think you are looking'],
#  ['The student government of a California university vowed to drop the term illegal immigrant last week'],
#  ['Altruism', ' I think the answer is altruism. The article you'],
#  ['Bob Ross is back.',
#   ' The answer is',
#   ' Bob Ross is back',
#   ' The reason is'],
#  ['I had not seen or even heard of braces before coming to America. Several kids I knew ha'],
#  ['The 5 WORST Exercise Mistakes That Are Destroying Your Metabolism',
#   ' Keeping'],
#  ['The Killers and M83 teamed up with Social Network star Max Minghella'],
#  ['The answer is a bit more complicated than that. The site shows everything that Google knows about you'],
#  ['Yes', ' they are.'],
#  ['Therapists are noticing a lot of their clients are feeling overwhelmed and anxious about th'],
#  ['The Sportsma',
#   ' near Whitstable in Kent',
#   ' has topped the 2016 National Restaurant award'],
#  ['This 3-year-olds mom found her standing on something',
#   ' but the reason why broke her heart:'],
#  ['Richm',
#   ' California Backs Plan To Use Eminent Domain To Help Underwater Borrowers',
#   ' Article'],
#  ['Little did the four thugs in Illinois realize who they were messing with when they decided to attack'],
#  ['Riri Williams', ' Riri Williams is the new Iron Man. She i'],
#  ['Melissa McCarthy Says Her Goodbyes to The World!',
#   ' I think the answer is'],
#  ['The baby died minutes after daycare worker put him in car seat for a nap. I ha'],
#  ['I was overcome with grief when my 19-year-old daugh',
#   ' Vanessa Nicolson sent a message to'],
#  ['Revolutionary knitting',
#   ' I think the answer is',
#   ' Revolutionary knitting',
#   ' Because'],
#  [''],
#  ['The article also includes a video of a woman who says she was told by a white man tha'],
#  ['The commercial is a tribute to the people who lost their lives in the 9/11 attacks. The commercial'],
#  ['19 Teens Who Did The Most Inxa02016', ' The answer is', ' 19 Teen'],
#  ['The nations food industry announced plans to cut through the food label confusion with easier to understand languag'],
#  ['The feature phone is a simple dev',
#   ' with a small screen and a few basic features. It'],
#  ['Kim Kardashian checking her makeup',
#   ' I think the answer is',
#   ' Kim Kardashian checking her makeup'],
#  ['Our hearts are broken at this photo of a toddler standing on the toilet',
#   ' I think'],
#  ['Yes',
#   ' really. Queen Rania of Jordan has joined the social media bandwagon',
#   ' and her'],
#  ['Kundan Lal Gujral', ' The answer is', ' Kundan Lal Guj'],
#  ['Banksy responded by painting a mural on the building.'],
#  ['Queen Maxima shows us the one color you need to wear for fall',
#   ' I think the'],
#  ['Jaden Smith Dead: Viral CNN Video Finally Confirms Suicide?',
#   ' The article is a'],
#  ['I think the answer is',
#   ' She wants to play Kitana because she likes the blade'],
#  ['The Thing monster is not a shape-shifter. It is a human being that has been inf'],
#  ['A pair of good quality boots',
#   ' I think the answer is',
#   ' A pair of good quality'],
#  ['Lemons are great for your sk',
#   ' and drinking lemon water in the morning is a great way to'],
#  ['Spark',
#   ' The answer is Spark',
#   ' the New Zealand telecommunications company.'],
#  ['The cutouts are on the side of the swimsu', ' not the front.'],
#  ['The New York Times',
#   ' CBS News',
#   ' BBC',
#   ' The Washington Post',
#   ' LA Times',
#   ' Mashable'],
#  ['Neanderthals were much like us. Their brains were as large as ours',
#   ' and they carried'],
#  ['@MileyCyrus tweets post-shower photo ', ' I think the answer i'],
#  ['The boy was asking Santa to help him die.',
#   ' The boy was asking Santa to help him'],
#  [''],
#  ['@KirstieAlley reveals what triggered her cocaine addiction:',
#   ' @KirstieAl'],
#  ['Your ObGyn is probably doing this painful and unnecessary thing',
#   ' I think the answer i'],
#  ['Because he is a narcissist and he thinks he is the best thing since sliced bread.'],
#  ['London Bridge is down',
#   ' The answer is',
#   ' London Bridge is down',
#   ' Because',
#   ' The article'],
#  ['The offer can be g',
#   ' but you can refuse',
#   ' according to P3 Organics entrepreneur Amy Caz'],
#  ['Men are actually tracking their colleagues’ periods with an app',
#   ' I think the answer is'],
#  ['Nintendo’s next generation system – code named NX – will reportedly eschew discs f'],
#  ['The article is about Madeleine McCa',
#   ' a British girl who went missing in 2007. The article'],
#  ['A Dog In A Crate!'],
#  ['Millennials: these are the most common mistakes you could make with your money',
#   ' I'],
#  ['Advertising is a huge part of the TV business. But kids programming is a special cas'],
#  ['Brenton Thwaites', ' I think the answer is Brenton Thwaites. I'],
#  ['The answer is the article titl',
#   ' The Naked Celebrities in Kanye Wests Video React.'],
#  ['The problem is that the home is a messy place. The home is a messy place. Th'],
#  ['Olivia Wilde', ' Statement to be answered:'],
#  ['Clench the muscles in your lower body to push blood back into your upper body.'],
#  ['Netflix has only canceled three shows: Hemlock Grov',
#   ' Lilyhammer',
#   ' and Bloodline'],
#  ['Donald Trump',
#   ' The answer is',
#   ' Donald Trump',
#   ' because',
#   ' The title of the article i'],
#  ['Wiley – five landmarks in the godfather of grimes career', ' I think the'],
#  ['McLaren is spending £1 billion pounds ($1.45 billion dollars) over the next six yea'],
#  ['The tunnels were discovered in the Villa of Hadria',
#   ' a Roman emperor who ruled from 117 to'],
#  ['$420', ' 000', ' I think the answer is', ' $420', ' 000', ' Reason'],
#  ['Bone broth', ' The answer is', ' Bone broth', ' The title of'],
#  ['Rockstar has really done the unthinkable this time!',
#   ' You Wouldn’t Believe What Rock'],
#  ['Its a good time to be @britneyspears', ' I think the answer is'],
#  ['The answer is that the satellite images were taken by the Landsat 8 satell',
#   ' which is operated'],
#  ['Holly Madison reveals her biggest fear',
#   ' I think the problem is that you have a lot of'],
#  ['Yes',
#   ' I did. I was surprised to learn that KFC is a huge deal in Japan on'],
#  ['Taking Tylenol may reduce your ability to feel certain emotions toward others.',
#   ' I think'],
#  ['Arrogance', ' The CEO of Whole Foods says he never hires people who'],
#  ['Over the years',
#   ' insomniacs have been offered pills',
#   ' plants',
#   ' mindfulness'],
#  ['It’s not intelligence or talent... it’s something that anyone can learn.',
#   ' The answer is',
#   ' It'],
#  ['The Biggest Loser is a TV show that helps people lose weight. The show is a h'],
#  ['Belgium',
#   ' I think the answer is',
#   ' Belgium',
#   ' Because',
#   ' The country all food lovers need'],
#  ['The father is not charged with homicide because he was defending his daughter from a sexual assault. Th'],
#  ['The presence of other people.', ' The presence of other people.'],
#  ['The baffling reason many millennials dont eat cereal is because they dont want to clean u'],
#  ['A new study suggests that raising the minimum wage could have lasting effects not only on todays economy',
#   ' but'],
#  ['The All New Captain Underpants Extra Crunchy Book o Fun 2', ' I think'],
#  ['The number of blades of a fan depends on the place where they are being used. In India'],
#  ['Kris Bryant and Co. are responsible for four of the five most popular MLB jerseys s'],
#  ['20. Parkour Training (A', ' free) You can come to a sticky end running up'],
#  [''],
#  ['Jessica Simpson rocked skinny jeans for a night out with her family on Tuesday.',
#   ' I'],
#  ['This is a picture of a model with fiery angel wings on a smartphone',
#   ' Thi'],
#  ['Ubisoft Club is a free-to-play service that allows players to access a library of Ub'],
#  ['The US blows everyone else out of the water in 1 key way because the US has the most su'],
#  ['The crucial thing is to use the right keywords.',
#   ' I think the answer is',
#   ' Your résumé'],
#  ['Relationships are the key to a happy life.',
#   ' The answer is',
#   ' Relationships are the'],
#  ['Robert Downey Jr. Confirms The Future Of Iron Man 4',
#   ' The answer is Robert'],
#  ['Colombia',
#   ' I think the answer is',
#   ' Colombia',
#   ' The article title is a'],
#  ['Love Actually',
#   ' The Holiday',
#   ' Love',
#   ' Actually',
#   ' The Grinch',
#   ' The answer i'],
#  ['The ultrasound photo.'],
#  ['Facebook is changing its algorithm to avoid clickbait headlines',
#   ' which it says are misleading'],
#  ['The clocks go back at the end of Octob',
#   ' which means waving goodbye to British Summer'],
#  ['Tennessee could become the 21st state in the country to legalize medical marijuana. A bill introduced las'],
#  ['She died from commotio cordis',
#   ' a rare heart condition that occurs when the heart is jol'],
#  ['1. Did you know its technically illegal to drive the Model X over the Brooklyn Bridge?',
#   ' 2'],
#  ['Pebbles new $70 device might be one of the best products of the year'],
#  ['The Battlefield 1 Open Beta will end on Thursday',
#   ' September 8. EA made the announcement on'],
#  ['50 years since Bob Dylan did what?',
#   ' The answer is',
#   ' 50 years since Bob Dylan'],
#  ['The Symptom of Depression We Dont Talk About',
#   ' The answer is',
#   ' The symptom'],
#  ['Genius tips for getting your children to do the things they dont want to (including fibbing'],
#  ['I have a travel credit card that gives me 5',
#   ' 000 bonus miles for signing up. I'],
#  ['The answer is that it would be a very very very very very very very very very'],
#  ['Between the Bars'],
#  ['Yes', ' Dormammu is a major villain from the comics and is a major threat'],
#  ['The baby panda is actually a second cub', ' not the first one.'],
#  ['@CoryBookers win exposes glaring senate reality', ' The answer is'],
#  ['Yahoo', ' The answer is Yahoo.'],
#  ['Jon is in the crypts', ' which is where Lyanna Stark is buried. He i'],
#  ['N',
#   ' the government cannot disregard a vote for Brexit. The government can ignore the vote',
#   ' but'],
#  ['I tried the alkaline diet and heres what happened',
#   ' I tried the alkaline diet and here'],
#  ['Pain & Gain', ' The answer is', ' Pain & Gain', ' The title of'],
#  ['The catch is that the phones will only have black-and-white displays. The company says its aiming f'],
#  ['The rounded corners are a design choice that Apple has made for a long time. The rou'],
#  ['Charity is good for your health because it gives you a sense of purpose and meaning in lif'],
#  ['The Patriots were down 28-3 with 21 minutes left in the game. They needed a miracl'],
#  ['They are all aliens.',
#   ' I think the answer is',
#   ' They are all aliens.',
#   ' Reason'],
#  ['Saudi Arabia was the top recipient of American-made arms from 2011-2015',
#   ' followed closely by the'],
#  ['Brie Larson', ' Brie Larson', ' Brie Larson is the correct answer'],
#  ['The judges are all wom',
#   ' and they are all mothers. They are all mothers of daughters'],
#  ['The ‘Right’ Age to Get Married',
#   ' The ‘right’ age to get married is between'],
#  ['Coconut milk', ' The answer is Coconut milk.', ' The article is about the'],
#  ['The book is a mem', ' and it is a political treatise. It is not a'],
#  ['Katy Perry and Rihanna now share a pretty big record',
#   ' I think the answer is'],
#  ['The waitress is going to surprise her kids with the money.'],
#  ['Xylitol', ' The answer is Xylitol.'],
#  ['The three models are in a group called SketchSHE',
#   ' and they’ve become internationally famous for'],
#  ['The answer is the United Nations Commission of Inquiry on Human Rights in Eritrea',
#   ' which released it'],
#  ['The answer is the number of the statement.'],
#  ['Bill Maher has a very important message for people interviewing Trump ➡️ by @lee_m'],
#  ['N'],
#  ['Sydney',
#   ' The answer is Sydney',
#   ' Australia.',
#   ' The article is talking about the Darling Square'],
#  ['The truth of the matter is manufacturers owe a duty of care to consumers. The specific duty you'],
#  ['Red cabbage is boiled and the liquid is used to make a natural food coloring. Th'],
#  ['Country star tells Westboro Baptist Church how he really feels',
#   ' I think the answer is that'],
#  ['Lindsay Lohan is back in the recording studio and youll never guess who shes collaborating with.'],
#  ['A $10 Bottle Of Wine Has Been Named One Of The Best In The World - Wi...'],
#  ['Linda R',
#   ' 65-year-old model explains secret to aging naturally',
#   ' I think the answer i'],
#  ['Go to a Krispy Kreme donut shop on Feb. 24', ' and be one of the'],
#  ['@glaad: The fall TV season will be less gay than the fall TV season of las'],
#  ['The pizza saver is a small plastic piece that sits on top of the pizza in the box'],
#  ['The 9-5 workday is a thing of the past. The future of work is flexibl'],
#  ['I sat on the Iron Throne from Game of Thrones made a visit to New York'],
#  ['1. ATM fees', ' 2. Late fees', ' 3. Underused subscriptions', ' 4.'],
#  ['NASA might plant a garden on the moon',
#   ' The answer is',
#   ' NASA might plant a garden'],
#  ['Yes',
#   ' people look like their names.',
#   ' The article is a bit misleading. The study i'],
#  ['The Knicks are the worst team in New York sports history.',
#   ' The Knicks are the'],
#  ['The rising trend of all-cash buyers is bad news for first-time homebuyers'],
#  ['I’m not sure what the term clickbait means anymore. It seems to have becom'],
#  ['Bob Ha',
#   ' the trainer on the popular NBC show',
#   ' thinks contestants should try intermittent fasting'],
#  ['Dont eat these 16 cancer causing foods',
#   ' The answer is',
#   ' Dont eat these 16 cancer'],
#  ['Would I do it tomorrow?',
#   ' I think the answer is',
#   ' No',
#   ' Because',
#   ' Tomorrow i'],
#  ['Drake is dominating the charts by doing something no other artist has ever done',
#   ' The answer'],
#  ['31 Like Like 0 1 share Raw potatoes have been used for centuries to cater for several ailments and effectively too. Blending this crop to extract it’s juice is a known traditional remedy. It helps in combating several ailments such as gastritis',
#   ' diabetes',
#   ' it will lower your blood pressure and it can even destroy cancer cells. Leading researchers advice that you consume 1 tablespoon of potato juice mix with some water and you should drink this solution 30 minutes before any meal and that includes breakfast',
#   ' lunch and dinner to take care of gastritis. Studies have been conducted on the health benefits of potato juice and one was done by a professor of Medicine from the University of Akita',
#   ' Japan – Dr. Kagamine. He was able to extract a compound from raw potatoes that had a tremendous effect on tumors',
#   ' reducing it effectively. When you drink raw potato juice you will boost your immune system and avoid infectious diseases easier. It will also give you a jolt in energy. Here are some health benefits of raw potato juice. It will boost your immune system. It lowers your blood sugar. It helps cater for liver and kidney ailments. It helps to combat cardiovascular disease. It treats skin diseases. It helps to detoxify the body. It will combat gastritis and other stomach issues. It helps in combating cancer. Potato peels are rich in zinc',
#   ' potassium',
#   ' protein',
#   ' carbohydrates',
#   ' iron',
#   ' vitamin C and B6. They also help to detoxify your body of harmful toxins',
#   ' it is also great for treating blackheads',
#   ' acne and in giving your bright and glowing skin. Using raw potato juice in making a homemade facial mask will help to cleanse your pores and also tighten it. DIY Homemade Potato Juice Wash the potatoes and take out the the seeds and any green part from the crust. Chop up the potatoes into small pieces. Use a cloth fabric to wrap the chopped pieces and then squeeze the juice out. You can use a juicer to blend the chopped potatoes. Consume your raw potato juice fresh and you can drink it with other veggies and fruits as well such as lemon',
#   ' carrots and apples.',
#   ' Statement to be answered: This Will Shock You – The Juice That Kills Cancer Cells',
#   ' Treat Diabetes',
#   ' Gastritis and Lower Blood Pressure!',
#   ' The juice that kills cancer cells',
#   ' treat diabetes',
#   ' gastritis and lower blood pressure is the juice'],
#  ['The eclipse will plunge countries into darkness and spark the end of the worl',
#   ' doomsayer'],
#  ['The guy was singing Smash Mouths All Star even though the lyrics to Joh'],
#  ['$1.3 billion', ' The answer is', ' $1.3 billion', ' EA'],
#  ['Diversification is a buzz word that investors have been taught they should desire. When Im speaking'],
#  ['California and New York top plenty of lists. This isnt one of them.',
#   ' I think the'],
#  ['#8 is the one that is HORRIFYING. The former employee says tha'],
#  ['No', ' The answer is', ' No', ' The first sentence is a'],
#  ['Dermatologists Explain How To Solve Mans Stinky Balls Problem'],
#  ['Wiz Khalifas Blacc Hollywood', ' The answer is', ' Adeles voice will'],
#  ['The answer is no. The game will not support the older save files in present gen consol'],
#  ['The trend is the increasing number of criminals-turned-terrorists.'],
#  ['The NHLs newest franchise will be called the Vegas Golden Knights.'],
#  ['Alex Newell is a transgender member of the shows glee club', ' The answer'],
#  ['Alfred Hitchcock',
#   ' I think the answer is',
#   ' Alfred Hitchcock',
#   ' Because',
#   ' The'],
#  ['The mummy was found in a grave in the Altai Mountains of western Mongolia. The grav'],
#  ['Nas Reveals New Album Details', ' Business Ventures & More'],
#  ['The literal point of trees is the point where the trees are. The point of'],
#  ['The real money-maker for the Internet of Things is the Industrial Internet of Things. The Industrial I'],
#  ['Jacks',
#   ' Mississippi',
#   ' I think the answer is',
#   ' Jackson',
#   ' Mississippi',
#   ' because',
#   ' The title'],
#  ['The packaging is not sexist. The packaging is gender neutral. The packaging is not sexist becaus'],
#  ['Scientists just discovered where HIV began',
#   ' The answer is',
#   ' Scientists just discovered where HIV'],
#  ['The Nahmad family of London art dealers is said to have tucked away in the Geneva'],
#  ['Pennsylvania Hands Down Another Controversial Homeless Feeding Ban',
#   ' I think the answer'],
#  ['Kelly Clarkson Expecting A Baby Girl With Husband Brandon Blackstock',
#   ' I think the'],
#  ['She is looking as gorgeous as ever because she is wearing a beautiful dress.'],
#  ['TIDALHiFi was the most popular free app for Apple this weekend.',
#   ' I think'],
#  ['N',
#   ' BlackBerry is not done making smartphones. It is just done making smartphones that it makes itself.'],
#  ['N',
#   ' it is not time to change it. The article is not saying that your password is on'],
#  ['The word is klittra',
#   ' which is a combination of the Swedish words for clitori'],
#  ['Seagulls are what biologists call kleptoparasites',
#   ' animals that rob the food'],
#  ['The last rat catcher of India is a man named Eranna', ' who lives in the'],
#  ['The company',
#   ' VanMoof',
#   ' is a Dutch bike company that ships bikes to customers in the'],
#  ['Bill Ca', ' Veteran New York Times TV Reporter', ' Taking Buyout', ' '],
#  ['San Francisco and Los Angeles account for more than 1/3 of all electric car sales in the country'],
#  ['Yes',
#   ' you can. You can pick the sauce with the most salt.',
#   ' Yes',
#   ' you'],
#  ['The video is from Turkey',
#   ' and the title is a bit misleading. The title i'],
#  ['Ballistic: Ecks vs. Sever (2002) might be the worst movie ever ma'],
#  ['1. Take a hike', ' 2. Grow your idea', ' 3. Get unlost'],
#  ['I think the answer is that the video is a fake. The video is a par'],
#  ['Platinum is the worlds third-most traded metal',
#   ' and there is a lot less of'],
#  ['N'],
#  ['UConn Faculty and Students Challenge University Over Many Missteps Handling Sexual Assaul'],
#  ['The Brutal Truth About Those Pyramid Schemes',
#   ' The Brutal Truth About Those P'],
#  ['Saying thank you and sending thank you cards makes you appear to have more interpersonal'],
#  ['Patrick Fugit', ' I think the answer is', ' Patrick Fugit', ' Reason'],
#  ['Payroll taxes are the biggest tax you pay. No one talks about it.',
#   ' The answer'],
#  ['Google Auto',
#   ' The company registered Google Auto LLC',
#   ' in 2011 when it switched from using Toyota Priu'],
#  ['The article is about a couple from Gujarat who have decided to go for family planning after having 17 k'],
#  ['He spots a strange nest made of dryer lint. Then he notices the 3 tail'],
#  ['Detroits infant mortality rate is twice the national averag',
#   ' but mothers there dont stand alone',
#   ' Detroit'],
#  ['The article is a hoax',
#   ' a fake news',
#   ' a propaganda. The article is a fake new'],
#  ['Yes',
#   ' Disney just pulled off something theyve never done before in Finding Dory. They just'],
#  ['H', ' Cocaine', ' Nicotine', ' Alcohol', ' and Barbiturates'],
#  ['The Big Mac Index',
#   ' which compares the price of a Big Mac in different countries',
#   ' is a'],
#  ['Jared Polis Challenged To Energy Debate By Colorado Oil And Gas Association President',
#   ' I'],
#  ['On the contrary',
#   ' say experts. According to statistics',
#   ' 2016 is shaping out to be one of'],
#  ['1. Your relationship difficulties',
#   ' 2. Your detailed financial state -- or financial problems',
#   ' 3.'],
#  ['1. Give them an IOU that youll make them their fave breakfast whenever they want! Pa'],
#  ['You can get the new $35',
#   ' 000 Tesla Model 3 by preordering it on March 31'],
#  ['She is playing multiple characters in the show.'],
#  ['Thieves can steal your smartphone PIN code in SECONDS using thermal cameras (and Android us'],
#  ['Freaking Insane',
#   ' I think the answer is',
#   ' Insane',
#   ' Because',
#   ' The title'],
#  ['N',
#   ' you dont have to fast before a cholesterol test. The article says that fasting may provide'],
#  ['The Batman game will be released in this summer and The Walking Dea',
#   ' Season 3 will release in the'],
#  ['Penny Hardaway was an NBA megasta',
#   ' but you cant imagine what hes doing now!'],
#  ['The surprising thing that may change about your vision when you get older is that the risk of abnormal col'],
#  ['Quentin Tarantino Thinks This Role Is the Best Character He’s Ever Written',
#   ' The answer'],
#  ['21 Baby Names Voted The Worst of 2016... So Far', ' The answer i'],
#  ['Zero.',
#   ' The answer is zero.',
#   ' The article you linked to says',
#   ' There have so far'],
#  ['The big surprise was that the cats were not orphaned at all. They were just pretending'],
#  ['N',
#   ' Daredevil will not be recast. Charlie Cox will reprise his role as Matt Mur'],
#  ['Naomi Watts'],
#  ['The number of text messages teens send each day is outrageous',
#   ' I think the answer i'],
#  ['The morning-after pill is a form of emergency contraception that can prevent pregnancy when taken af'],
#  ['The UK is not part of the EU',
#   ' so the EU funding will not be available. However'],
#  ['VISA and MasterCard are the two most popular credit card brands in the world. They are both'],
#  ['Fish and chips',
#   ' The answer is Fish and chips are disappearing from pub and restaurant menu'],
#  ['Paul McCartney Reveals What Really Split Up the Beatles:',
#   ' Paul McCartney Reveals What'],
#  ['Zosia Mam', ' who plays Shoshanna on HBOs Girls'],
#  ['N',
#   ' its not a time traveler. The camera in the video could be any one of a'],
#  ['23 amazing accidental google searches',
#   ' The answer is',
#   ' 23 amazing accidental google searches',
#   ' Because'],
#  ['Portla',
#   ' Maine',
#   ' voters on Tuesday approved legalizing recreational marijuana for residents 21 and older.'],
#  ['The Turing Phone Cadenza', ' The Turing Phone Cadenza is a'],
#  ['Syracuse University',
#   ' I think the answer is',
#   ' Syracuse University',
#   ' Because'],
#  ['Taylor Momsen strips down to lingerie for @MaximMag',
#   ' I think the answer'],
#  ['Chinese man is as tough as nails',
#   ' literally',
#   ' The answer is',
#   ' Chinese man'],
#  ['Every move you make. Every click you take. Every game you play. Every place you stay'],
#  ['The kids from Stranger Things were tasked with handing out peanut butter and jelly sandwich'],
#  ['N',
#   ' she does not. The claim that she is an editor of a Sharia newspaper is false'],
#  ['Washing', ' D.C.', ' I think the answer is', ' Washington', ' D.C.'],
#  ['You will have to make a decision about whether you will ask what she already knows. If you'],
#  ['Duterte plans to ‘SHOOT and KILL’ these people; find out who they a'],
#  ['Max and Scott are the two characters in the Street Fighter 2 intro video.'],
#  ['The result is so much fun!',
#   ' I think the answer is',
#   ' The result is so much'],
#  ['The missionary told her that the babies in the orphanage do not cry because they were sl'],
#  ['Sony has denied mod support for Fallout 4 on the PS4',
#   ' but it has allowed mod'],
#  ['Goldie Hawn thinks she has something to teach business leaders and shes right',
#   ' I think'],
#  ['Yes',
#   ' but it will take time.',
#   ' Yes',
#   ' but it will take time.',
#   ' The article'],
#  ['N', ' it does not.'],
#  ['The theory is that Rey is the granddaughter of Emperor Palpatine. The theory'],
#  ['Steve didnt leave to go to college. He didnt die in a car accident and wasnt a'],
#  ['The study',
#   ' believed to be the first of its kind',
#   ' was conducted by researchers at Bowling'],
#  ['Yogurt is a natural moisturizer. It contains lactic a', ' which helps to'],
#  ['The 57 is there to make it easier to get the ketchup out of th'],
#  ['£4'],
#  ['1. Stop drinking so much damn juice. Su',
#   ' some small percentage of what youre drinking probably'],
#  ['Its off the market! @MariahCarey and @NickCannon sell Bel-A'],
#  ['California',
#   ' New York',
#   ' Washington',
#   ' Connecticut',
#   ' Iowa',
#   ' Maine',
#   ' Massachusetts',
#   ' Minnesota',
#   ' Rhode Island'],
#  ['The baby was abandoned in a fiel',
#   ' and the umbilical cord was still attached. The'],
#  ['N', ' they have not been sexting.', ' No', ' they have not been sexting.'],
#  ['M&amp;Ms Mega', ' I think the answer is', ' M&Ms Mega', ' Reason'],
#  ['She hollowed out a baked potato and made it into this awesome meal.',
#   ' The answer'],
#  ['LaCroix is a sparkling water brand that has been around for over 30 years. Bu'],
#  ['Donald Trump',
#   ' I think the answer is',
#   ' Donald Trump',
#   ' Because',
#   ' The first line'],
#  ['Wi-Fi stands for nothing.'],
#  ['The NES Classic Edition doesnt support downloadable or physical add-ons because it isnt meant for v'],
#  ['Guaranteed Rate Field', ' The answer is', ' Guaranteed Rate Field'],
#  ['Justice League: Gods Among Us',
#   ' The title is Justice League: Gods Among U'],
#  ['6 miles',
#   ' I think the answer is',
#   ' 6 miles',
#   ' Because',
#   ' The density of'],
#  ['A recent Boston University School of Medicine study found that women who are able to have children la'],
#  ['The average person lasts in bed for 19 minutes.',
#   ' The answer is',
#   ' 19 minute'],
#  ['Something was spotted on Trumps head during press conference - and it explains his hair'],
#  ['The tea seller is Kishore Bhaiyawala', ' who is a resident of Surat. He'],
#  ['Lady Gaga',
#   ' The picture hints at Lady Gagas later musical success as shes sitting'],
#  ['Kendall Jenner is trying out a new look',
#   ' I think the answer is',
#   ' Kendall'],
#  ['Moes Southwest Grill has unseated Chipotle as fast casual Mexican restaurant B'],
#  ['The new series of Top Gear is as entertaining as ever',
#   ' according to an early review'],
#  ['The Manchester United manager was known for his strict rules on the pitch',
#   ' but one rule in particular'],
#  ['1. When youve misplaced your charging block',
#   ' plugging into a computer seems like an obviou'],
#  ['Barenaked Ladies cancels show at SeaWorld after watching documentary',
#   ' I think the answer i'],
#  ['How do fish swim in schools? Scientists say its in their genes',
#   ' The answer i'],
#  ['The milk and coke react to each other in this way because the phosphoric acid molecules in C'],
#  ['Apparently were in serious denial about our weight',
#   ' The answer is',
#   ' Apparently were in'],
#  ['Seoul',
#   ' South Korea',
#   ' I think the answer is Seoul',
#   ' South Korea. The reason i'],
#  ['This news about chicken nuggets is truly disturbing',
#   ' This is a very interesting question',
#   ' '],
#  ['Men Are Afraid to Take Parental Leave. Guess Why:', ' Men Are Afraid'],
#  ['The flight attendant was concerned that the woman was not aware of the situation and that she would b'],
#  ['Netflix series ending sooner than expected?',
#   ' The article is about the show House of Card'],
#  ['Anna Gunn is following up her Mindy Project guest role and sticking in the Fox family'],
#  ['WATCH: Country star delivers EPIC slam to Westboro Baptist Church'],
#  ['Yes', ' GTA 6 is going to be released this year.', ' Yes', ' GTA'],
#  ['Put the dongle in your pocket.', ' The answer is', ' Put the dongle in'],
#  ['Francis and the Lights', ' Broods', ' Sampha', ' Radiohead', ' DJ Snake'],
#  ['VIDEO',
#   ' GTA 5 Redux has a release date',
#   ' and what has been done to the game'],
#  ['U.K. train operator CrossCountry recently came under fire when a company employee allegedly refused to sea'],
#  ['A Major Musician Keeps Trying To Be On The Walking Dead',
#   ' The Walking Dead'],
#  ['The woman in the video is a thief. She is stealing packages from a strangers home.'],
#  ['The article states that the game could have made billions more if it had been able to capitaliz'],
#  ['Actress blames her new Blackberry for accidental topless tweet',
#   ' The answer is',
#   ' Al'],
#  ['Samsungs VR strategy is to partner with Oculus',
#   ' and to use the Gear VR a'],
#  ['This is the scariest sentence you will ever read about the Internet:',
#   ' This is the'],
#  ['N',
#   ' we should not wipe mosquitoes off the face of the Earth. The mosquito is a very'],
#  ['Hot Summer Nights',
#   ' one of the most exciting new films at the South by Southwest Film Festival'],
#  ['I have a friend who talks in his sleep. He says things like', ' Dont'],
#  ['The students were appalled at the vandalism. They were not going to be sil'],
#  ['The most dangerous drug in the world is the one that is most likely to kill you. Th'],
#  ['The fossil was the shell of an ancient glyptodon. As paleontologist Alejandro Kramarz of'],
#  ['Labrador retriever',
#   ' The article is about the popularity of purebred dogs.'],
#  ['He wore a cap and gown and sat in the front row during the ceremony.'],
#  ['Phoebe was a meth addict and the show was her hallucinations. She was a homel'],
#  ['Britney Spears Threatens to Sue Tabloid: Find Out Why! - The Hollyw'],
#  ['Finally! Google Maps fixes its most annoying feature',
#   ' The answer is the bolded part. The'],
#  ['The article says that you can put an extra $6',
#   ' 000 a year into an employer-spon'],
#  ['1. Accenture (ACN)', ' 2. Caterpillar (CAT)', ' 3. U'],
#  ['.twitter.com/8zZz0qJ8z1 — The Daily Show ('],
#  ['I was in the elevator with my dog and I was so scared. I was alone in th'],
#  ['The Edge is a perfectly adequate SUV – it neither disappoints nor excels in any particular area.'],
#  ['The tip was a 0% tip.', ' The answer is', ' 0%', ' The'],
#  ['Simon Cowell has chosen his panel for the new series THE X Factor 2016 judges have been confirm'],
#  ['Portland Trailblazers', ' The answer is', ' Portland Trailblazers'],
#  ['1. Scarlett Johansson 2. Chris Evans 2. Robert Downey', ' Jr.'],
#  ['Scientists have explained the most annoying thing about food',
#   ' The answer is',
#   ' Scientists have'],
#  ['The most overrated sex position is missionary.',
#   ' I think the most overrated sex'],
#  ['Bobby Moynihan',
#   ' The answer is',
#   ' Bobby Moynihan',
#   ' Because',
#   ' The title'],
#  ['Money is the leading cause of stress in relationships',
#   ' I think the answer is',
#   ' Money i'],
#  ['Extravers', ' Agreeableness', ' and Conscientiousness', ' Extraversion:'],
#  ['The answer is the word never. The word never is the only word tha'],
#  ['Google',
#   ' I think the answer is',
#   ' Google',
#   ' The first article is about'],
#  [''],
#  ['This will prove to you that age is just a number. :D #fitnessmotiva'],
#  ['The article states that the hurricane was well off the East Coast. The article also states that th'],
#  [''],
#  ['N',
#   ' you dont. The study that the underwear is based on is not good science. The'],
#  ['Mike Gatto',
#   ' The answer is Mike Gatto.',
#   ' The article is about a bill that'],
#  ['The Panthers will win Super Bowl 50', ' according to Madden 2016'],
#  ['Mary Lou Bruner lost her bid for the Texas State Board of Education.',
#   ' I think the'],
#  ['Cancer',
#   ' The health condition that concerns Americans most is cancer',
#   ' The health condition that concerns American'],
#  ['The 1 quality we often mistake for weakness can actually make you stronger',
#   ' I think the answer'],
#  ['The FDA has released an official warning to dog owners on the dangers of xylitol'],
#  ['57 percent of people in a landmark survey released last week have no clue where the Grand Canyon is loca'],
#  ['Washington National Cathedral',
#   ' Washington',
#   ' DC',
#   ' The answer is',
#   ' Washington National Cathedral',
#   ' Washington',
#   ' '],
#  ['Amherst College is being sued for $2 million in damages by a former student who claims he wa'],
#  ['Adam Sandler', ' I think the'],
#  ['She Lays A Stick Of Cheese On Dough. Watch What Happens When Sh'],
#  ['N',
#   ' Kelly Mantle is not double dipping. She is eligible for an Oscar in both male'],
#  ['The FBI arrested a man for doing something horrible at the Whole Foods salad bar.',
#   ' The FBI'],
#  ['The worlds largest volcano lurks beneath the Pacific Ocea',
#   ' researchers announced today (Sept. 5)'],
#  ['They went to Charles',
#   ' S.C.',
#   ' and Savannah',
#   ' Ga.',
#   ' and had lunch at'],
#  ['Jesus was gay.'],
#  ['Go outside on Sunday night after sunset and look up.',
#   ' The answer is',
#   ' Go outside'],
#  ['The Internet',
#   ' The Internet is the most disruptive technology over the next 5 years',
#   ' The'],
#  ['University of Colorado Boulder',
#   ' The answer is University of Colorado Boulder.',
#   ' The title of'],
#  ['He has been using the fan money to purchase goods at the prison commissary and probably paying f'],
#  ['He is using Twitter in the worst way. He is using Twitter to promote his books. H'],
#  ['The Glens shot-stopper JC (John-Charles) Hutchison and his wife Emma hav'],
#  ['I wanted the holy grail: Legal weed. After the Districts law legalizing possession of'],
#  ['Astronomers tally HOW MANY alien worlds beyond our solar system?',
#   ' The article i'],
#  ['The Fizzics mach',
#   ' which is about the size of a small kitchen appliance',
#   ' produce'],
#  ['Subaru', ' Audi', ' Toyota', ' Mazda', ' Lexus', ' Fiat', ' The answer i'],
#  ['Yes', ' I can relate. I have a son who is a freshman in college. He i'],
#  ['Usain Bolt kept a secret from everyone and his feats at the Rio Olympics just became more impressiv'],
#  ['He got his tongue stuck on the pole. He tried to get it off',
#   ' but it wouldnt'],
#  ['Purring is a sound that cats make when they are happy',
#   ' relaxed',
#   ' or content. It'],
#  ['I think the answer is', ' She was wearing a thong', ' The article'],
#  ['On Thursday',
#   ' Adrienne Maloof and Paul Nassif released a joint statement proclaiming'],
#  ['No.'],
#  ['The video is a speedrun of Fallout 4',
#   ' which is a game that takes about 100'],
#  ['a cold spell',
#   ' Scientists have finally solved the mystery of why the Mongol hordes never conquered'],
#  ['Badass', ' I think the answer is', ' Shailene Woodley'],
#  ['10 great pop songs from March you mightve missed',
#   ' I think the answer is'],
#  ['Step 1: Get more sleep',
#   ' Step 2: Avoid electronic devices in the bedroom',
#   ' Step 3: Drink'],
#  ['A judge reveals some simple advice if you ever loan someone money',
#   ' The answer is',
#   ' A'],
#  ['The reason Mark Zuckerberg has taped over his laptop camera is because he is paranoid about hack'],
#  ['The answer is to follow your passion. The author is saying that you should follow your pass'],
#  ['The ferrite bead is a small cylinder that sits on the end of your laptop charger.'],
#  ['The order says the company must pump the water from the area of the lake that is in th'],
#  ['Larry Emdur',
#   ' I think the answer is',
#   ' Larry Emdur',
#   ' Because',
#   ' The first'],
#  ['The last time the global monthly temperature was below average was February 1985',
#   ' The answer is'],
#  ['Description: The ice is disappearing.'],
#  ['Gravity',
#   ' The movie James Cameron calls the best space film ever done',
#   ' Gravity',
#   ' Reason'],
#  ['Store it in the refrigerator',
#   ' The easiest way to extend the life of your makeup i'],
#  ['ChickMagnet4Lyfe', ' I think the answer is yes', ' but I'],
#  ['Mississippi',
#   ' The most unhealthy state is Mississippi',
#   ' Because',
#   ' The most unhealthy'],
#  ['Heart disease', ' The disease that kills one woman a minute in the U.S. i'],
#  ['Teslas new long-term manifes',
#   ' signaling the start of the companys new direction for the next'],
#  ['The skeletons were found in a burial site in the village of Staryi Tarta'],
#  ['Melanoma',
#   ' The answer is Melanoma.',
#   ' The article is about a study that'],
#  ['Britney Spears new single Work Bitch leaked this weekend. Spears has b'],
#  ['23 products everyone who hates everyone needs to own',
#   ' I think the answer is'],
#  ['Internet pornography is a pervasive and wide reaching technology',
#   ' growing at a breathtaking rate'],
#  ['The side effect is that it makes you unable to empathize with others pain.'],
#  ['Media proves in the tank for Hillary Clinton',
#   ' I think the answer is',
#   ' Media prove'],
#  ['Wonder if youre smart? These 5 signs can prov',
#   ' according to science.',
#   ' The answer'],
#  ['The Wall Street Journals Christopher Mims baited a hook on Monday',
#   ' dangled it in front'],
#  ['The Emmy campaign is just the beginning. Breaking Bad is gearing up for a'],
#  ['Man Risks His Life By Lying Flat On Railway Track. What Happened Next Will Bl'],
#  ['The article says that mice flown aboard the space shuttle Atlantis returned to Earth with the early signs of'],
#  ['The article says that you should point the antenna u',
#   ' but I dont know if this is true'],
#  ['The problem is that Elon Musk is the CEO of Tesla',
#   ' and he doesnt want to sell.'],
#  ['The most murderous mammal is probably not what you think it is. A new study ha'],
#  ['Washington',
#   ' I think the answer is',
#   ' Washington',
#   ' The article title is Washington'],
#  ['Singapore to New York (10',
#   ' 252 miles)',
#   ' Perth to London (9',
#   ' 008 miles)'],
#  ['Spirit Airlines',
#   ' I think the answer is Spirit Airlines',
#   ' because they are the only one that'],
#  ['What @Oprah no longer worries about now that shes 60:', ' What @Oprah no'],
#  ['Houston is set to pass Chicago as the 3rd largest in the U.S.'],
#  ['Yes', ' it is.'],
#  ['The answer is that the 6 systems will get rid of Wi-Fi dead spots in your house.'],
#  ['This step of Manohar Parrikar is women empowerment in true sense - The Frustra'],
#  [''],
#  ['Guess Which New Title People Really Want To Play On PC',
#   ' The answer is',
#   ' Red'],
#  ['Texting and talking on cell phones',
#   ' The answer is',
#   ' Texting and talking on cell'],
#  ['Taylor Swifts 1989 album just did something that the music business hasnt seen for 14 years'],
#  ['Orange Is The New Black Season 2 will premiere on Netflix on June 6',
#   ' 2015.',
#   ' I'],
#  ['According to scientists',
#   ' all blue-eyed people of the world share this one thing in common.'],
#  ['The bomb squad was later invited to carry out a controlled explosion after which they found out what th'],
#  ['Wine',
#   ' I think the answer is',
#   ' Wine',
#   ' Heres one thing we never thought would be'],
#  ['Scientists say men with one intriguing characteristic are more attractive to women',
#   ' I think'],
#  ['The Warriors are No. 1.',
#   ' The answer is',
#   ' The Golden State Warriors',
#   ' Because'],
#  ['Menopause', ' but it can be'],
#  ['Daily Meditation for Success: Do This First Thing Every Morning',
#   ' I think the answer i'],
#  ['I think the answer is that the statement is not true. The article is about a'],
#  ['You should do whatever you want with your body',
#   ' Statement to be answered: Chelsea Handler Admit'],
#  ['I think she is a masochist. She is a masochist because she is promoting h'],
#  ['a music video by OK Go and a load of literature.'],
#  ['Narendra Modi', ' the superstar has a huge fan following on twitter'],
#  ['Titanium',
#   ' The man with a titanium chest',
#   ' Titanium',
#   ' After seven years with part'],
#  ['A drop.', ' The sun is a star', ' and stars are not on fire. They are'],
#  ['Your passport is valid for six months after the date of issue. If you are traveling within six'],
#  ['(...and the worst customers are the younger ones who Google how to disable a burgla'],
#  ['Listening',
#   ' Nonverbal communication',
#   ' Saying thank you',
#   ' Being a good communicator'],
#  ['The population in Russia and the former USSR as a whole is older than that of the worl'],
#  ['The bacteria that causes this infection is found in the mouths of up to 74 percent of dog'],
#  ['Dr Nelu is a paediatric doctor who is passionate about kids’ health and aim'],
#  ['The first few hack releases earned modest attention—roughly 1',
#   ' 000 downloads apiece',
#   ' according'],
#  ['The article states that the ability to navigate long distances has long been shrouded in mystery.'],
#  ['Robert Schwentke'],
#  ['Mary Landrieus husband brokered real estate deals for lobbyists',
#   ' campaign donors'],
#  ['The reason is predominantly to do with social class because everything in British society is to do with social'],
#  ['The chances of being struck by lightning are about 1 in a million. What exactly is lightning a'],
#  ['She paid $10',
#   ' 000 to look like a Disney princess.',
#   ' The answer is',
#   ' She'],
#  ['The best TV show of every year since 2000',
#   ' according to critics',
#   ' You can use'],
#  ['Every three wears',
#   ' and never in a row.',
#   ' The article is a bit misleading.'],
#  ['She glues coins on the bottom of her daughter’s shoes for a brilliant reason! Something'],
#  ['Pope Francis racked up yet another magazine cover with his appearance on the front of iconic rock magaz'],
#  ['The article says that there’s an iOS 10 update coming on September 30th and at leas'],
#  ['The villain of Iron Man 3 was gender-swapped for a reason you wont believe.'],
#  ['The crew of this flight did the sweetest thing for the grandmother of one of the Orlando shooting victim'],
#  ['The answer is to use the word cool in the title. The word cool'],
#  ['Jane Addams',
#   ' Hull House founder',
#   ' social activist and Nobel Prize winner Jane Addams was celebrated in'],
#  ['The S is a Moebius strip.'],
#  ['1. To quickly assess an item’s quality',
#   ' hold the fabric up to a bright light.'],
#  ['Nev',
#   ' ever brush in the morning. For one thing it leads to frizz',
#   ' and second'],
#  ['Yes', ' there are. The article lists a few', ' but there are many more.'],
#  ['A leather jacket',
#   ' I think the answer is',
#   ' A tie',
#   ' Because',
#   ' The article i'],
#  ['Britain and the United States are leading the global economic recovery',
#   ' The answer is Britain and the'],
#  ['Yes',
#   ' but the number of possible outcomes grows too rapidly compared to the rate that the number of possible'],
#  ['They are all one name celebrities.'],
#  ['The article says that the academy will pay $10 per statuette.',
#   ' The answer is $10',
#   ' '],
#  ['1. To record Kermit singing Rainbow Connection in the swamp for 1979’'],
#  ['Amitabh Bachcha',
#   ' Salman Khan and Akshay Kumar',
#   ' The answer is',
#   ' Amit'],
#  ['25',
# ...
#  ['The article is about a mother who took a photo of her daughter standing on a toilet and s'],
#  ['Warby Park',
#   ' Apple',
#   ' Alibaba Group',
#   ' Google',
#   ' Instagram',
#   ' Color of Change',
#   ' HBO'],
#  ['She cuts her window blinds with some scissors. The end result is simply stunning'],
#  ['Canada is a country that is very much like the United States. It has a population of ov'],
#  ['The trailer is a boat trailer.'],
#  ['Mary J. Bliges fath', ' Thomas Blige', ' was stabbed in the neck by'],
#  ['The iconic red lifeguard swimsuits made famous by Pamela Anderson and co',
#   ' What'],
#  ['and I can tell you that I have'],
#  ['Water mixed with honey and lemon',
#   ' The answer is',
#   ' Water mixed with honey and lemon'],
#  ['Player spends 9 years leveling up to pass through secret door in game',
#   ' The answer'],
#  ['Jimmy Butler wants to remain in Chicago for the long haul and would also like to see the team pick'],
#  ['$350', ' I think the answer is', ' $350', ' Because', ' The breakdown:'],
#  ['The investigators claimed to have got clinching evidence against them and based on which they wa'],
#  ['The IRS spent $10', ' 000 on this parody of The Apprentice'],
#  ['Yes', ' watermelon is good for you. It is rich in nutrients like lycopene'],
#  ['Emma',
#   ' 29',
#   ' festival booker',
#   ' meets Eddie',
#   ' 29',
#   ' plumber What were you hoping'],
#  ['Netflix Acquires Streaming Rights to Highly Praised Documentary',
#   ' The answer is Netflix'],
#  ['The day before yesterday I sat in the gallery of the California Senate and saw something that just a few'],
#  ['— Third Metric (@'],
#  ['Netanyahu Walks to U.N. Podium', ' Hits Audience Epic With 2-Word'],
#  ['Nvidia', ' Nvidia is a company that makes graphics processing units (GPU'],
#  ['The puppy is a coyote.'],
#  ['Kohl’s unusual plan for Christmas is to stay open for 107 hours straight before Christmas.'],
#  ['The script is a fake. The Star Wars Twitter account has confirmed that the leaked s'],
#  ['The answer is no. The article is talking about the brains ability to map numbers',
#   ' not'],
#  ['Kristin Cavallari was arrested in Illinois for driving with a California license.'],
#  ['She’s dressed as a Ghostbuster.'],
#  ['Scarlett Johansson like youve never seen her before',
#   ' I think the answer is'],
#  ['Americans are eating more meals at hom',
#   ' which is hurting McDonalds.',
#   ' The answer is'],
#  ['We asked the filmmakers if the couple depicted onscreen is indeed a lesbian couple. They neith'],
#  ['Description: DeAng'],
#  ['The answer is',
#   ' The Democrats are not going to nominate Hillary Clinton for president in'],
#  ['The transmissions',
#   ' broadcast by the C-Span network',
#   ' technically break House rules',
#   ' but one Democrat'],
#  ['As if we didnt love beer and sandwiches enough.',
#   ' I think the answer is',
#   ' As if'],
#  ['The answer is',
#   ' Michael Douglas',
#   ' Because',
#   ' The tattoo is a picture of Michael'],
#  ['The Senate confirmed Keith Harper as ambassador to the United Nations Human Rights Council Tuesday',
#   ' making him the first'],
#  ['The water in the hose was at least 150 degrees Fahrenh',
#   ' which is hot enough to cause second'],
#  ['1. Window Coverings', ' 2. Linens and Towels', ' 3. Uphol'],
#  ['Christian Lunsf',
#   ' son of alleged mugger',
#   ' returns stolen money to victim',
#   ' gets a nice'],
#  ['Europeans do this so much better than us because they have more money and they can afford to buy'],
#  ['Elite Dangerous: Horizons Xbox One Release Date Announced',
#   ' The answer is in'],
#  ['Apple Makes Big iPhone Announcement And Its Bad News For Rivals',
#   ' The answer'],
#  ['A vibrator', ' The answer is', ' A vibrator', ' The first'],
#  ['N',
#   ' it doesnt. The article is about the new study that reveals that the apps users are'],
#  ['N',
#   ' it is not true. The article says that the synchronisation of periods is a popular belief'],
#  ['Yes',
#   ' he has seen the trailer.',
#   ' Yes',
#   ' he has seen the trailer.',
#   ' From'],
#  ['Busy', ' I think the answer is', ' Busy', ' Because', ' The word busy i'],
#  ['The article is a news report about North Koreas latest threat to the United States. The articl'],
#  ['Old Navy Under Fire For Offensive Fathers Day T-Shirt', ' I'],
#  [''],
#  ['The Apple Watch is a beta product. It is a beta product because it is a new produ'],
#  ['Sick days are a thing of the past. In fa',
#   ' many companies are getting rid of'],
#  ['Ask This One Question to Get Past Awkward Small Talk and Make a Real Connection'],
#  ['A cool blue',
#   ' I think the answer is a bit more complicated than that. The color'],
#  ['He has been busy doing voice work for video games',
#   ' animated films',
#   ' and cartoons',
#   ' which'],
#  ['N',
#   ' but it is a new technique that has not been tested on a large scale.'],
#  ['Scientists have found a human protein that blocks Zika virus replication and prevents brain cell death',
#   ' Answer'],
#  ['Indulgent f',
#   ' drinks',
#   ' parties',
#   ' travelling and presents make Christmas an expensive time of year'],
#  ['Hong Kong', ' The city that may soon lose its skyskraper crown'],
#  ['The sites comeback has been fraught with problems from the get-go. In the days bef'],
#  ['George Clooney is a pretty great movie star who also happened to be a pretty bad Batman.'],
#  ['Cats are natural predators',
#   ' and they have a tendency to practice their hunting skills. They'],
#  ['The song is called Discovery of the Camp and is featured in the TV show Band of Broth'],
#  ['Youre not going to like the latest changes coming to Instagram. The companys director of business opera'],
#  ['A Shockingly Easy Way to Avoid Wasting Thousands of Gallons of Water a Yea'],
#  ['Bill Clinton never expected to get this disease!',
#   ' The answer is',
#   ' Bill Clinton never expected'],
#  ['Anne Hathaway is a very talented actress',
#   ' but she is also very annoying. She'],
#  ['Gillian Anderson',
#   ' The answer is Gillian Anderson',
#   ' the actress who played'],
#  ['The Michigan Attorney Generals office has released a statement in response to the Michigan Supreme Courts ruling tha'],
#  ['Yes',
#   ' it could limit mass animal extinctions.',
#   ' The article is a bit misleading.'],
#  ['Chick Fil A did what after the gay club shooting? They gave out free food to the peopl'],
#  ['Yes',
#   ' he is a racist.',
#   ' I think the question is a bit too broad',
#   ' but'],
#  ['The video in question contains footage of his landlord calling him a fagg',
#   '  which'],
#  ['Summaries that are way too long; overused résumé jargon; and appearing too formal'],
#  ['The statement is false. The dispensaries are not losing money. They are operating at a l'],
#  ['Dont let your spouse be your everything. No one person can be your everything. N'],
#  ['Mark Zuckerberg has 5 bodyguards when he goes jogging.', ' The answer is'],
#  ['September 11',
#   ' 2016',
#   ' I think the answer is',
#   ' September 11',
#   ' 2016',
#   ' Because'],
#  ['The reason why Zlatan Ibrahimovic has delayed Manchester United move is because he wants to get a larg'],
#  ['@TheEllenShow gives a grateful formerly homeless man check for huge amount',
#   ' The'],
#  ['N', ' she doesnt hate water. She just doesnt like it.'],
#  ['Farrah Abraham', ' I think the answer is', ' Farrah Abraham', ' The'],
#  ['Kevin James would be a bat boy for the Mets',
#   ' The answer is',
#   ' Kevin Jame'],
#  ['Rachel McAdams favorite Mean Girls quote is not trying to make fetch happen'],
#  ['Michelle Obamas movie request might surprise you',
#   ' I think the answer is',
#   ' Michelle Obama'],
#  ['1. Apple', ' 2. Google', ' 3. Amazon', ' 4. Microsoft', ' 5. Samsung'],
#  ['Yes', ' you can sue your employer for excessive business travel.'],
#  ['Singapore beats NYC Paris for this distinction',
#   ' I think the answer is',
#   ' Singapore beats NY'],
#  ['Yes! In fa',
#   ' North America',
#   ' including United States',
#   ' Canada',
#   ' Mexico',
#   ' and Greenland',
#   ' could'],
#  ['The man on the other end of the ph',
#   ' who calls himself Kevin Smith',
#   ' ask'],
#  ['They were expecting triplets. But the girl was having her oxygen supply cut off by the tw'],
#  ['The Tesla Model Ss Summon feature is in beta (development) m', ' so it'],
#  ['Netherlands',
#   ' The Netherlands has the most plentiful',
#   ' healthy food: Oxfam',
#   ' The'],
#  ['The weather',
#   ' The article says that the showrunners are delaying the season'],
#  ['Hawaii',
#   ' The healthiest state in America is...',
#   ' Hawaii',
#   ' Because...',
#   ' The state of Hawaii'],
#  ['The Samsung Galaxy Note 7 is a phone to be reckoned with. Howev',
#   ' it was yet'],
#  [''],
#  ['Universitys alumni freak out over attempt to force them into a new social network',
#   ' I'],
#  ['Fuck you',
#   ' I think the answer is',
#   ' Fuck you',
#   ' Because',
#   ' The article is about'],
#  [''],
#  ['Microsoft',
#   ' The answer is',
#   ' Microsoft',
#   ' Because',
#   ' The title of the article is Apple reveal'],
#  ['The survey results suggest that people are more likely to sacrifice the lives of pedestrians than their ow'],
#  ['Ugg boots',
#   ' The answer is',
#   ' Ugg boots',
#   ' Because',
#   ' The top trending'],
#  ['Love saves us all.',
#   ' The answer is',
#   ' Love saves us all.',
#   ' The reason i'],
#  ['The inductor is a coil of wire', ' and the capacitor is a block of some'],
#  ['Social connections make us happier and healthier while loneliness kills',
#   ' The answer i'],
#  ['Starbucks is testing a new latte you probably want to know about',
#   ' I think the problem'],
#  ['She responded by giving him a dose of his own medicine. Its a familiar tale for many young'],
#  ['The walk of shame is a form of punishment for theft in Indonesia. The punishment is ca'],
#  ['Malala Yousafzai', ' I think the answer is', ' Malala Yousaf'],
#  ['Homework could have an impact on kids health. Should schools ban it? The answer is'],
#  ['Jennifer Lopez',
#   ' Harry Connick Jr.',
#   ' Keith Urban',
#   ' The answer is',
#   ' Jennifer Lopez',
#   ' '],
#  ['Fred Armisen will guest star on House Of Lies',
#   '  Showtimes Golden Globe-n'],
#  ['Lithuania', ' Lithuan'],
#  ['The power of simple life changes to prevent heart disease is that they can be done by any'],
#  ['Yes',
#   ' Meryl Streep was approached to play Susan Boyle in the upcoming biopic about her'],
#  ['N',
#   ' the man killed his wife because she wanted to die.',
#   ' The article is a bit'],
#  ['Mary Shelley was a woman of many talents. She was a w', ' a feminist'],
#  ['People regularly use to have two periods of sleep and do tasks in between',
#   ' Description: Professor Roger Ekirch of Virginia Polytechnic and State University claims people used to have a first sleep and a second sleep and it was a normal practice until the late 1800s.',
#   ' only to wake up in the middle of the night frustratedly unable to get back to sleep. While today this is seen as insomnia',
#   ' until the end of the 19th century people did it on purpose. Well after the Industrial Revolution',
#   ' many people in Britain still swore by the health benefits of a ‘first sleep’ and ‘second sleep’. For centuries',
#   ' according to a sleep historian',
#   ' they would use the time when they woke up at night to do household chores',
#   ' visit friends - or make love to their spouse. Sleeping through the night is by comparison a ‘modern invention’',
#   ' according to Professor Roger Ekirch of Virginia Polytechnic and State University. Speaking yesterday at the Royal Society of Medicine',
#   ' he said: ‘Middle of the night insomnia was a rare problem before the late 1800s. As early as in the 16th century it was utterly normal',
#   ' unworthy of comment.’ Bedtime was historically around 10pm',
#   ' after which',
#   ' he added: ‘Most individuals awakened shortly past midnight to an hour or so of consciousness',
#   ' in which they meditated',
#   ' they conversed and made love - not necessarily in that order. ‘A 16th century physician said making love was better after the first sleep',
#   ' when people have more enjoyment and do it better.’ People used the gap between their first and second sleep to wash clothes',
#   ' have a conversation or even to steal the neighbour’s firewood',
#   ' historical records show. It was thought that lovemaking between the two sleep phases was responsible for large families',
#   ' with labourers able to conceive several children because they waited until after their energy-giving first sleep to do it. It was also thought to aid digestion',
#   ' if people turned from lying on their right to their left when they woke up during the night. References to two phases of sleep go back to Chaucer',
#   ' with a character in The Squire’s Tale',
#   ' in the Canterbury Tales',
#   ' deciding to go back to bed after her ‘firste sleep’. Unless kept awake by a cold house',
#   ' bed bugs or worry',
#   ' most people were unconcerned about getting up in the night. It was not seen as insomnia',
#   ' and ‘sleeplessness’ referred only to failing to fall asleep in the first place. But the practice of having a first and second sleep fell out of favour in the decades following the Industrial Revolution',
#   ' when people increasingly worked long hours as machine manufacturing dominated British industry. The sleep historian said the shift came at the end of the 19th century',
#   ' as the end of the first sleep crept later to around 3am',
#   ' before it was jettisoned altogether. Suddenly sleeping in two phases was seen as inefficient and people were warned that indulging would lead to headaches and constipation. It was even feared that it might',
#   ' in young men and women',
#   ' cause ‘lustful thoughts’. Speaking at a Royal society event in London on the subject of sleep',
#   ' Prof Ekirch said: ‘Sleep represented a necessary evil best confined to a single interval',
#   ' thus allowing someone to steal the march on the day and on one’s fellow human beings who were still enjoying their second sleep.’ As a result',
#   ' today',
#   ' the history professor said',
#   ' many people who wake at night think they are ‘abnormal’. However research suggests this may be a normal sleeping pattern when people are away from artificial lights and the blue light from electronic devices. Prof Erich said: ‘Rather than the product of an implacable disorder',
#   ' their sleep',
#   ' viewed from the high ground of history',
#   ' may just be natural.’',
#   ' Tags: Why',
#   ' waking',
#   ' night',
#   ' natural',
#   ' Why waking up in the night is natural: People regularly use to have two periods of sleep and do tasks in between',
#   ' The article i'],
#  ['The name of the game is to bring autonomous driving to urbanites who dont own cars — and don'],
#  ['Corsica',
#   ' Germany',
#   ' Italy',
#   ' New Zealand',
#   ' and San Francisco',
#   ' The answer'],
#  ['The year 2016 is likely to be the hottest yea', ' according to the Met'],
#  ['She w', ' Oh', ' wonderful! I felt like I wanted to cry. It wa'],
#  ['The body-positive Instagram is going viral for all the right reasons because it is a powerful and inspirational'],
#  ['The answer is', ' The Piano Guys', ' Because', ' The Piano Guy'],
#  ['Theyre cheap. You can get a really great Chromebook for around $200',
#   ' or about one'],
#  ['Cheyenne Jackson is engaged to his boyfriend',
#   ' You can use the following regex:',
#   ' b'],
#  ['This baby starts crying. Watch what the dog does!'],
#  ['Cornell University'],
#  ['Saying done is a simple way to train your brain to be more productive. It crea'],
#  ['Carbonated water is good for you.'],
#  [''],
#  ['The Great Pyramid of Giza is not perfectly squa',
#   ' but it is not lopsided either'],
#  ['Beheadings', ' impalement', ' and smoking', ' I think the answer is'],
#  ['Statement to be answered: Inside our three-month effort to attend Apples iPhone 7 launch party'],
#  ['The SAS sniper shot the leader of the Islamic State conting',
#   ' flanked by several guards with'],
#  ['All Along the Watchtower', ' The song is a cover of a song by'],
#  ['I think the answer is that the article is a satire. The article is written'],
#  ['A blood moon is coming Oct. 8 -- and heres how to see it'],
#  ['Tami Erin', ' I think the answer is', ' Tami Erin', ' Because'],
#  ['I think the answer is celery.']]

# %%
predictions[1]
# Out:
# ['Gwyneth Paltrow\'"', ' "\'I think the answer is\'"', ' "\'Gwyneth Palt']
