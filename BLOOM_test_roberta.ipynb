# %%
import transformers
from transformers import BloomForQuestionAnswering
from transformers import BloomForCausalLM
from transformers import BloomTokenizerFast
import torch

from os.path import exists
from os.path import isdir

# %%
model = BloomForCausalLM.from_pretrained("bigscience/bloom-7b1") #remove -1b7 for whole modelb
tokenizer = BloomTokenizerFast.from_pretrained("bigscience/bloom-7b1")
# Out:
# Downloading:   0%|          | 0.00/734 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/27.5k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.16G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/222 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %%
prompt = "It was a dark and stormy night"
result_length = 50
inputs = tokenizer(prompt, return_tensors="pt") #??

# %%
# Greedy Search
print(tokenizer.decode(model.generate(inputs["input_ids"], 
                       max_length=result_length
                      )[0]))
# Out:
# It was a dark and stormy night, and the wind howled and howled, and the
# storm was so great that the sea was rolling in great waves, and the
# ship was tossing and rolling, and the sea was so rough

# %% [markdown]
# # Load train and validation data

# %%
def error(msg):
    print('  [\033[91mx\033[0m] ' + msg)
    exit(1)

def success(msg):
    print('  [\033[92mo\033[0m] ' + msg)
    
def load_json_lines(f):
    if not exists(f):
        error('The file "' + f + '" does not exist.')

    ret = []
    num = 1
    
    if isdir(f):
        f = glob(f + '/*.json*')
        
        if len(f) != 1:
            error('The input is an directory that contains multiple json files. Please create only a single json file. Got ' + str(f))
        
        f = f[0]
    
    with open(f, 'r') as inp:
        for l in inp:
            try:
                ret += [json.loads(l)]
            except:
                error('Invalid line ' + str(num) + ' in "' + f + '" with content: ' + l.strip())
            num += 1

    success('The file ' + f + ' is in JSONL format.')
    return ret

# %%
train = load_json_lines('train.jsonl')
validation = load_json_lines('validation.jsonl')
test = load_json_lines('input.jsonl')
# Out:
#   [o] The file train.jsonl is in JSONL format.
#   [o] The file validation.jsonl is in JSONL format.
#   [o] The file input.jsonl is in JSONL format.

# %%
#Function for creating prompt from entry

def make_prompt(entry):
    context = ' '.join(entry['targetParagraphs'])
    clickbait = entry['postText'][0]
    prompt = f"Context: {context}\n\nQuestion: {clickbait}\n\nAnswer: "
    
    ##
    
    #if '?' in clickbait:
    #    prompt = f"Context: {context}\n\Question: {clickbait} \n\nAnswer:"  ## Statement version
    #else:
    #    prompt = f"Context: {context}\n\n{clickbait}:"
    return prompt
    
prompt = make_prompt(train[38])
inputs = tokenizer(prompt, return_tensors="pt") #??

# %%
predictions_from_prompts = []
prompts = [make_prompt(x) for x in validation]

for i, prompt in enumerate(prompts):
    print(i,"/",len(prompts))
    inputs = tokenizer(prompt, return_tensors="pt")
    prediction = tokenizer.decode(model.generate(inputs["input_ids"], 
                           max_length=len(inputs['input_ids'][0])+20
                          )[0])
    anchor = prompt[-15:]
    pred = prediction[prediction.find(anchor)+15:].strip('</s>').strip()
    if '\n' in pred:
        #pred = pred.replace('\n', ' ')
        pred = [x for x in pred.split('\n') if len(x)!=0][0]
    predictions_from_prompts.append(pred)
    print('title:',validation[i]['postText'][0],'\nprediction:',pred, '\ntarget:', validation[i]['spoiler'][0], 
          '\nhuman target:',validation[i]['provenance']['humanSpoiler'])
# Out:
# 0 / 800
# title: Five Nights at Freddy’s Sequel Delayed for Weird Reason
# prediction: The game is being delayed because it’s too dark.
# target: some of the plot elements are so disturbing that they are making him feel sick
# human target: They think It's too dark. #StopClickBait
# 1 / 800
# title: Why Arizona Sheriff Joe Arpaio’s fate could hang on a single word
# prediction: The judge found that Arpaio and his aides had engaged in multiple acts of misconduct, di
# target: "intentionally"
# human target: "Intentionally", because it's hard to judge intentionality.
# 2 / 800
# title: Here’s how much you should be tipping your hairdresser
# prediction: The amount you should tip your hairdresser depends on the service you received and the length of time
# target: 20%
# human target: None
# 3 / 800
# title: "Harry Potter" alums reunite for new movie
# prediction: The cast of "Harry Potter" reunites for a new movie.
# target: Alan Rickman & Rupert Grint
# human target: Alan Rickman and Rupert Grint in "CBGB"
# 4 / 800
# title: A man swallowed a microSD card and you won't believe what happened next!
# prediction: The man pooped the card into a pasta strainer and then plugged it into a computer to
# target: a man who swallowed a 64GB microSD card and then pooped it into a strainer
# human target: This shit again  https://t.co/t2TjvTUuGM
# 5 / 800
# title: This popular soda could cure your hangovers scientists say:
# prediction: The study was published in the journal Alcoholism: Clinical and Experimental Research. The researchers found that a
# target: Sprite
# human target: Sprite
# 6 / 800
# title: The anytime snack you won't feel guilty about eating
# prediction: The answer is no.  The reason is that the snack is not healthy.  The snack is not healthy
# target: Smoky Paprika-Baked Garbanzo Beans
# human target: Smoky Paprika-Baked Garbanzo Beans
# 7 / 800
# title: You won't believe this stunning "Harry Potter" revelation about Professor McGonagall
# prediction: Professor McGonagall was originally hired by Dumbledore to teach Defense Against the Dark Arts (DADA)
# target: McGonagall was appointed as Dumbledore’s assistant in 1956, not as his replacement.
# human target: She was hired to teach Defense Against the Dark Arts, but after Tom Riddle cursed the position, Dumbledore moved her to Transfiguration to protect her.
# 8 / 800
# title: J.J. Abrams has an answer on if there will be a post-credits scene in the new 'Star Wars'
# prediction: No, there’s not. All the scenes are actually in the movie.
# target: All the scenes are actually in the movie
# human target: no
# 9 / 800
# title: Kristin Cavallari (@KristinCav) opens up about just how fake "The Hills" was
# prediction: Kristin Cavallari (@KristinCav) opens up about just how fake "The Hill
# target: "I had fake relationships, fake fights. I don't care anymore, I can tell you.
# human target: Very
# 10 / 800
# title: How 1 model prepares for lingerie shoots
# prediction: The model (and daughter of Isabelli Rossellini) is the new face of Agent Provoc
# target: Elettra Wiedemann
# human target: Elettra Wiedemann (@ElettraW); cuts out sugar &amp; exercises
# 11 / 800
# title: Guess who Obama just dined with in Vietnam
# prediction: Anthony Bourdain
# target: Anthony Bourdain
# human target: Anthony Bourdain
# 12 / 800
# title: How This 20-Year-Old Died From Kissing Her Boyfriend
# prediction: The girl had a severe allergy to peanuts, and she was not carrying her Epi
# target: he'd eaten a peanut butter sandwich and wasn't aware of her peanut allergy
# human target: She had a peanut allergy and he had eaten a peanut butter sandwich. #StopClickBait
# 13 / 800
# title: The question former O.J. Simpson prosecutor hates being asked
# prediction: The question former O.J. Simpson prosecutor hates being asked
# target: Marcia Clark
# human target: Does she think he did it? (she does)
# 14 / 800
# title: Hollywood legend's amazing home is on the market
# prediction: The house is currently listed for $5,495,000.
# target: Mitzi Gaynor
# human target: Mitzi Gaynor; in Beverly Hills for $5495000
# 15 / 800
# title: What are mosquito-control workers spraying in Miami?
# prediction: The answer is the insecticide naled, which is used to kill mosquitoes.
# target: Dibrom
# human target: The main ingredient of the insecticide, Dibrom, is the chemical Naled. It works by killing mosquitoes on contact.
# 16 / 800
# title: Do birds fart?
# prediction: No, birds do not fart.
# target: They don’t fart
# human target: No one is sure, but if they do it has no smell. #StopClickBait
# 17 / 800
# title: Angry ex-boyfriend bursts into delivery room, assumes fighting stance and does the most...
# prediction: He kicked the pregnant woman in the chest and was put into a bear hug.
# target: kicked her and got into a fight with her current boyfriend
# human target: Kicks the pregnant woman in the chest. #StopClickBait
# 18 / 800
# title: Local Cops Make SHOCKING Move Against Boy Selling Teddy Bear To Buy Food
# prediction: The Franklin Police Department has been criticized for their handling of the case. The police department has been criticized
# target: Dunham picked the boy up and took him to a Subway to get something to eat. He then took him to the Franklin Police Department.
# human target: they buy him a sandwich from Subway, also file neglect charges against his parents
# 19 / 800
# title: Parents Discover A Secret Hidden In Adoptive Daughter’s Family Tree
# prediction: The DNA test revealed that the girl in the photo was not Aubrey’s biological daughter. Instead
# target: Not only does Aubrey have cerebral palsy, but she was neglected and abused by her biological mother.
# human target: Her little sister was found through Facebook and it was discovered that she also has cerebral palsy.
# 20 / 800
# title: The one morning work mistake you can't recover from
# prediction: The one morning work mistake you can't recover from is the one you make when you don't get up early
# target: starts later
# human target: Arriving later than your coworkers
# 21 / 800
# title: Is It Safe To Take Melatonin Pills To Help You Fall Asleep?
# prediction: Melatonin is a hormone that is naturally produced by the pineal gland in the brain. It
# target: The bottom line: Unfortunately, there's not enough solid research out there on whether melatonin supplements are truly an effective and safe way to get to sleep.
# human target: "Unfortunately, there's not enough solid research out there on whether melatonin supplements are truly an effective and safe way to get to sleep."
# 22 / 800
# title: Why there will probably never be a "Dawson's Creek" reunion
# prediction: The show's creator, Kevin Williamson, said he didn't want to write it and he didn't think it
# target: Kevin Williamson said he didn't want to write it
# human target: The creator doesn't want to write it
# 23 / 800
# title: Mom Is Pregnant With Twins. But 25 Weeks Later, Doctors Drop THIS Bombshell About Her Babies
# prediction: The doctors told Edwyna and TJ that their babies were in a very precarious condition. They
# target: Sophie and Riley were considered "micro-preemies" and suffered a slew of health issues, like chronic lung disease and holes in their hearts.
# human target: No doctor drops any bombshells, she goes into early labor, both twins survive. #StopClickBait
# 24 / 800
# title: Apple iOS 9.3.2 Has A Nasty Surprise
# prediction: iOS 9.3.2 is bricking iPad Pros. ‘Great Features’ and ‘Nasty
# target: bricking iPad Pros
# human target: It bricks iPad Pros. #StopClickBait
# 25 / 800
# title: State rep who likened food stamp recipients to wild animals loses Senate primary
# prediction: Former state Rep. Stacey Nelson (D) lost the Republican primary for the Senate seat vacated
# target: Stace Nelson
# human target: In South Dakota
# 26 / 800
# title: You'll never believe how much these Instagram models make
# prediction: They make a lot of money.
# target: Paige Hathaway – £3.8million
# human target: Around 100K per sponsored post, up to 4 million annually.
# 27 / 800
# title: How distance brought an end to an NBA power couple that withstood conflicts of interest and professional trials:
# prediction: The distance between the two owners was growing, and the two coaches were not able to talk about their
# target: Buss and Jackson announced that they were mutually ending their four-year engagement
# human target: None
# 28 / 800
# title: A Tourist Ignored a Museum's "Please Don't Touch" Sign, Guess What Happened Next
# prediction: The Museum's Clock Crashes Off the Wall
# target: In the video, an abstract, wooden sculpture clock appeared not to be working, so a male tourist decided to take matters into his own hands, pulling on weights and levers for more than 30 seconds before the clock came flying off the wall and into pieces on the floor.
# human target: The piece that he repeatedly touched fell off the wall and broke. #StopClickBait
# 29 / 800
# title: Taco Bell's Newest Menu Item Has One Ridiculous Ingredient That Will Leave You Questioning Everything
# prediction: The Jalapeno Popper Quesarito is a burrito that includes jalapenos and cheese
# target: reduced fat sour cream
# human target: Reduced fat sour cream
# 30 / 800
# title: Rebekah Brooks is back with Rupert Murdoch, and this time it's digital
# prediction: The Wall Street Journal reports that Brooks will be joining News Corp's digital arm, Storyful, a
# target: Brooks would eventually return to a role at News Corp, few expected her to land at Storyful
# human target: She’s going to run @Storyful
# 31 / 800
# title: Your favorite children's book illustrator just got his own exhibition in Chicago
# prediction: Edward Gorey
# target: Edward Gorey
# human target: Edward Gorey
# 32 / 800
# title: Fashion brand lets models go un-Photoshopped and makeup-free
# prediction: The fashion industry is a very competitive industry and it is very difficult to stand out from the crowd.
# target: Rag & Bone
# human target: Rag &amp; Bone (@rag_bone)
# 33 / 800
# title: Jennifer Lawrence cuts off her long hair... and debuts Hollywood's biggest trend
# prediction: No, it's not a trend. It's a style choice.
# target: pixie cut
# human target: Short hair
# 34 / 800
# title: The oven cleaning hacks that will have your appliance sparkling without ANY scrubbing
# prediction: The oven cleaning hacks that will have your appliance sparkling without ANY scrubbing
# target: homemade oven cleaner
# human target: None
# 35 / 800
# title: Lawmakers could do this to fight corruption. But they won’t.
# prediction: The lawmakers are not going to do this to fight corruption. They are going to do this to
# target: In February, when Rep. David Jolly introduced his quixotic plan to ban members of Congress from soliciting campaign contributions, the Florida Republican had only six co-sponsors.
# human target: Ban members of Congress from personally soliciting campaign contributions
# 36 / 800
# title: He Rescued This Bizarre Creature From a Sidewalk, But He Had No Idea What It Would Grow Into
# prediction: A Southern Flying Squirrel
# target: southern flying squirrel
# human target: A Flying Squirrel
# 37 / 800
# title: 29 of the most beautiful TV quotes of all time
# prediction: 1. "You can't live your life according to maybes." – Poussay Washington, Orange I
# target: 1. "You can't live your life according to maybes."
# human target: None
# 38 / 800
# title: Man admires the fence he repaired – now watch what happens just seconds later
# prediction: The man is now in a treehouse with a zip-line for his grandson.
# target: At this point, a large dog -- presumably Stella -- bounds into view, runs to one end of the fence and jumps right over it, almost without effort.
# human target: His dog jumps over the fence easily. #StopClickBait
# 39 / 800
# title: WHOA someone just paid $168000 for THIS
# prediction: The person who paid $168,000 for the cabinet is the person who bought the cabinet.
# target: Hope's antique cabinet
# human target: An antique Japanese cabinet owned by Bob Hope
# 40 / 800
# title: 14 things that’ll happen in 2017 according to "The Simpsons"
# prediction: 1. Some alt-right guy will invent the make-up gun. Homer invented it in the episode "W
# target: 1. Some alt-right guy will invent the make-up gun.
# human target: None
# 41 / 800
# title: I was really bad at sports in high school. This new study helps me understand why.
# prediction: The study is not about sports, but about deliberate practice. The study is about the relationship between deliberate
# target: Some people are just better at sports than others
# human target: Some people are genetically better at sports. #StopClickBait
# 42 / 800
# title: Say it ain't so! Jon Stewart has set his official departure date from #TheDailyShow
# prediction: The Daily Show is not going anywhere. Jon Stewart is not leaving the show. He is just going
# target: August 6th
# human target: August 6th
# 43 / 800
# title: How big is Justin Bieber's dick really?
# prediction: Justin Bieber's dick is average.
# target: perfectly average
# human target: ¯\_(ツ)_/¯
# 44 / 800
# title: One word that should never follow "I love you"
# prediction: I love you.
# target: "but"
# human target: "but"
# 45 / 800
# title: If you've ever dreamed of getting up close and personal with a rocket launch, YOUR TIME IS NOW
# prediction: NASA is offering a 360-degree live stream of the launch of the Atlas V rocket, which
# target: On Tuesday morning, NASA will broadcast its first-ever rocket launch livestream in 360-degree video
# human target: None
# 46 / 800
# title: Three remain from the Class of '98.
#
# All three are legends.
# prediction: I think that we have a chance to win. I think that we have a chance to win.
# target: Vince Carter
# human target: None
# 47 / 800
# title: She Put Baking Soda On Her Toes... And Solved One Of Life’s Most Annoying Problems
# prediction: Baking soda is a great way to get rid of toenail fungus. It is a
# target: Baking soda
# human target: It helps neutralize the acidity of the venom in a bee sting
# 48 / 800
# title: For The First Time In Its 126-Year History, This Newspaper Endorsed A Democrat
# prediction: The Arizona Republic has only endorsed Republican candidates for president in its 126-year history But this year is different
# target: The Arizona Republic
# human target: The Arizona Republic
# 49 / 800
# title: Cancer is contagious among clams. What about us?
# prediction: The answer is that cancer is contagious among humans, but not among clams.
# target: I don’t think we should be starting to panic
# human target: No we are not contagious among clams.
# 50 / 800
# title: 1/3 of Americans believe this about the Syria conflict
# prediction: The Bible does not predict the end of the world. The Bible does not predict Armageddon.
# target: apocalyptic omen
# human target: That it indicates pending armageddon
# 51 / 800
# title: The horrible incident that cut my honeymoon short
# prediction: The honeymoon is the light at the end of the tunnel for many brides and grooms-to
# target: Rudner and her husband rented ATVs. After hitting a speed bump and falling off of the vehicle, her husband shattered his shoulder and Rudner rotated her hip
# human target: ATV accident shattered husband's shoulder
# 52 / 800
# title: This Drug Could Add Five Years To Your Dog’s Life
# prediction: The drug is currently being tested on 32 middle-aged dogs (6-9 years old) for it
# target: rapamycin
# human target: Rapamycin (also called sirolimus) in low doses has slowed aging processes in mice. Testing for the result in dogs is still ongoing and not yet proven. #StopClickBait
# 53 / 800
# title: ANOTHER Catholic university drops abortion coverage
# prediction: Yes, another Catholic university has dropped elective abortion coverage for its staff. In a letter dated Oct
# target: Santa Clara University
# human target: Santa Clara University
# 54 / 800
# title: College president to students: "This is not a day care. This is a university!"
# prediction: This is a university, and it is a day care.
# target: Oklahoma Wesleyan University
# human target: College = Oklahoma Wesleyan University
# 55 / 800
# title: How men can get the bedroom blues too
# prediction: The answer is that men are not as emotionally expressive as women. They are more likely to
# target: The sadness some men feel at this point may be due to the contrast between the joy of arousal and feeling like a superhero and the sensation of the feel-good hormones wearing off.
# human target: None
# 56 / 800
# title: She might be the only author to benefit from the Amazon-Hachette war thanks to Stephen Colbert
# prediction: Yes, she might be the only author to benefit from the Amazon-Hachette war thanks to Stephen
# target: Edan Lepucki
# human target: .@EdanL
# 57 / 800
# title: This NFL Player Slept in a Utility Closet in College to Save Money
# prediction: Tim Masthay, of the Green Bay Packers, and his wife Amanda are the best team
# target: Tim Masthay
# human target: Tim Masthay, punter for the Green Bay Packers
# 58 / 800
# title: Psychedelic drugs are not cocaine — here’s why that matters
# prediction: The answer is that psychedelics are not cocaine.  The difference is that cocaine is a drug
# target: But psychedelics may not be as dangerous and addictive as our society thinks.
# human target: LSD, psilocybin, and MDMA are all placed in schedule I; however, many psychedelic experts agree that these substances are not addictive and have a low potential for abuse. In fact, they may just be the total opposite. #StopClickBait
# 59 / 800
# title: What weighs 2032 pounds is orange and can be seen in New York this week?
# prediction: The world's largest pumpkin.
# target: World's Largest Pumpkin
# human target: World's largest pumpkin
# 60 / 800
# title: You won't BELIEVE how much Paris Hilton dropped on two teeny-tiny dogs!
# prediction: $25K for 2 pounds of dog.
# target: $25K
# human target: $25,000
# 61 / 800
# title: This Guy Put An Ice Cream Cone In His Pocket... Seconds Later, He Was In Handcuffs.
# prediction: The ice cream cone law was passed in the state of Alabama in the early 1900s. It wa
# target: If you find yourself so moved to store ice cream in your back pocket in Alabama, you’ll pay the price, and we don’t just mean a cold rear end.
# human target: Alabama has a law against it. #StopClickBait
# 62 / 800
# title: How to completely banish stress in just THREE MINUTES
# prediction: Close your eyes and breathe in through your nose. Sigh. Count in and out through your nose
# target: close your eyes or simply stare at a fixed point
# human target: None
# 63 / 800
# title: Lawmakers are going to punish university for not shutting down "Sex Week"
# prediction: The lawmakers are going to punish the university for not shutting down "Sex Week" because the
# target: University of Tennessee
# human target: U of Tennessee
# 64 / 800
# title: The reason why this ex-basketball player got arrested will make you MAD!
# prediction: He was arrested for threatening to kill his ex-girlfriend and uploading their sex video online.
# target: Almario
# human target: Former basketball player Alvin Japhet Almario was arrested by the NBI for alleged physical abuse and uploading a sex video of him and his exgirlfriend. #StopClickBait
# 65 / 800
# title: One of the most ‘annoying things’ on the entire planet just turned 20
# prediction: Crazy Frog, the frog that annoyed people all over the world for almost two years, has turned
# target: Crazy Frog
# human target: None
# 66 / 800
# title: Explainer: Is There Any Science Behind Astrology?
# prediction: There is no science behind astrology.
# target: "Although astrologers seek to explain the natural world, they don't usually attempt to critically evaluate whether those explanations are valid — and this is a key part of science."
# human target: Nope. #StopClickBait
# 67 / 800
# title: This Is the First Thing Guys Notice About Women
# prediction: Your Face
# target: face
# human target: Their face
# 68 / 800
# title: The latest Hollywood baby name: Kaius
# prediction: The name is... Kaius Jagger Berman! He'll go by Kai, Zoe announced to
# target: Rachel Zoe Gives Birth To Her Second Baby Boy!
# human target: Kaius Jagger Berman newborn son of Rachel Zoe (@rachelzoe)
# 69 / 800
# title: An unlikely company is crushing America's biggest clothing stores
# prediction: Amazon is crushing America's biggest clothing stores.
# target: Amazon
# human target: It's Amazon
# 70 / 800
# title: Shower Habits You Need To Stop Doing Immediately
# prediction: 1. Washing Your Face Without a doubt, it’s easier and less messy to wash your face when
# target: 1. Washing Your Face
# human target: A 25 item list of super obvious "shower hacks" (such as wash your feet, don't use soap that irritates your skin). Full List in Comments [answers.com]
# 71 / 800
# title: When People Ate People, A Strange Disease Emerged
# prediction: In 1962, a local leader in the Eastern Highlands of Papua New Guinea asks Fore men to stop
# target: kuru
# human target: Tribes that ate Corpses as part of a Funeral Ritual often Contracted a Deadly Sickness similar to Mad Cow Disease called Kuru, with Symptoms Including Loss of Motor and Emotional Control
# 72 / 800
# title: Prevent Your Kids From Playing Near This Dangerous Common Plant That Can Kill Them
# prediction: Dieffenbachia is a common indoor plant that is used to decorate homes. It is also
# target: Dieffenbachia
# human target: Dieffenbachia
# 73 / 800
# title: Are lefties really more creative?
# prediction: No, they are not more creative than righties.
# target: The answer to that is a definitive ... maybe.
# human target: Despite many studies on the subject, scientists have no definitive answer.
# 74 / 800
# title: You Won't Believe What "Unknown Substance" Sent 7 Planned Parenthood Staffers to the Hospital
# prediction: The substance was baby food.
# target: baby food
# human target: Baby Food
# 75 / 800
# title: You'll Never Guess What (Or Who) Michael Douglass' Son Cameron Has Tattooed On His Abs
# prediction: Michael and Kirk Douglass
# target: Michael and Kirk
# human target: His dad and grandpa--Michael and Kirk Douglas. #StopClickBait
# 76 / 800
# title: The cancer-causing ingredient lurking in your beauty products:
# prediction: 1,4-dioxane is a chemical used in personal care products to make them feel sof
# target: 1,4-dioxane
# human target: None
# 77 / 800
# title: The surprising thing that may be making you crave junk food
# prediction: The gut microbes that are in your gut are not only responsible for your digestion, but they
# target: gut bacteria
# human target: Gut bacteria
# 78 / 800
# title: What It Feels Like to Die
# prediction: It is a very difficult question to answer. I have been in the position of being a family member
# target: from the last two weeks until the last breath, somewhere in that interval, people become too sick, or too drowsy, or too unconscious, to tell us what they’re experiencing
# human target: it "remains shrouded in mystery."
# 79 / 800
# title: This state is NOT excited about legal weed
# prediction: The state is not excited about legal weed, but they are excited about legalizing marijuana for
# target: Wyoming
# human target: Wyoming; not legal there but borders Colorado
# 80 / 800
# title: This company wants you to bring your dog to work
# prediction: I don't think this is a good idea. I think it is a good idea to bring your dog
# target: Nvidia
# human target: None
# 81 / 800
# title: Here's Why Some Big Brand Names Are Suddenly Missing A's, B's And O's
# prediction: The #MissingType campaign is a global effort to encourage people to donate blood. The campaign i
# target: it's all part of a massive effort to encourage people around the globe to donate blood
# human target: They're raising awareness of how few people donate blood and the risk it poses to the public when there isn't blood available in emergencies
# 82 / 800
# title: If Donald Trump were black, would the GOP base accept him? The answer is obvious.
# prediction: The GOP base would accept him, but the GOP base would not accept him as a candidate
# target: Republican voters would enthusiastically welcome a black candidate, a Donell Trump — so long as he, too, championed nationalist, politically incorrect, anti-immigrant populism.
# human target: No.
# 83 / 800
# title: This is how much coffee Americans drinks every day
# prediction: 2.1 coffee drinks per day, and it increases with age.
# target: 2.1 coffee drinks
# human target: 2.1 coffee drinks/day and it increases with age
# 84 / 800
# title: Why this model is suing  for $1.5 BILLION
# prediction: The model is suing because she is not happy with the way Match.com handled the situation.
# target: Yuliana Avalos
# human target: Class action suit; photos were used on many phony account
# 85 / 800
# title: Are Red Hot Chili Peppers Really 'The Worst Band In The Universe'?
# prediction: No, they are not.
# target: you’d still have a hard time arguing they were even the worst band on this stage
# human target: No.
# 86 / 800
# title: Obama’s Female Staffers Came Up With a Genius Strategy to Make Sure Their Voices Were Heard
# prediction: The White House has a long history of gender discrimination. The first female White House aide, Mary Louise
# target: Female staffers adopted a meeting strategy they called "amplification": When a woman made a key point, other women would repeat it, giving credit to its author.
# human target: When a woman made a point, other women would repeat it and give credit to the one who originally made it
# 87 / 800
# title: How Beats tricks you Into thinking it makes a premium product
# prediction: The headphones are so cheaply made that they need to add weight to make them feel heft
# target: In these headphones, 30% of the weight comes from four tiny metal parts that are there for the sole purpose of adding weight
# human target: They add internal pieces of metal to give headphones more weight.
# 88 / 800
# title: This Clever Trick Will Instantly Clear Your Lawn of Unwanted Leaves
# prediction: The answer is a cardboard box.
# target: giant piece of cardboard
# human target: Use a large piece of cardboard to act as a giant shovel. Definitely not instant, but still faster than a rake. (Video in comments) #StopClickBait
# 89 / 800
# title: This might be the darkest theory yet about why Donald Trump keeps winning
# prediction: The fear of death is one of several interrelated psychological concepts that could help explain why Donald Trump ha
# target: Solomon’s recent research shows that people who are thinking about death are more likely to say they support him
# human target: People who think about death are more likely to support him
# 90 / 800
# title: The curious cases and unsolved #mysteries that perplexed us in #2016
# prediction: The following are some of the most baffling cases and unsolved mysteries that perplexed
# target: Mark and Jacoba Tromp and their adult children Ella, Riana and Mitchell left their home in Silvan, east of Melbourne, taking cash but leaving behind bank cards and mobile phones.
# human target: None
# 91 / 800
# title: Ex-Cons Remember Their Worst Jobs After Being Released from Prison
# prediction: I remember my worst job after being released from prison. It was a job that I was hired for
# target: working on a cattle ranch as a utility farmer,
# human target: Sauté cook in Italian restaurant, utility farmer on a cattle ranch, picking up trash at the city dump at 38°C, telemarketing.
# 92 / 800
# title: Verizon and AT&amp;T Don't Like This Internet Ruling, But Your Pocketbook Will
# prediction: The FCC has ruled that the Internet should be treated as a public utility, and that broadband providers should
# target: net neutrality
# human target: Ruling upheld FCC regulation that supports net neutrality
# 93 / 800
# title: Instead Of A Graduation Speech, This Teen Does THIS And Surprises Everyone!
# prediction: This is a great example of how to use a simple, yet powerful, message to inspire your audience
# target: sang his very own special rendition of Lukas Graham’s hit song "7 Years."
# human target: He sings his own graduate version of "7 Years".
# 94 / 800
# title: 'Star Wars: Episode 8' Working Titled Leaked
# prediction: 'Star Wars: Episode 8' Working Titled Leaked
# target: Fall of the Resistance.
# human target: Episode VIII: Fall of the Resistance
# 95 / 800
# title: We've finally figured out when the moon formed
# prediction: The moon formed about 4.5 billion years ago, and scientists think the giant impact that formed the
# target: 4.47 billion years ago
# human target: 4.47 billion years ago.
# 96 / 800
# title: Another country decriminalizes marijuana
# prediction: The United States decriminalized marijuana in 1937, and the United Kingdom decriminalized it in
# target: Switzerland
# human target: Switzerland
# 97 / 800
# title: You Should STOP Eating Baby Carrots for THIS Disturbing Reason!
# prediction: Baby carrots are not good for you. They are bad for you. They are not healthy.
# target: They are soaked in a bath of chlorine
# human target: They're soaked in chlorine to remove germs from the manufacturing process. #StopClickBait
# 98 / 800
# title: The iPhone 5C number Apple doesn't want you to know
# prediction: The iPhone 5C is a rebranded iPhone 5 with nearly all the same specs.
# target: preorder figure was 2 million
# human target: Number of preorders
# 99 / 800
# title: I Thought It Was Weird She Glued Pennies To Her Daughter’s Shoes, But When I Found Out Why? GENIUS!
# prediction: The reason why she glued the pennies to her daughter’s shoes is because she wanted to
# target: make-shift tap shoes
# human target: Makeshift tap shoes
# 100 / 800
# title: GOP governor pressured to reveal secret donors
# prediction: The Michigan Republican Party has been pressured to reveal the identities of the donors to the NERD fund
# target: Gov. Rick Snyder (R-Michigan)
# human target: MI's Rick Snyder
# 101 / 800
# title: President Obama won't end his vacation for one specific reason
# prediction: Obama doesn't want to play by the rules of modern politics. He doesn't want to be seen as a
# target: Because he believes he can monitor the situation as well — or better — from where he is
# human target: He thinks visiting the flooding in Louisiana would just be political theater
# 102 / 800
# title: The last utopia?
# prediction: The last utopia is the United States of America.
# target: Mr Thiel, who previously said New Zealand was a "utopia" and has invested heavily there, is just one of several US migrants who have realised what the country has to offer.
# human target: None
# 103 / 800
# title: Well this is one way to get flawless skin
# prediction: Yes, but it is not the only way. There are other ways to get flawless skin.
# target: two foundations
# human target: Layer on two foundations
# 104 / 800
# title: Wow! This Company Pays For Employees' Weddings And Their Kids' College
# prediction: This is a great example of how companies are thinking outside the box to attract and retain employees. The
# target: Boxed
# human target: Boxed, an online Costco-like retailer. (Yes, they're hiring.) #StopClickBait
# 105 / 800
# title: Just a slight flaw with this argument...
# prediction: The flaw is that Barron is not a university official, and therefore cannot be held responsible for the
# target: key objectives of MILO’s tour was the promotion of free speech on typically censorious American college campuses
# human target: None
# 106 / 800
# title: What's lurking in your white wine WILL scare you
# prediction: The answer is arsenic. Arsenic is a naturally occurring element that is found in the earth
# target: toxic metal arsenic
# human target: Arsenic; also found in water beer food etc.
# 107 / 800
# title: How much will JPMorgan pay for 'London Whale' losses?
# prediction: The settlement is expected to be for at least $700 million.
# target: $900 million
# human target: More than $900 million the @nytimes reports
# 108 / 800
# title: 5 reasons why no one has built a better EpiPen
# prediction: 1. Mylan has patent protection that lasts through 2025
# target: 1. Mylan has patent protection that lasts through 2025
# human target: they're patented, demand is low, and it's expensive (other 2 reasons were repetitive)
# 109 / 800
# title: Here's what Donald Trump rejects when he undermines the election results
# prediction: The Constitution of the United States is the supreme law of the land. It is the law of the
# target: he would keep the nation "in suspense" about whether he will accept the results
# human target: Democracy.
# 110 / 800
# title: Gwyneth Paltrow’s wellness philosophy, in 10 Quotes
# prediction: Gwyneth Paltrow’s wellness philosophy, in 10 Quotes
# target: "I like to do a cleanse once a year. But it's not just juices. And I don't do it for weight loss,"
# human target: None
# 111 / 800
# title: 25 Signs You’re Not In Your Early Twenties Anymore
# prediction: 25 Signs You’re Not In Your Early Twenties Anymore
# target: 1. You buy hemp milk not because it’s ironic, but because your digestion isn't what it used to be.
# human target: You're 25 or older.
# 112 / 800
# title: 1-Minute Trick To Stop Headaches From Disturbing You On Busy Days
# prediction: I have a headache and I have to go to work. I have to go to work and
# target: All you need to do is applying pressure on your sinuses between your eyes and nose and on the back of your head for 60 seconds.
# human target: Contrary to what the picture shows, you actually need to use your thumbs apply pressure to your sinuses (via the side of the nose) and the back of your neck (Where your skull meets the neck). You need to do both sides, and hold them for a minute *each*. #StopClickBait
# 113 / 800
# title: 15 LGBTQ Celebrities You Didn’t Know Came Out In 2016
# prediction: 15 Kristen Stewart Actress Kristen Stewart was the other half to actor Robert Pattinson for years, and
# target: 15 Kristen Stewart
# human target: Kristen Stewart, Aubrey Plaza, Mara Wilson, Colton Haynes, Reid Ewing, Shane Dawson, Ryan Beatty, Rayvon Owen, Gloria Vanderbilt, Nur Warsame, Justine Greening, George Shelley, James Franco, Amandla Stenberg, and Rowan Blanchard
#
# #StopClickBait
# 114 / 800
# title: Chris Brown has big plans for 2014
# prediction: Chris Brown has big plans for 2014. He is currently working on his sixth studio album, "X,
# target: his sixth studio album, "X," will hit stores on May 5
# human target: His sixth studio album "X" hits stores on May 5
# 115 / 800
# title: Trouble in paradise? Rose Leslie doesn't want to work with Game Of Thrones beau Kit Harington again
# prediction: I think we leave it at that. We had such a fabulous time working together on Thrones.
# target: wants to achieve her own success
# human target: No, she just wants to have an independent career that she makes through her own hard work and success.
# 116 / 800
# title: Her Thug Boyfriend Scarred Her For Life, The Way She Responded Took GUTS.
# prediction: I don't think she was scarred for life. She was scarred for a while, but she
# target: Chantelle
# human target: Became a model and won a beauty pageant.
# 117 / 800
# title: 'Today' anchor makes not one but TWO huge announcements
# prediction: Guthrie announced that she got married and then announced that she was pregnant.
# target: Savannah Guthrie
# human target: Savannah Guthrie married &amp; pregnant
# 118 / 800
# title: After learning she didn't have long to live, she composed a dating profile for the man she'd leave behind
# prediction: I have been married to the most extraordinary man for 26 years. I was planning on at least another
# target: Jason Brian Rosenthal
# human target: None
# 119 / 800
# title: This Ridiculously Simple Service Is Saving Canadian Drivers A Ton of Money
# prediction: The answer is yes, and it is called EasyAuto123.com. This is a free service
# target: EasyAuto123.com
# human target: Basically an advertisement for a car loan comparison web site
# 120 / 800
# title: You favorite television show just got better
# prediction: The new season of Modern Family is coming to Netflix on September 10, and it is already a hit
# target: On September 10, flash sale site Joss & Main will be selling actual props from the sets
# human target: Article about "Modern Family" props being for sale
# 121 / 800
# title: This Genius Pokémon Go Theory May Have Just Revealed Where You Can Find Mew
# prediction: The answer is in the game's code.
# target: Guyana
# human target: Possibly Guayana
# 122 / 800
# title: Whoa eccentric basketball player is selling his very bizarre home
# prediction: The house is listed for $3.5 million, but the price has been reduced to $2.5
# target: Gilbert Arenas
# human target: Gilbert Arenas for $3mil in VA
# 123 / 800
# title: This guy went on a holiday with a group of total strangers for the greatest reason
# prediction: He was a Joe McGrath.
# target: Joe McGrath
# human target: None
# 124 / 800
# title: 9 incredible photo stories you absolutely can’t miss
# prediction: 9 incredible photo stories you absolutely can’t miss
# target: 1. "Never-Before-Seen Photos Behind the Scenes at the Women’s March"
# human target: None
# 125 / 800
# title: Nine families raised children who all went on to extraordinary success. Here’s what they have in common
# prediction: They are all the same. They are all the same. They are all the same. They are
# target: parent who was an immigrant or an educator
# human target: immigrant/educator parents, politically active parents, awareness of mortality, kids had more "freedom"
# 126 / 800
# title: #NeverTrump Loses Another One - I'm Shocked And Trump's Cheering!
# prediction:   This video player must be at least 300x168 pixels in order to operate
# target: Alex Castellanos
# human target: Alex Castellanos, a previous Mitt Romney employee
# 127 / 800
# title: This Republican mayor has an incredibly simple idea to help the homeless. And it seems to be working.
# prediction: The idea is simple, but it is not simple to implement. The mayor has a simple idea to
# target: bring the work to them
# human target: He started a jobs program.
# 128 / 800
# title: Is this deadly drug becoming a problem in American schools?
# prediction: Yes, it is. The problem is not limited to the United States. In the United Kingdom,
# target: heroin
# human target: Heroin; yes it is says @Teenvogue
# 129 / 800
# title: This trailer will take your breath away
# prediction: Yes, it will. But it will also take your breath away because it will be a trailer for
# target: "Gravity"
# human target: For the film "Gravity" opening 10/4
# 130 / 800
# title: She Wraps A Piece Of Bread Around Her Foot. When She Takes It Off? SHOCKING!
# prediction: The bread is a bandage. The bread is a bandage. The bread is a bandage
# target: Naturally Remove Yucky Corns And Calluses
# human target: Apparently it helps remove corns and callouses.
# #notworthit
# #StopClickBait
# 131 / 800
# title: Traffic-weary homeowners and Waze are at war, again. Guess who’s winning?
# prediction: The traffic-weary homeowners.
# target: For some drivers, their app-inspired shortcut became a permanent route.
# human target: Waze.
# 132 / 800
# title: 7 of the 10 Drunkest Cities in America Are All in a Single State
# prediction: Wisconsin
# target: Wisconsin
# human target: It's Wisconsin
# 133 / 800
# title: Costco &amp; Sam's Club Recall Ham For The Most Disgusting Reason
# prediction: The ham was covered in rubber material.
# target: pieces of rubber material embedded in the meat
# human target: The hams contained pieces of rubber.
# 134 / 800
# title: The Moon Hasn't Done This In Nearly Half A Century
# prediction: The Moon Hasn't Done This In Nearly Half A Century More Look to the skies this evening
# target: full moon on the same day as the summer solstice
# human target: It's not really 'doing' anything, it's just going to be in its full phase during the summer solstice, which are two events that happen to coincide every once it a while due to routine orbital mechanics
# 135 / 800
# title: Sacha Baron Cohen and his wife donate $1 million to Syrian refugees
# prediction: Sacha Baron Cohen and his wife donate $1 million to Syrian refugees
# target: Isla Fisher
# human target: "His wife" i.e. famous actress Isla Fisher (h/t @Slade)
# 136 / 800
# title: Does Sparkling Water Have a Downside?
# prediction: No, Sparkling Water is not a downside. It is a healthy drink. It is a
# target: the greatest potential health drawback of consuming bottled sparkling water is missing out on the benefit of fluoride when you drink it instead of fluoridated tap water
# human target: No.
# 137 / 800
# title: How much money did Paris Hilton make off her sex tape?
# prediction: According to the lawsuit, the porn site is claiming to have sold more than 1.5 million
# target: never received a dime
# human target: None she says
# 138 / 800
# title: Huge 'Jason Bourne' chase scene wrecked this many cars
# prediction: 170 cars
# target: 170
# human target: 170 cars.
# 139 / 800
# title: How this 27-year-old made $1 million last year:
# prediction: I made $27,000 last year. I made $27,000 last year. I made
# target: Her ticket out of debt and into financial freedom has been her blog, Making Sense of Cents, where she offers tips on saving and making money   and publishes income reports.
# human target: None
# 140 / 800
# title: This is what it actually means to be caught 'Doping' at the Olympics
# prediction: The IOC has decided that Russia will not be allowed to compete in the Rio Olympics. This i
# target: taking a banned or illegal substance in order to improve performance
# human target: Taking a banned or illegal substance to improve performance.
# 141 / 800
# title: The Ridiculously Simple Trick That'll Keep Your Food From Spoiling
# prediction: The FIFO method of sorting your groceries.
# target: move all the perishable older goods to the front and place the newer groceries behind them.
# human target: Use the "First In, First Out" method - move newer items to the back of the fridge, behind the older items. #StopClickBait
# 142 / 800
# title: The best city for newlyweds is...
# prediction: Minneapolis, Minnesota
# target: Atlanta
# human target: Atlanta says @CreditDonkey; Tulsa Okla. says @RentDotCom
# 143 / 800
# title: Kanpur Couple Called Off Their Wedding Because Of PM Narendra Modi. You'll Be Surprised To Know Why.
# prediction: The couple was married in a temple in Kanpur. The bride-to-be was a government employee and
# target: The woman strongly believed that PM Narendra Modi is responsible for poverty and other terrible conditions in our country. Whereas the husband felt otherwise. He strongly believed that NaMo is doing his best to fix everything, gradually.
# human target: They had opposing views on the PM. #StopClickBait
# 144 / 800
# title: Six of Roald Dahl's made-up words have been added to the Oxford English Dictionary to celebrate his centenary
# prediction: The six new words are: Dahlesque, Golden ticket, Human bean, Oompa Loom
# target: Dahlesque
# human target: Dahlesque, Golden ticket, Human bean, Oompa Loompa, Scrumdiddlyumptious, Witching hour. Revised were Frightsome, Gremlin, Scrumptious, Splendiferous.
# 145 / 800
# title: Startling link between kidnapped teen's mom and suspect
# prediction: The Georgia Bureau of Investigation (GBI) has released a statement regarding the arrest of Maria Corral,
# target: arrested in a 2012 marijuana trafficking bust
# human target: They were arrested in same 2012 drug bust
# 146 / 800
# title: The most unexpected country that rocks at making olive oil
# prediction: The most unexpected country that rocks at making olive oil is Greece. The Greek olive oil is the best
# target: Peloponnese
# human target: Greece
# 147 / 800
# title: What does Brexit mean for UK Citizens who already booked Summer Holiday abroad?
# prediction: The UK is leaving the European Union. This means that the UK will no longer be part of the
# target: If you've booked a holiday, but are yet to exchange your pounds for a foreign currency, you're going to be a victim of Britain leaving the EU I'm afraid. And your flights look like they're going to go up in price, too.
# human target: Exchanging pounds to a foreign currency will be more expensive
# 148 / 800
# title: The ISIS Says It's Scared Of Only One Country And It's Not America Or Russia
# prediction: The Israelis.
# target: Israel
# human target: Israel.
# #StopClickBait
# 149 / 800
# title: Oscar favorite latest name rumored for "Star Wars"
# prediction: Chiwetel Ejiofor
# target: Chiwetel Ejiofor
# human target: Chiwetel Ejiofor
# 150 / 800
# title: The cutest little European city you've probably never heard of
# prediction: Lviv, Ukraine
# target: Lviv, Ukraine
# human target: Lviv Ukraine
# 151 / 800
# title: You Won’t Believe What Emma Roberts Has Done Now
# prediction: She’s still wearing her braids.
# target: is still wearing her updo braids TWO DAYS after debuting the glamorous look at the Met Gala
# human target: She wore the same braid three days in a row.
# Seriously.
# That's really what the article is about.
# #StopClickBait
# 152 / 800
# title: Why 2017 is the year to visit Kathmandu
# prediction: The two year anniversary of the Nepal earthquake is approaching. The capital is back on its feet. Now
# target: Every rupee spent in hotels and restaurants, shops, taxis or temples, is helping Kathmandu back on to its feet
# human target: None
# 153 / 800
# title: You've never heard the f-word this much in your entire life
# prediction: The Wolf of Wall Street
# target: "The Wolf of Wall Street" features a lot of swear words. According to Vulture, there are 569 variations on the f-word alone
# human target: It's said in Wolf of Wall Street a lot
# 154 / 800
# title: This Puppy Just Howled For The First Time! Watch What His Proud Mom Does In Response!
# prediction: The mom is so proud of her baby, she joins in the howling!
# target: she joins in
# human target: Whines. #StopClickBait
# Video in comments!
# 155 / 800
# title: Click to hear about some of the things that have been keeping us busy. #2 will blow your mind.
# prediction: I think the answer is that we are working on a lot of things. We are working on a
# target: Mobile web (m.reddit.com) is undergoing a major overhaul
# human target: Reddit started development on a new frontpage algorithm.
# 156 / 800
# title: Temple University breaks world record for PB&amp;J sandwiches
# prediction: Yes, they did.
# target: Guinness World Record: the most peanut butter and jelly sandwiches made in an hour
# human target: Students MADE 49,100 sandwiches in one hour, breaking the previous record of 39,303. Sandwiches were donated to 15 food banks and shelters in Philly
# 157 / 800
# title: Legal weed sales halted in small town due to lack of staples
# prediction: The Colorado Supreme Court ruled that the lack of staples in a petition to allow recreational marijuana
# target: La Junta
# human target: Staples literally; La Junta CO
# 158 / 800
# title: Here’s when the first 64 player multiplayer Battlefield 1 livestream is coming
# prediction: Battlefield 1 will be livestreamed on June 12 at 5 PM ET.
# target: June 12 at 5 PM ET
# human target: June 12 at 5 PM ET. #StopClickBait
# 159 / 800
# title: 'Star Wars: The Force Awakens' Actress Opens Up About Painful Disorder
# prediction: The "Star Wars" actress, 24, posted a selfie and explained that she has been suffering from
# target: Daisy Ridley
# human target: endometriosis
# 160 / 800
# title: @LadyGaga and @RKelly team up
# prediction: @LadyGaga and @RKelly team up on "Do What U Want"
# target: on "Do What U Want"
# human target: TO FIGHT KAIJU!...er I mean for one song on Gaga's new album "A
# 161 / 800
# title: 17 signs you are totally a caffeine mom
# prediction: 1. You have a coffee addiction. 2. You have a coffee addiction. 3. You have
# target: 1. Starbucks prevents you from losing it on your kids.
# human target: None
# 162 / 800
# title: President Trump? There’s only one way to stop it happening
# prediction: There’s only one way to stop it happening. It’s to vote for Hillary Clinton.
# target: vote Clinton.
# human target: Convince voters who hate both candidates to vote for Hillary
# 163 / 800
# title: Just guess how much Mayweather spends on haircuts
# prediction: $1,000 per haircut
# target: $1,000 per haircut
# human target: $2000 per week
# 164 / 800
# title: The Secret Reason Apple Might Be Killing the iPhone headphone jack
# prediction: The headphone jack is dead.
# target: If we're being honest, this probably won't be the most exciting iPhone release we've seen
# human target: Article does not say why
# 165 / 800
# title: Guess Who Amber Rose Wants to Be Her Next Baby's Father
# prediction: Wiz Khalifa
# target: Wiz Khalifa
# human target: Her ex, Wiz Khalifa.  #StopClickBait
# 166 / 800
# ...
# prediction: Never swipe your card at a cash register.
# target: You see, if you swipe a chip card instead of inserting it into slot, the merchant is responsible for covering any fraudulent charges — not the bank.
# human target: Don't swipe it. #StopClickBait
# 750 / 800
# title: Magazine responds to backlash against Melissa McCarthy cover
# prediction: I agree with the magazine's response. The magazine's editors were not trying to hide the fact that
# target: Elle
# human target: ELLE (@ELLEmagazine)
# 751 / 800
# title: Here's what happens if you never wash your jeans
# prediction: The bacteria and other microorganisms that live on your skin and in your clothes will continue to grow and
# target: A few years ago, one of McQueen's students wore his jeans for 15 months straight without a single wash and then tested the level of bacteria on them. The student-teacher team was surprised to find that the unwashed jeans carried nearly the same amount of bacteria as those same pants after they had been washed and then worn for another 13 days.
# human target: Pretty much nothing
# 752 / 800
# title: Why some people think Trump snorted cocaine or Adderall before Monday’s presidential debate
# prediction: Trump snorted Adderall because he was on Adderall and he was on Adderall
# target: Many tweeters noticed some strange behavior on Trump’s part; in addition to his seeming inability to control the volume of his speech, the man couldn’t stop sniffling (see the supercut below).
# human target: He was sniffling during the debate. Because if he had a cold, it wouldn't get as many clicks.
# 753 / 800
# title: Rubbing These Two Things on Your Teeth Will Make Them Whiter in Minutes
# prediction: No, it won't.
# target: coconut oil
# human target: Coconut Oil & Tumeric. #StopClickBait
# 754 / 800
# title: Why You Should Drink Milk Before A Road Trip
# prediction: Drinking milk before a road trip is a good idea because it helps you stay hydrated and also
# target: It’s chock-full of nutrients and electrolytes like potassium, which not only keep you hydrated but also take longer for your body to process so you buy some time between bathroom breaks.
# human target: "Recent studies have shown" milk's nutrients take longer for the body to process than soda's sugar, so therefore you don't have to pee as often. (Yeah, makes sense.)
# 755 / 800
# title: This woman was rejected from a job interview with a savage emoji message
# prediction: The woman was not rejected from the job interview. She was rejected from the job. The woman wa
# target: laughing face emoji
# human target: None
# 756 / 800
# title: Look which formerly infamous Internet star is the new face of @AmericanApparel
# prediction: Chris Crocker
# target: Chris Crocker
# human target: .@ChrisCrocker
# 757 / 800
# title: Read this before you go out to shovel your driveway
# prediction: The answer is that it is not safe to shovel your driveway after a snowstorm. The
# target: Talk to a doctor before shoveling if you have a history of heart disease Stop immediately if you feel dizzy or tightness in the chest
# human target: None
# 758 / 800
# title: Her Daddy Died Before She Was Born. But Watch What They Capture On Camera...
# prediction: The photo is a beautiful representation of the family’s hope for the future. The child’s smile i
# target: Newborn Smiling In Her Recently Deceased Father’s Gloves
# human target: The photographer positions the baby with her father's motorcycle gloves as though she's being "held" in her father's hands. #StopClickBait
# Thanks Amrita for the link!
# 759 / 800
# title: You'll never believe what Selena Gomez orders at McDonalds
# prediction: A number 7 with medium fries and a Coke
# target: number 7 with medium fries and a Coke
# human target: It's a #7 with medium fries and a Coke.
# 760 / 800
# title: This state wants to legalize medical marijuana. Police agencies won't let it
# prediction: The police agencies are not standing in the way of legalizing medical marijuana. They are standing in
# target: Minnesota
# human target: Minnesota
# 761 / 800
# title: Parents Who Bring Forgotten Lunch to School See Shocking Orders Posted on Door
# prediction: The Catholic High Schools for Boys in Little Rock, Arkansas, deserves a raucous round of appl
# target: "If you are dropping off your son’s forgotten lunch, books, homework, equipment, etc., please TURN AROUND and exit the building," the sign read. "Your son will learn to problem-solve in your absence."
# human target: "If you are dropping off your son’s forgotten lunch, books, homework, equipment, etc., please TURN AROUND and exit the building," the sign read. "Your son will learn to problem-solve in your absence."
# 762 / 800
# title: How to fix lag in SSB4 on 3DS
# prediction: The 3DS version of Super Smash Bros 4 is a great game. The release date brought a
# target: 2 human players and 2 CPUs resulted in no lag.
# human target: Deal with it
# 763 / 800
# title: Two Strangers Hug a Woman After Asking for Directions, but Watch What the Lady in Purple Does
# prediction: The woman in purple is the thief.
# target: stealing her jewelry
# human target: She pickpockets them
# 764 / 800
# title: The next #SNL Weekend Update anchor is...
# prediction: Cecily Strong
# target: Cecily Strong
# human target: Cecily Strong (@cecilybecily)
# 765 / 800
# title: 19 things you’ll only get if you’re low AND high maintenance
# prediction: ive worn the same shirt everyday for a week [packing for vacation] hmmm. i'll
# target: 1. When it comes to food, you won’t just eat any old thing.
# human target: None
# 766 / 800
# title: State senators want to make it easier to legislate behind closed doors
# prediction: The Arizona legislature has been working on a bill that would allow lawmakers to meet privately to
# target: Arizona
# human target: ARIZONA
# 767 / 800
# title: The Real Reason Airplane Windows Don't Always Align With Your Seat
# prediction: The reason your seat isn’t where it should be is because the airline has to make money. They
# target: airlines rarely follow those recommendations
# human target: Although airplanes are designed to have windows aligned with the seats, most airlines do whatever they want in terms of actually aligning the rows. #StopClickBait
# 768 / 800
# title: Here's A New Clue About Where 'The Simpsons' Actually Takes Place
# prediction: The Simpsons' Springfield is in Oregon, but the real Springfield is in any state but
# target: Springfield, Oregon
# human target: Basically, Oregon.
# 769 / 800
# title: A Pregnant Dog Lays Lifelessly In A Field, But Seconds Later, I Gasped
# prediction: A pregnant dog lays lifelessly in a field, but seconds later, I gasped. The
# target: Norah picked her head up
# human target: It was alive
# 770 / 800
# title: Here’s Sony’s Response To Microsoft’s Invite to Connect Xbox One and PS4 Networks
# prediction: Sony’s response to Microsoft’s invite to connect Xbox One and PS4 networks
# target: Sony confirmed that the company was not against cross-console support and open to the idea of allowing PlayStation 4 players to play online against other consoles
# human target: "We're considering it, but nothing official yet."
# 771 / 800
# title: The 'Batman v Superman' Easter Egg Almost Everybody Missed
# prediction: The canisters Bruce Wayne/Batman used have "Pb" — the abbreviation for lead in the
# target: the canisters Bruce Wayne/Batman used have "Pb"
# human target: The letters 'Pb' on the kryptonite canisters, explaining why Superman didn't use X-ray vision to see inside them.
# 772 / 800
# title: If You've Ever Shivered After Peeing, THIS Is What's Happening
# prediction: The post-micturition convulsion syndrome is a condition that causes you to shiver after you
# target: "post-micturition convulsion syndrome."
# human target: There are two theories- you get cold *or* it's an involuntary reflex. #StopClickBait
# 773 / 800
# title: NASA Warns Massive Asteroid Is Heading Towards Earth TODAY
# prediction: NASA has just confirmed that a gargantuan mile-long asteroid is heading towards Earth and will brush past u
# target: The end is not near, as a ‘near Earth pass’ isn’t actually that near at all – in fact, the asteroid is going to go past the Earth 7.3 million miles away (that’s 30 times further away than the moon), reports the Daily Star.
# human target: This is literally an excerpt from the article itself.
#
# "The end is not near, as a ‘near Earth pass’ isn’t actually that near at all – in fact, the asteroid is going to go past the Earth 7.3 million miles away"
#
# #StopClickBait
# #NextLevelClickBait
# 774 / 800
# title: A woman who interviewed over 100 people at Goldman Sachs says there's one question she always hoped candidates would ask her, but they never did
# prediction: I think this is a good question for interviewees to ask because, as a candidate,
# target: "Where do you see yourself in five years?"
# human target: "where do you see yourself if 5 years?"
# 775 / 800
# title: Boris Johnson's Brexit speech was uploaded to Pornhub with a new title
# prediction: The video was uploaded to Pornhub with the title "Dumb British blond fucks 15 million
# target: Dumb British blond fucks 15 million people at once.
# human target: "Dumb British blond fucks 15 million people at once"
# 776 / 800
# title: WATCH: Wrestling legend comes out of the closet at 73
# prediction: The clip was taped in 2012, but it was only released on Thursday, June 12, when
# target: Pat Patterson
# human target: Pat Patterson
# 777 / 800
# title: Hey, what's that thing *you* did to succeed?
# prediction: I don't know what you mean.
# target: bullshitting
# human target: None
# 778 / 800
# title: Former "Community" star tweets importance of "Arsenio Hall Show"
# prediction: Former "Community" star Yvette Nicole Brown says she was the only black woman to appear on the
# target: Yvette Nicole Brown
# human target: Yvette Nicole Brown (@YNB)
# 779 / 800
# title: 11 of the nation's 100 most dangerous cities are in this state
# prediction: Florida is the fourth most populous state in the U.S., but it contains more of nation
# target: Florida
# human target: Florida
# 780 / 800
# title: J.K. Rowling has revealed a heartbreaking truth about Hagrid
# prediction: Hagrid was expelled from Hogwarts as a teenager, and he never returned to the school. He
# target: not have enough happy memories to produce a Patronus
# human target: "Hagrid couldn’t produce a Patronus. It’s a very difficult spell."
# 781 / 800
# title: Perhaps the most shocking result so far is in Missouri. #ElectionNight
# prediction: The most shocking result so far is in Missouri. Democrat Jason Kander looks to be running very
# target: Democrat Jason Kander looks to be running very strongly in the exit polls.
# human target: "Democrat Jason Kander looks to be running very strongly in the exit polls." That is not a "result."
# 782 / 800
# title: How long does sex normally last?
# prediction: How long does sex normally last? The answer is not a simple one. It depends on many factor
# target: from 33 seconds to 44 minutes
# human target: 5.4 minutes
# 783 / 800
# title: People are very worried by this video of Donald Trump
# prediction: I think it's a little bit of a stretch to say that people are worried about this video of Donald
# target: he could not locate the guy sitting right in front of him.
# human target: None
# 784 / 800
# title: The antibodies that were invented to help immunologists find GOD
# prediction: The antibodies that were invented to help immunologists find GOD were called monoclonal antibodies. Mon
# target: monoclonal antibodies as scientific tools and for the treatment of diseases
# human target: Hybridoma technology (for producing monoclonal antibodies) was invented to help explain how humans can produce billions of different antibodies — in other words, to explain the "generation of diversity" (GOD) found in antibodies
# 785 / 800
# title: 6 transcendental festivals out in the middle of nowhere
# prediction: AfrikaBurn - Tankwa Karoo
# target: BOOM – Portugal
# human target: None
# 786 / 800
# title: KFC’s secret ingredient is 'the most under-appreciated spice' in the world
# prediction: The answer is white pepper.
# target: white pepper
# human target: White pepper.
# 787 / 800
# title: Sex experts think that more straight men are exploring a formerly taboo hot spot
# prediction: I think that more straight men are exploring a formerly taboo hot spot, but I don't think that
# target: anal sex
# human target: The butt.
# 788 / 800
# title: Things in the Olsen twins' lives that make no sense
# prediction: The Olsen twins are not the same as the other twins. They are not the same as the
# target: earned much of their fortune making unintentionally laughable direct-to-video movies
# human target: list in comments saves 13 clicks
# 789 / 800
# title: 13 Pokémon The Designers Just Gave Up On
# prediction: Mewtwo
# target: Klefki
# human target: Klefki, Rotom, Luvdisk, Unown, Vanilluxe, Jynx, Cofagrius, Voltorb, Dedenne, Druddigon, Exeggutor, Garbodor, and Sunabaa (Japanese name, upcoming), along with explanations of why the author doesn't like them
# 790 / 800
# title: 9 things Elizabeth Taylor taught us about the art of love
# prediction: 9 things Elizabeth Taylor taught us about the art of love
# target: I don’t pretend to be an ordinary housewife
# human target: None
# 791 / 800
# title: Both Campaigns Stunned After Houston Chronicle Makes VERY Surprising Endorsement
# prediction: The Houston Chronicle is a very conservative newspaper, and it is not surprising that they would endorse Hillary Clinton
# target: Hillary Clinton
# human target: They endorse Hillary Clinton after endorsing Mitt Romney in a previous election
# 792 / 800
# title: One Guy Decided To Explore This Abandoned Building... And Instantly Regretted It.
# prediction: The guy was lucky to escape with his life. He was definitely not the only one who was in
# target: This was clearly a crack house, and he was standing there with a dealers stash. People have gotten killed for less. Well guess what? The dealer comes back!
# human target: He found jail cells, graffiti, a shopping cart, empty pool, offices, office supplies, floor buffer and a broom. #StopClickBait
# 793 / 800
# title: Here's a controversial idea about China's economy that no one wants to hear
# prediction: The idea is that China needs to move away from industrial manufacturing and toward services. The reason is that
# target: China is too quick to rebalance its services sector
# human target: Their rebalancing to a service economy may be too hasty
# 794 / 800
# title: Dog Dies One Hour After Hiking With His Owner, Veterinarian Gives Shocking Reason Why
# prediction: The dog died because he ate water hemlock. The vet said that the dog was poisoned by
# target: the plant the dog was chewing on was deadly water hemlock
# human target: It ate water hemlock which is poisonous even in small amounts
# 795 / 800
# title: This is what happens when you leave a hotel cleaner a $500 tip
# prediction: The cleaner is shocked and surprised by the generosity of the two men. She is grateful for the
# target: The video below shows the stunned cleaner initially refusing to accept the tip, before another hotel worker reassured her by saying, "You deserve it."
# human target: She is happy
# 796 / 800
# title: This Texas GOP elector announces that he won't vote for Trump
# prediction: The Texas elector is not a "faithless elector". He is a Republican elector who i
# target: Christopher Suprun
# human target: None
# 797 / 800
# title: This beauty queen cured her acne with one diet change
# prediction: The answer is yes, but it is not a diet that is recommended by doctors. The diet that
# target: Rachel Crawley
# human target: None
# 798 / 800
# title: WikiLeaks' Julian Assange Reported Dead
# prediction: Assange is alive and well. — WikiLeaks (@wikileaks) October 17, 2016
# target: Julian Assange’s internet link has been intentionally severed by a state party
# human target: It was just his wifi that was dead.
# 799 / 800
# title: Original "Law &amp; Order: SVU" cast member leaving the show
# prediction: Richard Belzer is leaving "Law & Order: SVU." Belzer, who has been
# target: Richard Belzer
# human target: Richard Belzer

# %%
import pickle

with open('prompt_spoilers_7b1.dat', 'wb') as f:
    pickle.dump(predictions_from_prompts, f)

# %%
i = 38 #37 is good
train[i]['postText'], train[i]['spoiler'], train[i]['provenance']['humanSpoiler']
# Out:
# (['This Is What Bill Clinton Will Actually Be Called If Hillary Becomes President'],
#  ['the first gentleman'],
#  'The First Gentleman')

# %%
train[0].keys()
# Out:
# dict_keys(['uuid', 'postId', 'postText', 'postPlatform', 'targetParagraphs', 'targetTitle', 'targetDescription', 'targetKeywords', 'targetMedia', 'targetUrl', 'provenance', 'spoiler', 'spoilerPositions', 'tags'])

# %% [markdown]
# # BLOOM For Question-Answering

# %%
from transformers import pipeline, AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained('deepset/roberta-base-squad2')
question_answering = pipeline("question-answering", model="deepset/roberta-base-squad2", tokenizer=tokenizer)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/496M [00:00<?, ?B/s]

# %%
spoilers_from_qa = []
for i, entry in enumerate(validation):
    print(i,'/',len(validation))
    context = ' '.join(entry['targetParagraphs'])
    question = entry['postText'][0]
    result = question_answering(question=question, context=context)

    print('title:',entry['postText'][0],'\nprediction:',result['answer'])
    spoilers_from_qa.append(result['answer'])
# Out:
# 0 / 800
# title: Five Nights at Freddy’s Sequel Delayed for Weird Reason
# prediction: too dark
# 1 / 800
# title: Why Arizona Sheriff Joe Arpaio’s fate could hang on a single word
# prediction: intentionally
# 2 / 800
# title: Here’s how much you should be tipping your hairdresser
# prediction: slightly smaller tip
# 3 / 800
# title: "Harry Potter" alums reunite for new movie
# prediction: Michael Gambon
# 4 / 800
# title: A man swallowed a microSD card and you won't believe what happened next!
# prediction: John Doe
# 5 / 800
# title: This popular soda could cure your hangovers scientists say:
# prediction: Sprite
# 6 / 800
# title: The anytime snack you won't feel guilty about eating
# prediction: midnight
# 7 / 800
# title: You won't believe this stunning "Harry Potter" revelation about Professor McGonagall
# prediction: she had been teaching at Hogwarts for "Thirty-nine years this December".
# 8 / 800
# title: J.J. Abrams has an answer on if there will be a post-credits scene in the new 'Star Wars'
# prediction: No, there’s not
# 9 / 800
# title: Kristin Cavallari (@KristinCav) opens up about just how fake "The Hills" was
# prediction: fake relationships, fake fights
# 10 / 800
# title: How 1 model prepares for lingerie shoots
# prediction: First, you have to mentally prepare
# 11 / 800
# title: Guess who Obama just dined with in Vietnam
# prediction: Anthony Bourdain
# 12 / 800
# title: How This 20-Year-Old Died From Kissing Her Boyfriend
# prediction: he'd eaten a peanut butter sandwich and wasn't aware of her peanut allergy
# 13 / 800
# title: The question former O.J. Simpson prosecutor hates being asked
# prediction: Does she think Simpson really did it
# 14 / 800
# title: Hollywood legend's amazing home is on the market
# prediction: Mitzi Gaynor
# 15 / 800
# title: What are mosquito-control workers spraying in Miami?
# prediction: in response to state Department of Health investigations
# 16 / 800
# title: Do birds fart?
# prediction: birds rarely or never fart
# 17 / 800
# title: Angry ex-boyfriend bursts into delivery room, assumes fighting stance and does the most...
# prediction: yell obscenities
# 18 / 800
# title: Local Cops Make SHOCKING Move Against Boy Selling Teddy Bear To Buy Food
# prediction: hungry
# 19 / 800
# title: Parents Discover A Secret Hidden In Adoptive Daughter’s Family Tree
# prediction: something was missing
# 20 / 800
# title: The one morning work mistake you can't recover from
# prediction: Rolling into the office around 9:30 a.m.
# 21 / 800
# title: Is It Safe To Take Melatonin Pills To Help You Fall Asleep?
# prediction: there also haven't been any good studies showing the long-term safety
# 22 / 800
# title: Why there will probably never be a "Dawson's Creek" reunion
# prediction: The Capeside gang
# 23 / 800
# title: Mom Is Pregnant With Twins. But 25 Weeks Later, Doctors Drop THIS Bombshell About Her Babies
# prediction: heartbreak
# 24 / 800
# title: Apple iOS 9.3.2 Has A Nasty Surprise
# prediction: Re-release a tweaked version of iOS 9.3.2
# 25 / 800
# title: State rep who likened food stamp recipients to wild animals loses Senate primary
# prediction: Rick Weiland
# 26 / 800
# title: You'll never believe how much these Instagram models make
# prediction: seven-figure salaries
# 27 / 800
# title: How distance brought an end to an NBA power couple that withstood conflicts of interest and professional trials:
# prediction: Jackson and Buss had to sign documents
# 28 / 800
# title: A Tourist Ignored a Museum's "Please Don't Touch" Sign, Guess What Happened Next
# prediction: flying off the wall and into pieces on the floor
# 29 / 800
# title: Taco Bell's Newest Menu Item Has One Ridiculous Ingredient That Will Leave You Questioning Everything
# prediction: Jalapeno Popper Quesarito
# 30 / 800
# title: Rebekah Brooks is back with Rupert Murdoch, and this time it's digital
# prediction: digital media
# 31 / 800
# title: Your favorite children's book illustrator just got his own exhibition in Chicago
# prediction: Edward Gorey
# 32 / 800
# title: Fashion brand lets models go un-Photoshopped and makeup-free
# prediction: Rag & Bone
# 33 / 800
# title: Jennifer Lawrence cuts off her long hair... and debuts Hollywood's biggest trend
# prediction: pixie cut
# 34 / 800
# title: The oven cleaning hacks that will have your appliance sparkling without ANY scrubbing
# prediction: a new series of kitchen hacks
# 35 / 800
# title: Lawmakers could do this to fight corruption. But they won’t.
# prediction: nothing happens
# 36 / 800
# title: He Rescued This Bizarre Creature From a Sidewalk, But He Had No Idea What It Would Grow Into
# prediction: a healthy adult squirrel
# 37 / 800
# title: 29 of the most beautiful TV quotes of all time
# prediction: 29
# 38 / 800
# title: Man admires the fence he repaired – now watch what happens just seconds later
# prediction: a large dog
# 39 / 800
# title: WHOA someone just paid $168000 for THIS
# prediction: Hope's antique cabinet
# 40 / 800
# title: 14 things that’ll happen in 2017 according to "The Simpsons"
# prediction: One day there will be a female president
# 41 / 800
# title: I was really bad at sports in high school. This new study helps me understand why.
# prediction: Some people are just better at sports than others
# 42 / 800
# title: Say it ain't so! Jon Stewart has set his official departure date from #TheDailyShow
# prediction: August 6th
# 43 / 800
# title: How big is Justin Bieber's dick really?
# prediction: grand outlier
# 44 / 800
# title: One word that should never follow "I love you"
# prediction: "but"
# 45 / 800
# title: If you've ever dreamed of getting up close and personal with a rocket launch, YOUR TIME IS NOW
# prediction: pads-eye view
# 46 / 800
# title: Three remain from the Class of '98.
#
# All three are legends.
# prediction: Vince Carter
# 47 / 800
# title: She Put Baking Soda On Her Toes... And Solved One Of Life’s Most Annoying Problems
# prediction: heartburn
# 48 / 800
# title: For The First Time In Its 126-Year History, This Newspaper Endorsed A Democrat
# prediction: The Arizona Republic
# 49 / 800
# title: Cancer is contagious among clams. What about us?
# prediction: I don’t think we should be starting to panic
# 50 / 800
# title: 1/3 of Americans believe this about the Syria conflict
# prediction: an indication that our days are numbered
# 51 / 800
# title: The horrible incident that cut my honeymoon short
# prediction: hitting a speed bump
# 52 / 800
# title: This Drug Could Add Five Years To Your Dog’s Life
# prediction: rapamycin
# 53 / 800
# title: ANOTHER Catholic university drops abortion coverage
# prediction: Loyola Marymount University
# 54 / 800
# title: College president to students: "This is not a day care. This is a university!"
# prediction: the cha
# 55 / 800
# title: How men can get the bedroom blues too
# prediction: they don’t show it
# 56 / 800
# title: She might be the only author to benefit from the Amazon-Hachette war thanks to Stephen Colbert
# prediction: Ms. Lepucki
# 57 / 800
# title: This NFL Player Slept in a Utility Closet in College to Save Money
# prediction: Tim Masthay
# 58 / 800
# title: Psychedelic drugs are not cocaine — here’s why that matters
# prediction: psychedelics may not be as dangerous and addictive
# 59 / 800
# title: What weighs 2032 pounds is orange and can be seen in New York this week?
# prediction: watermelon
# 60 / 800
# title: You won't BELIEVE how much Paris Hilton dropped on two teeny-tiny dogs!
# prediction: $40K for less than 2 pounds
# 61 / 800
# title: This Guy Put An Ice Cream Cone In His Pocket... Seconds Later, He Was In Handcuffs.
# prediction: 9
# 62 / 800
# title: How to completely banish stress in just THREE MINUTES
# prediction: there was a simple three-minute solution
# 63 / 800
# title: Lawmakers are going to punish university for not shutting down "Sex Week"
# prediction: the Tennessee state House has already passed a resolution
# 64 / 800
# title: The reason why this ex-basketball player got arrested will make you MAD!
# prediction: the suspect had planned to upload the sex videos
# 65 / 800
# title: One of the most ‘annoying things’ on the entire planet just turned 20
# prediction: Crazy Frog
# 66 / 800
# title: Explainer: Is There Any Science Behind Astrology?
# prediction: real science to support astrology
# 67 / 800
# title: This Is the First Thing Guys Notice About Women
# prediction: the derier
# 68 / 800
# title: The latest Hollywood baby name: Kaius
# prediction: Jagger Berman
# 69 / 800
# title: An unlikely company is crushing America's biggest clothing stores
# prediction: Amazon
# 70 / 800
# title: Shower Habits You Need To Stop Doing Immediately
# prediction: washing your face
# 71 / 800
# title: When People Ate People, A Strange Disease Emerged
# prediction: genetic
# 72 / 800
# title: Prevent Your Kids From Playing Near This Dangerous Common Plant That Can Kill Them
# prediction: Dieffenbachia
# 73 / 800
# title: Are lefties really more creative?
# prediction: Does being left-handed
# 74 / 800
# title: You Won't Believe What "Unknown Substance" Sent 7 Planned Parenthood Staffers to the Hospital
# prediction: baby food
# 75 / 800
# title: You'll Never Guess What (Or Who) Michael Douglass' Son Cameron Has Tattooed On His Abs
# prediction: Kirk
# 76 / 800
# title: The cancer-causing ingredient lurking in your beauty products:
# prediction: 1,4-dioxane
# 77 / 800
# title: The surprising thing that may be making you crave junk food
# prediction: gut bacteria
# 78 / 800
# title: What It Feels Like to Die
# prediction: half-dreaming, half-waking
# 79 / 800
# title: This state is NOT excited about legal weed
# prediction: Wyoming
# 80 / 800
# title: This company wants you to bring your dog to work
# prediction: Nvidia
# 81 / 800
# title: Here's Why Some Big Brand Names Are Suddenly Missing A's, B's And O's
# prediction: three key letters
# 82 / 800
# title: If Donald Trump were black, would the GOP base accept him? The answer is obvious.
# prediction: embraced Donald
# 83 / 800
# title: This is how much coffee Americans drinks every day
# prediction: 2.1
# 84 / 800
# title: Why this model is suing  for $1.5 BILLION
# prediction: their photos were used to make phony accounts
# 85 / 800
# title: Are Red Hot Chili Peppers Really 'The Worst Band In The Universe'?
# prediction: There’s no way
# 86 / 800
# title: Obama’s Female Staffers Came Up With a Genius Strategy to Make Sure Their Voices Were Heard
# prediction: amplification
# 87 / 800
# title: How Beats tricks you Into thinking it makes a premium product
# prediction: sneaky designers
# 88 / 800
# title: This Clever Trick Will Instantly Clear Your Lawn of Unwanted Leaves
# prediction: Brian Shreves
# 89 / 800
# title: This might be the darkest theory yet about why Donald Trump keeps winning
# prediction: fear of death
# 90 / 800
# title: The curious cases and unsolved #mysteries that perplexed us in #2016
# prediction: drugs, financial troubles, mental illness and "shared delusions".
# 91 / 800
# title: Ex-Cons Remember Their Worst Jobs After Being Released from Prison
# prediction: working on a cattle ranch as a utility farmer
# 92 / 800
# title: Verizon and AT&amp;T Don't Like This Internet Ruling, But Your Pocketbook Will
# prediction: Net neutrality
# 93 / 800
# title: Instead Of A Graduation Speech, This Teen Does THIS And Surprises Everyone!
# prediction: JP Wallace
# 94 / 800
# title: 'Star Wars: Episode 8' Working Titled Leaked
# prediction: Fall of the Resistance. Episode VIII to have the title Fall of the Resistance
# 95 / 800
# title: We've finally figured out when the moon formed
# prediction: 4.47 billion years ago
# 96 / 800
# title: Another country decriminalizes marijuana
# prediction: Switzerland
# 97 / 800
# title: You Should STOP Eating Baby Carrots for THIS Disturbing Reason!
# prediction: They are soaked in a bath of chlorine
# 98 / 800
# title: The iPhone 5C number Apple doesn't want you to know
# prediction: $465
# 99 / 800
# title: I Thought It Was Weird She Glued Pennies To Her Daughter’s Shoes, But When I Found Out Why? GENIUS!
# prediction: people don’t want to use pennies anymore
# 100 / 800
# title: GOP governor pressured to reveal secret donors
# prediction: Snyder
# 101 / 800
# title: President Obama won't end his vacation for one specific reason
# prediction: Because he believes he can monitor the situation
# 102 / 800
# title: The last utopia?
# prediction: New Zealand
# 103 / 800
# title: Well this is one way to get flawless skin
# prediction: a single swipe of face makeup
# 104 / 800
# title: Wow! This Company Pays For Employees' Weddings And Their Kids' College
# prediction: Boxed
# 105 / 800
# title: Just a slight flaw with this argument...
# prediction: both parties failed to reach a contractual agreement
# 106 / 800
# title: What's lurking in your white wine WILL scare you
# prediction: arsenic
# 107 / 800
# title: How much will JPMorgan pay for 'London Whale' losses?
# prediction: $700 million
# 108 / 800
# title: 5 reasons why no one has built a better EpiPen
# prediction: they’re not so user-friendly
# 109 / 800
# title: Here's what Donald Trump rejects when he undermines the election results
# prediction: the loser concedes to the winner
# 110 / 800
# title: Gwyneth Paltrow’s wellness philosophy, in 10 Quotes
# prediction: Her Change in Diet
# 111 / 800
# title: 25 Signs You’re Not In Your Early Twenties Anymore
# prediction: 16. You mix up Kendall and Kylie Jenner.
# 112 / 800
# title: 1-Minute Trick To Stop Headaches From Disturbing You On Busy Days
# prediction: 60 seconds
# 113 / 800
# title: 15 LGBTQ Celebrities You Didn’t Know Came Out In 2016
# prediction: 13
# 114 / 800
# title: Chris Brown has big plans for 2014
# prediction: his sixth studio album, "X," will hit stores on May 5
# 115 / 800
# title: Trouble in paradise? Rose Leslie doesn't want to work with Game Of Thrones beau Kit Harington again
# prediction: Rose Leslie
# 116 / 800
# title: Her Thug Boyfriend Scarred Her For Life, The Way She Responded Took GUTS.
# prediction: Chantelle
# 117 / 800
# title: 'Today' anchor makes not one but TWO huge announcements
# prediction: she set her wedding date before she found out she was having a baby
# 118 / 800
# title: After learning she didn't have long to live, she composed a dating profile for the man she'd leave behind
# prediction: Jason. Let’s add more about Jason
# 119 / 800
# title: This Ridiculously Simple Service Is Saving Canadian Drivers A Ton of Money
# prediction: EasyAuto123.com
# 120 / 800
# title: You favorite television show just got better
# prediction: Modern Family
# 121 / 800
# title: This Genius Pokémon Go Theory May Have Just Revealed Where You Can Find Mew
# prediction: Guyana
# 122 / 800
# title: Whoa eccentric basketball player is selling his very bizarre home
# prediction: Gilbert Arenas
# 123 / 800
# title: This guy went on a holiday with a group of total strangers for the greatest reason
# prediction: I think I can all my good friends
# 124 / 800
# title: 9 incredible photo stories you absolutely can’t miss
# prediction: 8
# 125 / 800
# title: Nine families raised children who all went on to extraordinary success. Here’s what they have in common
# prediction: drive, grit and social consciousness
# 126 / 800
# title: #NeverTrump Loses Another One - I'm Shocked And Trump's Cheering!
# prediction: #TrumpTrain
# 127 / 800
# title: This Republican mayor has an incredibly simple idea to help the homeless. And it seems to be working.
# prediction: Richard Berry
# 128 / 800
# title: Is this deadly drug becoming a problem in American schools?
# prediction: heroin epidemic
# 129 / 800
# title: This trailer will take your breath away
# prediction: Wowzer
# 130 / 800
# title: She Wraps A Piece Of Bread Around Her Foot. When She Takes It Off? SHOCKING!
# prediction: Castor Oil
# 131 / 800
# title: Traffic-weary homeowners and Waze are at war, again. Guess who’s winning?
# prediction: Waze
# 132 / 800
# title: 7 of the 10 Drunkest Cities in America Are All in a Single State
# prediction: Wisconsin
# 133 / 800
# title: Costco &amp; Sam's Club Recall Ham For The Most Disgusting Reason
# prediction: un-chewable portions were covered in pieces of rubber material
# 134 / 800
# title: The Moon Hasn't Done This In Nearly Half A Century
# prediction: full moon
# 135 / 800
# title: Sacha Baron Cohen and his wife donate $1 million to Syrian refugees
# prediction: London
# 136 / 800
# title: Does Sparkling Water Have a Downside?
# prediction: low acidity
# 137 / 800
# title: How much money did Paris Hilton make off her sex tape?
# prediction: never made a dollar
# 138 / 800
# title: Huge 'Jason Bourne' chase scene wrecked this many cars
# prediction: 170
# 139 / 800
# title: How this 27-year-old made $1 million last year:
# prediction: just shy of $1 million   $979,000
# 140 / 800
# title: This is what it actually means to be caught 'Doping' at the Olympics
# prediction: confusing mess
# 141 / 800
# title: The Ridiculously Simple Trick That'll Keep Your Food From Spoiling
# prediction: FIFO
# 142 / 800
# title: The best city for newlyweds is...
# prediction: Atlanta
# 143 / 800
# title: Kanpur Couple Called Off Their Wedding Because Of PM Narendra Modi. You'll Be Surprised To Know Why.
# prediction: they’re going to separate
# 144 / 800
# title: Six of Roald Dahl's made-up words have been added to the Oxford English Dictionary to celebrate his centenary
# prediction: Dahlesque
# 145 / 800
# title: Startling link between kidnapped teen's mom and suspect
# prediction: Maria Corral
# 146 / 800
# title: The most unexpected country that rocks at making olive oil
# prediction: Greece
# 147 / 800
# title: What does Brexit mean for UK Citizens who already booked Summer Holiday abroad?
# prediction: you're going to be a victim of Britain leaving the EU
# 148 / 800
# title: The ISIS Says It's Scared Of Only One Country And It's Not America Or Russia
# prediction: Israelis
# 149 / 800
# title: Oscar favorite latest name rumored for "Star Wars"
# prediction: Chiwetel Ejiofor
# 150 / 800
# title: The cutest little European city you've probably never heard of
# prediction: Lviv
# 151 / 800
# title: You Won’t Believe What Emma Roberts Has Done Now
# prediction: Roberts changed her clothes and her sunglasses, but not her braids
# 152 / 800
# title: Why 2017 is the year to visit Kathmandu
# prediction: There’s a compelling reason
# 153 / 800
# title: You've never heard the f-word this much in your entire life
# prediction: Slackstory
# 154 / 800
# title: This Puppy Just Howled For The First Time! Watch What His Proud Mom Does In Response!
# prediction: she joins in
# 155 / 800
# title: Click to hear about some of the things that have been keeping us busy. #2 will blow your mind.
# prediction: On the product side
# 156 / 800
# title: Temple University breaks world record for PB&amp;J sandwiches
# prediction: 49,100
# 157 / 800
# title: Legal weed sales halted in small town due to lack of staples
# prediction: lack of interest
# 158 / 800
# title: Here’s when the first 64 player multiplayer Battlefield 1 livestream is coming
# prediction: June 12
# 159 / 800
# title: 'Star Wars: The Force Awakens' Actress Opens Up About Painful Disorder
# prediction: endometriosis
# 160 / 800
# title: @LadyGaga and @RKelly team up
# prediction: Do What U Want
# 161 / 800
# title: 17 signs you are totally a caffeine mom
# prediction: 17
# 162 / 800
# title: President Trump? There’s only one way to stop it happening
# prediction: a vote for Clinton
# 163 / 800
# title: Just guess how much Mayweather spends on haircuts
# prediction: $1,000
# 164 / 800
# title: The Secret Reason Apple Might Be Killing the iPhone headphone jack
# prediction: to protect the next iPhone from the inevitable backlash
# 165 / 800
# title: Guess Who Amber Rose Wants to Be Her Next Baby's Father
# prediction: Wiz Khalifa
# 166 / 800
# title: Who knew @NickiMinaj's natural hair looked like this?
# prediction: No perm. No extensions
# 167 / 800
# title: Here’s what happens when schools let transgender students use the bathroom they want
# prediction: they made a change
# 168 / 800
# title: Adele's "Hello" video smashes YouTube record
# prediction: 1 billion views
# 169 / 800
# title: @HillaryClinton gets the advice she never asked for
# prediction: pantsuits
# 170 / 800
# title: 10 things you need to know before the opening bell
# prediction: The Fed is expected to hike rates
# 171 / 800
# title: How One Theory You Never Heard of Explains Everything Donald Trump Does
# prediction: Overton Window Theory
# 172 / 800
# title: BREAKING: This State Just Banned the Sale of ALL Semi-Auto Rifles, Effective Immediately
# prediction: Massachusetts
# 173 / 800
# title: One of the most useful iOS apps is finally back
# prediction: video-playing app is finally back in the App Store
# 174 / 800
# title: UFC Fighter Valentina Shevchenko Involved In Armed Robbery Shootout
# prediction: Chorrillos, Peru
# 175 / 800
# title: And the world's safest country in terms of homicides is...
# prediction: Liechtenstein
# 176 / 800
# title: Here's how long you can hold onto your cosmetics (via @GMA)
# prediction: two years
# 177 / 800
# title: The things you should never, ever do at a wedding
# prediction: Tacky
# 178 / 800
# title: How one man could have fathered 1000 kids
# prediction: if the ruler had sex about once a day for 32 years
# 179 / 800
# title: Customer reports cook with Down syndrome but was shocked when they discovered who he was
# prediction: the restaurant’s manager and co-owner
# 180 / 800
# title: We can't believe these are all under $100
# prediction: 19 warm sweaters
# 181 / 800
# title: 15 of the most powerful women in the weed industry
# prediction: Dr. Lakisha Jenkins
# 182 / 800
# title: Is There Really A 2 Billion-Year-Old Nuclear Reactor In Africa?
# prediction: An ancient nuclear reactor that was churning away 2 billion years ago
# 183 / 800
# title: How technology will bring loved ones back to life
# prediction: shaping how we grieve our loved ones if and when they die
# 184 / 800
# title: Breast cancer rates are on the rise among these women
# prediction: Black Women
# 185 / 800
# title: We found out what happens after you catch every Pokémon
# prediction: An international trip
# 186 / 800
# title: Sorry, Vegas. A new "world's largest hotel" is due to open in 2017. Find out where:
# prediction: Mecca, Saudi Arabia
# 187 / 800
# title: This is what happens when the government tries to grow weed. (Hint: It ain’t good.)
# prediction: looks like trash
# 188 / 800
# title: 5 things to know about presidential debate moderator Lester Holt
# prediction: Holt is a registered Republican
# 189 / 800
# title: The one thing you should never say to someone w/ OCD
# prediction: don't respond
# 190 / 800
# title: The Top 5 Free and Open Source Inventory Management Software Systems
# prediction: All of these systems can manage most small business inventory requirements
# 191 / 800
# title: The first photos from the reboot are here.
# prediction: Lara Croft: Tomb Raider
# 192 / 800
# title: This is how most college students actually use Tinder
# prediction: college
# 193 / 800
# title: Apparently All Taylor Swift and Tom Hiddleston Do Is...
# prediction: Take Walks on Beaches
# 194 / 800
# title: The four-letter word NO woman wants to hear
# prediction: ma'am."
# 195 / 800
# title: What Julia Roberts thinks of Jennifer Lawrence
# prediction: fabulous
# 196 / 800
# title: NASA just announced something big
# prediction: its next Mars rover, dubbed Mars 2020
# 197 / 800
# title: Why cars went from boxy in the '80s to curvy in the '90s
# prediction: exteriors have only become curvier
# 198 / 800
# title: The money-making secrets that rich people swear by
# prediction: Alan Andrews
# 199 / 800
# title: This 'sad' advice a male VC just gave to women in tech couldn't be more wrong
# prediction: only use their first initial and eliminate photos on both Twitter and LinkedIn
# 200 / 800
# title: 23 facts that will totally fuck with your perception of time
# prediction: Everything you see happened in the past
# 201 / 800
# title: Scientists say this behavior can make men more attractive to women
# prediction: altruism
# 202 / 800
# title: Is It Ethical to Kill Poachers?
# prediction: moral
# 203 / 800
# title: People confess the reasons they regret getting married
# prediction: selfish to the truly heartbreaking
# 204 / 800
# title: You won't believe what Samir Nasri has done to support Man City ahead of the League Cup final
# prediction: dying his hair sky blue
# 205 / 800
# title: Vincent Kompany makes OUTRAGEOUS Eden Hazard claim following Belgium's win over Hungary
# prediction: Ronaldo and Messi
# 206 / 800
# title: How AI could stop those awkward moments when your credit card is mistakenly declined
# prediction: MasterCard has now turned to artificial intelligence
# 207 / 800
# title: Here's Why We Wake Up With Gross Eye Gunk in the Morning
# prediction: we all get it
# 208 / 800
# title: A Bully Pours Super Glue In Her Hair, But What She Does Next Shocks Them All...
# prediction: cut her hair
# 209 / 800
# title: 8 things that will be more expensive next month
# prediction: warm coats, long pants, boots and sweaters
# 210 / 800
# title: Why Women Are No Longer Catching Up To Men On Pay
# prediction: women have actually lost ground to men in computer science in recent decades
# 211 / 800
# title: She Pours Listerine Onto Cotton And Dabs It On Her Armpit. Minutes Later? WHOA...
# prediction: mouthwash
# 212 / 800
# title: She Adopted This Cat From The Humane Society But Had No Idea He Could Do This
# prediction: potty trained
# 213 / 800
# title: @AnnCoulter won't stop ranting about this
# prediction: Hispanic voters
# 214 / 800
# title: Why a South Carolina man got bail after he shot, buried and ‘slow-cooked’ two people
# prediction: the prosecution was moving forward in its case against Loftis
# 215 / 800
# title: Why has this photo gone viral online?
# prediction: concern over lack of women at the table
# 216 / 800
# title: People Don’t Think Biting The Skin Around Their Nails Is Bad... Until They Learn The Horrible Truth.
# prediction: Some people are so compulsive
# 217 / 800
# title: Is THIS the world's deadliest toxin?
# prediction: type H" is so dangerous
# 218 / 800
# title: Former RHOBH star Adrienne Maloof 52 explains her 24-year-old BF
# prediction: Sean Stewart
# 219 / 800
# title: FUNBAG! What's better summer sex or winter sex?
# prediction: Summer
# 220 / 800
# title: Top conservative challenges GOP to "declare peace on the safety net"
# prediction: Arthur Brooks
# 221 / 800
# title: 17 ways to trick people into thinking you’re cool
# prediction: 15
# 222 / 800
# title: What happened when a professor built a chatbot to be his teaching assistant
# prediction: Jill reached the point where its answers were good enough
# 223 / 800
# title: Watch as a romantic waterfall wedding proposal goes horribly wrong
# prediction: Cunningham Falls
# 224 / 800
# title: Ever Wondered What These White Lines On iPhones Mean?
# prediction: Apple
# 225 / 800
# title: Do you need a gym nanny to make you exercise (and we don't mean a trainer)?:
# prediction: you can hire a gym babysitter
# 226 / 800
# title: The names of the women 'most likely' to get pregnant in 2017
# prediction: 1. Jessica
# 227 / 800
# title: Guess what Mark Zuckerberg wore on the new Vanity Fair cover
# prediction: grey tee and blue jeans
# 228 / 800
# title: Filming The Newest Game Of Thrones Was Way More Brutal Than It Looked
# prediction: arington
# 229 / 800
# title: BBC Micro Bit computer becomes a commercial product
# prediction: element 14
# 230 / 800
# title: New Battle Brews Over Bundy's Cattle In The Nevada Desert
# prediction: tortoise
# 231 / 800
# title: 10 things you need to know before the opening bell
# prediction: Sears reports
# 232 / 800
# title: Here's Why This Guy Is One Of Tinder's Most Right Swiped Men
# prediction: Andy Mizrahi
# 233 / 800
# title: This company wants to solve all your scanning and filing problems
# prediction: Ripcord
# 234 / 800
# title: 200-foot sinkhole swallows 12 buildings
# prediction: China's Sichuan Province
# 235 / 800
# title: Antibiotics will soon 'stop working'
# prediction: Urgent action is needed to control the use of antibiotics
# 236 / 800
# title: There was one very important thing missing from the Marco Rubio pancake breakfast:
# prediction: pancakes
# 237 / 800
# title: You’ll never believe how much Kim Kardashian’s morning skincare routine costs
# prediction: More
# 238 / 800
# title: Who’s The Biggest Khan In Bollywood? He Is
# prediction: Salman is a bigger star than me. I think Shah Rukh
# 239 / 800
# title: Is there a better way to observe Veteran's Day?
# prediction: two minutes of silence
# 240 / 800
# title: Ideas about how to bridge the gender gap on pay.
# prediction: affordable child care, paid sick days and parental leave
# 241 / 800
# title: When's the best time to share on Facebook?
# prediction: between 11am and 4pm
# 242 / 800
# title: Here Is the World's Ugliest Color (& It Has an Important Job) — Design News
# prediction: Pantone 448 C
# 243 / 800
# title: Kelsey Grammer reveals the secret origin of Sideshow Bob’s voice
# prediction: flamboyant voice
# 244 / 800
# title: Does Sean Bean Really Die More Than Other Actors?
# prediction: a walking spoiler alert
# 245 / 800
# title: God hates gays...who own chandeliers? This company seems to think so
# prediction: Ivory & Deene
# 246 / 800
# title: How to Enjoy the World’s Most Luxurious Hotels, Without Paying to Spend the Night
# prediction: Wood-paneled walls and studded leather barstools
# 247 / 800
# title: This teenager used to walk miles to work to take care of his mother, then everything changed
# prediction: Derrick Taylor
# 248 / 800
# title: The one place this Google executive won't take her phone
# prediction: 90 minutes
# 249 / 800
# title: SalesforceVoice: 3 ways to make your company more sales intelligent
# prediction: 1. Emphasize productivity
# 250 / 800
# title: North America is so cold right now this happened
# prediction: 1kIv0YvKp5
# 251 / 800
# title: Why this runner might use a breast pump before the Olympic Trials
# prediction: I didn’t
# 252 / 800
# title: Is this a duck or a rabbit?
# prediction: rabbit
# 253 / 800
# title: Michael Bennett reveals who he thinks the best player to play for Texas A&amp;M
# prediction: Ryan Tannehill
# 254 / 800
# title: Is John Krasinski Down for Bringing 'The Office' to the Big Screen?
# prediction: I’d do it
# 255 / 800
# title: "To look up out at this kind of creation and not believe in God is to me impossible."
# prediction: It just strengthens my faith
# 256 / 800
# title: This is how much a gold medal from #Rio2016 is really worth:
# prediction: $564
# 257 / 800
# title: Chewbacca Mom Shares REAL Reason Her Video Blew Up The Internet
# prediction: Candace
# 258 / 800
# title: People with this personality type may be happier and more successful
# prediction: realistic optimists
# 259 / 800
# title: This GOP lawmaker does NOT approve of students wearing pro-gay shirts
# prediction: Kevin Elmer
# 260 / 800
# title: 33 Things That Have Happened In The Harry Potter Universe Since The Series Ended.
# prediction: 20/33. Azkaban no longer uses Dementors as guardians
# 261 / 800
# title: The Secret iPhone 7 Weaknesses Apple Doesn't Want You to Know
# prediction: avant-garde British flautists
# 262 / 800
# title: This Trend Is Perfect For People Who Can't Paint Their Own Nails
# prediction: aerosol-based nail polishes
# 263 / 800
# title: Body language expert reveals nine ways to spot a liar
# prediction: hands or feet
# 264 / 800
# title: 35 Celebrities That Support Donald Trump (Number Six Will Surprise You A Lot)
# prediction: 35) Roseanne Barr
# 265 / 800
# title: Alarming find in kids' blood forces Michigan city to declare state of emergency
# prediction: lead
# 266 / 800
# title: Find out the reason why Manny Pacquiao decided to unretire from boxing
# prediction: boxing helped him provide for his family
# 267 / 800
# title: #ICYMI: Top #entertainment stories from the day that was
# prediction: Bengaluru Mass Molestation
# 268 / 800
# title: This is the best time to drink coffee
# prediction: 9 a.m.
# 269 / 800
# title: Is North Korea Behind Bank Heists?
# prediction: a hacking group in North Korea
# 270 / 800
# title: 'Worst' charity for veterans run by VA employee
# prediction: telemarketers
# 271 / 800
# title: He carried the flag the entire race.
# prediction: Sgt. Sanchez
# 272 / 800
# title: DMX arrested again
# prediction: DMX, whose real name is Earl Simmons
# 273 / 800
# title: #Pratyusha's former boyfriend #RahulRaj thinks this is a publicity stunt
# prediction: Rahul
# 274 / 800
# title: Why it's definitely worth it to get your flu shot
# prediction: experts agree it was the right call
# 275 / 800
# title: Author Says This Behavior Predicts Infidelity In A Relationship From Day One
# prediction: before a wedding even takes place
# 276 / 800
# title: BAD NEWS for workaholics
# prediction: your health may be suffering because of it
# 277 / 800
# title: Overwatch Has a Secret Character And She’s Going To Be Revealed Soon
# prediction: Sombra
# 278 / 800
# title: And the US state with the largest average penis size is...
# prediction: Utah
# 279 / 800
# title: Hollywood didn't want to make this Vin Diesel movie
# prediction: handmade than factory-made
# 280 / 800
# title: A bit of debris chipped the International Space Station. That’s just one piece of a much bigger problem
# prediction: paint
# 281 / 800
# title: Tim Tebow may not be the best quarterback on the Eagles' roster, but he has something that might help him succeed.
# prediction: zone-read specialist
# 282 / 800
# title: @iamdiddy lost HOW MUCH to Rick Ross playing Craps?!
# prediction: one million dollars
# 283 / 800
# title: Man Purchases Harley-Davidson Motercycle. His reason is unbelievable!...
# prediction: to cut down on his perceived duty to wave to other motorcyclists
# 284 / 800
# title: Target in PANIC after getting terrible news
# prediction: American Family Association’s boycott
# 285 / 800
# title: 1 congressman did something major for 2 little girls who needed a family
# prediction: made a family whole again by welcoming two twin girls into his home
# 286 / 800
# title: Nerd Wins Scrabble with word you've never heard of
# prediction: Braconid
# 287 / 800
# title: You won't believe how much money 'Chewbacca Mom' has made since video went viral
# prediction: $420,000
# 288 / 800
# title: Bernie Sanders Makes MAJOR Announcement To His Entire Staff And Followers (QUOTES)
# prediction: laying off
# 289 / 800
# title: You'll never guess what's for sale on eBay right now
# prediction: Vintage Home Finds.
# 290 / 800
# title: These are the most polluted cities in the world
# prediction: Jodhpur, India
# 291 / 800
# title: Guess which famous Andy Warhol painting could fetch $60 million this fall
# prediction: Coca-Cola
# 292 / 800
# title: You Should NEVER Line The Toilet Seat With Paper. The Reason? SHOCKING!
# prediction: Toilet paper, unlike toilet seats, are not designed to ward off bacteria
# 293 / 800
# title: Man Uses Lions At Zoo To Commit Suicide, But All Goes Horribly Wrong
# prediction: lions as vehicles for a quick suicide, but they ended up becoming the victims
# 294 / 800
# title: Here’s the secret way people are using Snapchat Spectacles.
# (Hint: sex)
# prediction: you have to be naked
# 295 / 800
# title: Rihanna's new Star Trek Beyond music video will make history tomorrow
# prediction: Thursday, June 30
# 296 / 800
# title: How Trump could win.
# prediction: with a smile from Fortuna
# 297 / 800
# title: A Very Special Baby Was Just Born In Indonesia, And People Still Can’t Believe He’s Real.
# prediction: Mama Ratu
# 298 / 800
# title: Yes, Donald Trump Won Latinos Over Marco Rubio and Ted Cruz. Here’s Why.
# prediction: Trump got an astounding 44 percent
# 299 / 800
# title: Pulitzer Prize makes major change
# prediction: broadened eligibility in feature writing and investigative reporting to include online and print magazines
# 300 / 800
# title: And the candidate who spoke the most at the #GOPDebate is ...
# prediction: Ted Cruz
# 301 / 800
# title: Scientists Now Know What Really Wiped Out Dinosaurs
# prediction: a massive asteroid
# 302 / 800
# title: She’s Over-Weight And Wants To Gain More Weight, Then Mom Does This! Shocking!!
# prediction: Caitlin Finley
# 303 / 800
# title: According To This Study, Drinking Fizzy Drinks Can Have A Disturbing Effect On Your Penis
# prediction: reduce a man’s sperm count by as much as thirty percent
# 304 / 800
# title: You Won’t Believe What 11-Time Olympic Medalist Ryan Lochte Eats for Dinner Every Friday
# prediction: pizza, chicken wings, and a Mountain Dew
# 305 / 800
# title: What are the biggest risks the world faces in 2017?
# prediction: Weak economic growth, rising inequality, wild weather, data fraud
# 306 / 800
# title: Where "Kanye West" is more popular than "Jesus Christ"
# prediction: 4,541,349 mentions
# 307 / 800
# title: So, don't be a cheat. Because, Science
# prediction: infinitely
# 308 / 800
# title: This is the most common birthday in the world
# prediction: September 16
# 309 / 800
# title: Big praise from the boss: The Arsenal icon Granit reminds me of
# prediction: a former midfielder
# 310 / 800
# title: She Glues Rope On An Old Tire Her Next Step Turns It Into Something I Want To Have In My House!
# prediction: ottoman
# 311 / 800
# title: What Mark Stoops said after Kentucky's loss to Southern Mississippi
# prediction: post-game presser
# 312 / 800
# title: Here's how Jason Statham has managed to stay ripped all these years
# prediction: strict diet, as well as a strict workout regime
# 313 / 800
# title: What A Man Did With His Useless Attic Is Unbelievable
# prediction: converted it into a boat's cabin
# 314 / 800
# title: On the fence about going out tonight? Here:
#
# 15 great excuses to not go out tonight:
#
# (You're welcome.)
# prediction: some good ideas
# 315 / 800
# title: What Juan Gabriel Said When Asked If He Was Gay Will Blow You Away
# prediction: "Art is feminine...
# 316 / 800
# title: This Woman Reacted to Her New Racist Workplace Dress Code in the Best Possible Way
# prediction: June J Rivas
# 317 / 800
# title: This bot has saved users $250 million, and it's coming to Facebook messenger
# prediction: If users get more specific about what they are saving for
# 318 / 800
# title: Teacher Reveals The Sexts And Love Notes That Led To Affair With Pupil
# prediction: selfies
# 319 / 800
# title: He Pokes His Phone With A Knife. What Happens Next Made Me Jump Out Of My Seat
# prediction: explode into flames
# 320 / 800
# title: It's Official: We're Going to Mars
# prediction: send men to Mars
# 321 / 800
# title: 29 Years Ago, Lynyrd Skynyrd Inspired THIS Band's Biggest Hit - You Won't Believe Who It Is!
# prediction: Rose
# 322 / 800
# title: BREAKING: WikiLeaks Founder Reveals Hillary Clinton's Way To Promote Her Presidential Campaign
# prediction: Google
# 323 / 800
# title: Here’s who professional gamblers are betting will become president
# prediction: Donald Trump and Hillary Clinton
# 324 / 800
# title: This Old Woman Sat Down At A Piano At The Bus Stop. What She Does Next? CHILLS!
# prediction: disappearing
# 325 / 800
# title: Beloved TV cartoon character races onto game consoles
# prediction: El Chavo del Ocho
# 326 / 800
# title: This 28-year-old retired with a $2 million net worth. Here's how she's investing in 2017:
# prediction: investment strategies
# 327 / 800
# title: How many millions did The Interview make online this weekend?
# prediction: over $15 million
# 328 / 800
# title: Why You Shouldn't Scare Your Cat With a Cucumber
# prediction: since your pet usually has positive associations with the space surrounding its food bowl
# 329 / 800
# title: Why J. K. Rowling Endorsed ‘Harry Potter and the Cursed Child’ for the Stage
# prediction: makes you desperate for more story
# 330 / 800
# title: What is the easiest way to quit smoking?
# prediction: hypnotherapy
# 331 / 800
# title: Born in a ‘Small Town’: How John Mellencamp Wrote the Song
# prediction: as a valentine
# 332 / 800
# title: Famous crime writer's home is up for grabs...interested?
# prediction: fan
# 333 / 800
# title: This island paradise is slowly being consumed by nature
# prediction: Monserrat
# 334 / 800
# title: LeBron reveals his secret motivation
# prediction: someone in Miami
# 335 / 800
# title: CEO gives back his entire $2 million bonus to company
# prediction: Plum Creek Timber's CEO Rick Holley
# 336 / 800
# title: Don't skip! She has a very important message for you. #Oscars #Oscar2017
# prediction: Brandon Maxwell
# 337 / 800
# title: Mom Who Beat Her Toddler To Death Just Learned A Painful Lesson Of The Term Prison Justice
# prediction: Kathryn Smith
# 338 / 800
# title: Guess how much money Bill Gross made last year? Exclusive by @ritholtz:
# prediction: $290 million
# 339 / 800
# title: Facebook Is Building Apartments Anyone Can Rent—But There's a Huge Catch
# prediction: the general public
# 340 / 800
# title: Skinny Jeans May Look Great But It Could Do This To Your Body. Shocking!
# prediction: stopped the blood flow in her calf muscles
# 341 / 800
# title: The most life-affirming TV episode of the year came from the most unexpected place
# prediction: San Junipero
# 342 / 800
# title: A creepy man in his underwear will remain on the campus of a women's college
# prediction: oot3yGbgJw
# 343 / 800
# title: Ticking time bomb
# prediction: Padmanabhan
# 344 / 800
# title: This woman saved a man’s life on their first date
# prediction: Janine Hall
# 345 / 800
# title: This Barista Had The Best Response When A Customer Asked To Be Served By A White Person
# prediction: I told her] ‘that’s fine’,
# 346 / 800
# title: Something Makes This Grandmother Run Out in the Rain...When You See Why, It Will Make You Cry!
# prediction: little girl says something so profound that it changes the mother’s mind
# 347 / 800
# title: You won’t believe how this Game of Thrones snow art was made
# prediction: trudged through 32.5km of heavy Alpine snow
# 348 / 800
# title: This Veteran Boiled Toilet Paper When She Was At Her Lowest. When You See Why, It's Incredible.
# prediction: believe
# 349 / 800
# title: Watch What Happens When You Try to Steal a Rolls Royce's Hood Ornament
# prediction: retract and disappear
# 350 / 800
# title: #SelenaGomez rates herself a WHAT on the hotness scale?!
# prediction: up and up
# 351 / 800
# title: What No One Tells You About Marriage
# prediction: Marriage is fucking hard
# 352 / 800
# title: There's A Brexit-Inspired Erotic Novel And It's Officially Gone Too Far
# prediction: Pounded by Pound
# 353 / 800
# title: 3 reasons why half of American workers are not using their vacation time
# prediction: many U.S. workers feel bound to their jobs
# 354 / 800
# title: You Won't Believe Who Khloe Kardashian Is Hooking Up With Now
# prediction: Trey Songz
# 355 / 800
# title: Blue Angel pilot decided not to eject to do something incredibly heroic
# prediction: save lives of people on the ground
# 356 / 800
# title: We bet this hot new home trend will surprise you
# prediction: mediation gardens
# 357 / 800
# title: Six of the last seven times this happened, stocks rose
# prediction: the index drop in the fourth
# 358 / 800
# title: The seven simple money-saving hacks that could save you THOUSANDS a year
# prediction: your receipts
# 359 / 800
# title: Why Rio ratings are terrible
# prediction: big defections among millennial audiences
# 360 / 800
# title: You won't believe what these benches are made from
# prediction: brick
# 361 / 800
# title: Poll shows what Americans think of Obama-Rouhani phone call
# prediction: 48 percent of Americans approve
# 362 / 800
# title: This herb could be the secret to curbing cows’ climate-changing burps
# prediction: Oregano
# 363 / 800
# title: Why Russia has two St. Patrick’s days this year
# prediction: many religious Russians abstain from alcohol
# 364 / 800
# title: Why Brock Turner Is Not Actually A Rapist
# prediction: Under English law
# 365 / 800
# title: This is the Secret to the Insane BLT at Tom Colicchio's New Sandwich Shop
# prediction: five minutes as opposed to 12-13 minutes
# 366 / 800
# title: The interesting thing that happened when Kansas cut taxes and California hiked them
# prediction: California grew just fine
# 367 / 800
# title: Austin couple upset with description on IHOP receipt
# prediction: BLACK PPL
# 368 / 800
# title: Well this is awkward (PHOTOS)
# prediction: how many women we spotted wearing the exact same outfit
# 369 / 800
# title: There's A £20,000 House Up For Sale But There's A Catch
# prediction: you can only live there for ten months out of the year
# 370 / 800
# title: Mayor's husband busted for allegedly selling meth
# prediction: Ruben Guerrero
# 371 / 800
# title: You Won’t Believe the Food That Has Quickly Replaced Tobacco as The Most Popular Currency in US Prisons
# prediction: Ramen
# 372 / 800
# title: A member of the X-Men just came out of the closet
# prediction: Benjamin Deeds
# 373 / 800
# title: Cynthia Nixon reveals a shocking fact about those "SATC" sex scenes
# prediction: IMDB Asks
# 374 / 800
# title: O.J. Simpson allegedly had an affair with this 1980s music video vixen
# prediction: Tawny Kitaen
# 375 / 800
# title: And the richest state in the country is...
# prediction: Maryland
# 376 / 800
# title: This might be the most energizing afternoon routine (it's not more coffee)
# prediction: going for a walk
# 377 / 800
# title: Boy dies after playing new 'game' all the kids are playing
# prediction: The Choking Game
# 378 / 800
# title: You probably know to ask yourself, "What do I want?" Here’s a way better question
# prediction: the reward
# 379 / 800
# title: It turns out you've probably been watching Netflix wrong for years
# prediction: once you’ve made the switch
# 380 / 800
# title: Paul Feig Reveals Character Names for the New 'Ghostbusters'
# prediction: Erin Gilbert, Jillian Holtzmann, Abby Yates and Patty Tolan
# 381 / 800
# title: The secret reason so many men go to the gym
# prediction: fears about body fat
# 382 / 800
# title: You'll Never Believe How This Woman Won $1 Million in Just 8 Seconds
# prediction: Cynthia
# 383 / 800
# title: Here’s The ‘No. 1’ Thing You Didn’t Know About Katy Perry
# prediction: hungry
# 384 / 800
# title: @JustinBieber goes by a different name now
# prediction: Bizzle
# 385 / 800
# title: Gene Wilder Agreed To Play Willy Wonka Under This One Condition
# prediction: no one will know if I’m lying or telling the truth
# 386 / 800
# title: Bones discovered in river believed to be 1000 years old
# prediction: Coln River
# 387 / 800
# title: The strange word everyone is saying/texting
# prediction: slash
# 388 / 800
# title: Country singer delivers EPIC slam to Westboro Baptist Church protesters
# prediction: Vince Gill
# 389 / 800
# title: Michael Jackson Fans Think He's Alive and They've Got Proof
# prediction: Michael Jackson is still alive
# 390 / 800
# title: Are Shorter Work Days Better For Your Health &amp; Productivity?
# prediction: a shorter work day may actually result in more productivity
# 391 / 800
# title: I was behind the wheel when a self-driving Uber failed — here's what happens
# prediction: not everything went according to plan
# 392 / 800
# title: [The Guardian] Why did Croatia fans disrupt their Euro 2016 match against Czech Republic?
# prediction: fed up with them
# 393 / 800
# title: 3 Things To Know About the Future of Virtual Reality
# prediction: Virtual reality will get more physical
# 394 / 800
# title: "Mandela" movie gets a TV premiere date
# prediction: Mandela: Long Walk to Freedom
# 395 / 800
# title: Tragic Details Of Kimbo Slice's Death Have Been Released
# prediction: Details
# 396 / 800
# title: Boeing is making a major change to its planes that could solve the biggest problem with air travel
# prediction: jet lag
# 397 / 800
# title: Here’s Why Blizzard Is Already Banning Thousands Of Overwatch Players
# prediction: cheating
# 398 / 800
# title: Nine of the weirdest Easter traditions happening right now around the world
# prediction: hot cross buns and egg hunts
# 399 / 800
# title: He created a database to "figure out what the government really does with the money." What he found surprised him
# prediction: What really happens?"
# 400 / 800
# title: He Tackles A Nurse At The Hospital. Then You See What's On The Floor Next To Them...
# prediction: balloons
# 401 / 800
# title: Why you SHOULD be selfish at work
# prediction: selfless people suffer most in workplaces
# 402 / 800
# title: The one strange trick that will make you live longer
# prediction: Meditating inside a beautiful stock-photo room filled with plants
# 403 / 800
# title: Nerd Wins Scrabble Championship With Word You’ve Never Heard Of
# prediction: Braconid
# 404 / 800
# title: The bizarre new way to eat eggs that has everyone going crazy
# prediction: grating
# 405 / 800
# title: The perfect playlist to listen to on "Star Wars" Day
# prediction: John Williams music
# 406 / 800
# title: Things people do for a good night #sleep!
# prediction: anything it takes to get your rest
# 407 / 800
# title: Why You Should Never Pet A Service Dog
# prediction: working dogs should never be pet or played with while they're working
# 408 / 800
# title: The First Person In The Royal Family Has Just Come Out As Gay
# prediction: Lord Ivar Mountbatten
# 409 / 800
# title: A man who retired at 34 explains one bad savings habit that everyone should avoid
# prediction: obsessed with it that they isolate themselves
# 410 / 800
# title: The Annoying Question No Mom Wants to Hear When She Goes on Vacation
# prediction: Who is watching your kids?"
# ...
# prediction: Watermelon seeds
# 662 / 800
# title: Here’s who Warren Buffett thinks should be the next Fed chairman
# prediction: Ben Bernanke
# 663 / 800
# title: Coming this fall
# prediction: Jordan Klepper
# 664 / 800
# title: 1 Reason Not To Go Online If You Live In The U.S.
# prediction: 3 click step
# 665 / 800
# title: You'll Never Guess What Else Gives You The Munchies
# prediction: marijuana
# 666 / 800
# title: Final episodes of "Breaking Bad" will be on @Netflix way sooner than you thought
# prediction: Feb. 24
# 667 / 800
# title: Is It Safe to Drink Blood?
# prediction: In very small amounts
# 668 / 800
# title: If you're a millennial couple, chances are you flat-out ROCK at this
# prediction: 49%
# 669 / 800
# title: "I’d never heard of this condition until the terrible joint pain set in."
# prediction: Neither had I
# 670 / 800
# title: How the Chicago Cubs won Game 7
# prediction: inning-by-inning
# 671 / 800
# title: How To Play Pokémon Go In Your Car Without Mowing Down Trees Or People
# prediction: unless your car is safely parked, and out of the way of other traffic
# 672 / 800
# title: Did You Know The Lids From Plastic Cups Were Made To Do This?
# prediction: a drink coaster
# 673 / 800
# title: The worst gift to give this Christmas
# prediction: ...and the gift isn’t always so well received
# 674 / 800
# title: Matt Damon once asked Prince where he lived, got the most Prince answer imaginable
# prediction: Minnesota
# 675 / 800
# title: Scarlett Johansson could make Oscar history
# prediction: Best Supporting Actress
# 676 / 800
# title: All Blue-Eyed People Have This One Thing In Common
# prediction: every blue-eyed person alive today has this same mutation
# 677 / 800
# title: A mother hears her dead son's heart beat
# prediction: Dawn Grace
# 678 / 800
# title: What No One Tells You About Going Platinum (Blonde)
# prediction: questions
# 679 / 800
# title: The fascinating tradition that sets baseball apart
# prediction: humor, sportsmanship and love of tradition
# 680 / 800
# title: The Crazy Cooking Hack that Slashes the Calories in Rice by Half
# prediction: coconut oil
# 681 / 800
# title: If You Ever See Your Cat Doing This, They’re Trying To Tell You Something Very Important.
# prediction: The higher they carry it
# 682 / 800
# title: If You See This In A Public Washroom LEAVE Immediately And Call 911.
# prediction: spy camera
# 683 / 800
# title: How to vacation like Taylor Swift, Madonna and more of the world's wealthiest celebs:
# prediction: travel in style
# 684 / 800
# title: This U.S. city is welcoming veterans with an innovative new program
# prediction: Louisville
# 685 / 800
# title: CNN caught ADDING key word to Trump's comments;Twitter ERUPTS
# prediction: racial profiling
# 686 / 800
# title: So THAT'S Why Men And Women Take Their Shirt Off Differently
# prediction: Men, however, just reach behind their neck
# 687 / 800
# title: Game of Thrones: Did you catch this subtle change during the finale?
# prediction: Did you miss it
# 688 / 800
# title: The eyeshadow color redheads should be wearing is...
# prediction: next spring
# 689 / 800
# title: "He is just a humongous human being that has out-of-this-world power. 550 feet is not out of the question."
# prediction: If there is nothing in the way
# 690 / 800
# title: The 20 cities with the world's lowest cost of living  via @YahooFinance
# prediction: 445
# 691 / 800
# title: According To Science, This Is The Most Addictive Food In The World
# prediction: pizza
# 692 / 800
# title: 8 countries where $200,000 in retirement savings will last 30 years
# prediction: Thailand
# 693 / 800
# title: The terrifying way not sleeping enough actually changes your gut
# prediction: bacteria
# 694 / 800
# title: 9 ways the new "Beauty and the Beast" is different from the original
# prediction: highly educated
# 695 / 800
# title: @MileyCyrus strips down in an entirely different way
# prediction: unmentionables
# 696 / 800
# title: The magic word this researcher says can get people to agree with you
# prediction: moral
# 697 / 800
# title: Why Buffy the Vampire Slayer was the best possible name for that show
# prediction: it captured the exact spirit of what he was planning to make
# 698 / 800
# title: This chain will give you free burgers for life, but on one condition
# prediction: Mr Burger
# 699 / 800
# title: Stop eating this food immediately! It causes 4 types of cancer!
# prediction: Hot dogs
# 700 / 800
# title: "Twilight" star reveals his latest obsession
# prediction: Breaking Bad."
# 701 / 800
# title: Marvel star jokes about alien sex because why not?
# prediction: A couple
# 702 / 800
# title: Looking for a job that doesn’t stress you out? Here are the best ones in 2017:
# prediction: 10
# 703 / 800
# title: The 10 Professions With the Most Psychopaths
# prediction: CEO
# 704 / 800
# title: Did You Know That This Plant From Your Garden Can Treat Hair Loss?
# prediction: You may not even be aware
# 705 / 800
# title: In case you're interested here is Scarlett Johansson's SAT score
# prediction: 1,080
# 706 / 800
# title: Look who just launched a new free streaming-music service:
# prediction: Google
# 707 / 800
# title: From chili to mustard, how to turn 8 classic ingredients into bulge-beating superfoods
# prediction: flakes or cayenne powder
# 708 / 800
# title: Bernie Sanders' Secret Service code name is...
# prediction: Intrepid
# 709 / 800
# title: REVEALED: People who POOP at this time of day are healthiest
# prediction: MORNINGS
# 710 / 800
# title: This university has more NCAA championships than black male freshmen
# prediction: UCLA
# 711 / 800
# title: If you leave your kids alone, it’s not predatory strangers who are a risk
# prediction: people who think they’re doing good
# 712 / 800
# title: Battlefield 1 might have a hilarious new game mode that sounds crazy
# prediction: Pigeon
# 713 / 800
# title: .@priyankachopra said what?😮🤣
# prediction: you don't wanna f*ck w/ the Avengers of the Beach
# 714 / 800
# title: "Dallas" Season 3 premiere date revealed
# prediction: February 24
# 715 / 800
# title: Here's exactly how much sleep you need to remain healthy
# prediction: three hours of sleep a night
# 716 / 800
# title: How @taylorswift13 really found @TeganandSara
# prediction: By watching the trailer for "G.B.F."
# 717 / 800
# title: When This Animal Shelter Asked Pokémon Go Players To Walk Their Dogs, They Didn’t Expect This
# prediction: Muncie
# 718 / 800
# title: Donald Trump calls Ted Cruz the p word
# prediction: pussy
# 719 / 800
# title: "We have already authorized this, meaning the law was passed almost 10 years ago."
# prediction: Ryan said.
# 720 / 800
# title: Expect Hillary to do this almost immediately if she wins in November
# prediction: new wars in the Middle East
# 721 / 800
# title: Ex-NFL player suspected in the death of his cellmate
# prediction: Lawrence Phillips
# 722 / 800
# title: And the best interior in the world is...
# prediction: Carrer Avinyó,
# 723 / 800
# title: The First Person to Capture All 142 Pokémon Just Got the Gift of a Lifetime
# prediction: Nick Johnson
# 724 / 800
# title: A Complete Stranger Saved This Mom and Her 4 Kids but Wanted 1 Major Thing in Return
# prediction: a completely drained battery
# 725 / 800
# title: What Will Make The Future Of Energy Terrorist-Proof?
# prediction: you’re not going to have single points of weakness on the system
# 726 / 800
# title: Wondering if you can get pregnant during a pregnancy? 🤔  Dr Karl has the answer for you. #science
# prediction: It's possible, but rare
# 727 / 800
# title: Tina Fey reveals one "SNL" cast member called her the C-word
# prediction: Colin Quinn
# 728 / 800
# title: How should publishers and news organizations utilize the text messaging medium?
# prediction: chatbots
# 729 / 800
# title: A Farmer Got More Than He Bargained For When He Dug Up This On Christmas Day
# prediction: mud
# 730 / 800
# title: Here's How Much You're Going To Spend On The Holidays This Year
# prediction: $1,175
# 731 / 800
# title: 10 Worthless Collectibles And the Reasons They Lost Their Value
# prediction: Lunch Boxes
# 732 / 800
# title: Oh?
# prediction: The evacuation of civilians and opposition fighters from eastern Aleppo
# 733 / 800
# title: This Rock Seems Out Of Place. When He Moves It? I Can't Believe It Leads To THIS
# prediction: farmer
# 734 / 800
# title: Channel 4 has revealed the latest celebrities to brave the most dangerous show on TV
# prediction: The Jump
# 735 / 800
# title: The Surprising Thing You Never Have To Do In Watch Dogs 2
# prediction: used a gun
# 736 / 800
# title: Gosselin: I can see Cowboys QB Tony Romo playing all 16 games if this happens
# prediction: Staubach
# 737 / 800
# title: Pikachu Just Got A New Name And People Are P****d!
# prediction: Pokemon Sun and Moon will be translated into Mandarin
# 738 / 800
# title: Plus-size "Top Model" winner lands MAJOR gig
# prediction: Whitney Thompson
# 739 / 800
# title: This is how humans are damaging #Earth!
# prediction: irreversible damage to the environment
# 740 / 800
# title: The Strange Reason Nearly Every Film Ends by Saying It’s Fiction
# prediction: purely coincidental."
# 741 / 800
# title: Why Are Cats So Insanely Afraid Of Cucumbers?
# prediction: It could represent the danger of a snake or another predator
# 742 / 800
# title: Want To Lose More Weight? Simply Replace Your Diet Soda With This After Meals
# prediction: water
# 743 / 800
# title: Is this @tomhanks best performance ever?
# prediction: at his very best
# 744 / 800
# title: WATCH: Moment A Panther Leaps At A Man With No Glass To Protect Him
# prediction: Mexican man
# 745 / 800
# title: This almost free item is one of the most important things you can keep in your car
# prediction: rags
# 746 / 800
# title: Chick-Fil-A just dropped a BOMB on Black Lives Matter...Police officers are pumped!
# prediction: Police officers are here to protect citizens
# 747 / 800
# title: 850 DNA matches after city clears rape kit backlog
# prediction: Houston
# 748 / 800
# title: Couple Waited 9 Years to Unwrap Wedding Gift That Read 'Do Not Open Until 1st Disagreement'
# prediction: Alison
# 749 / 800
# title: If You Have a Chip-Enabled Card, There's One Thing You Should Never Do
# prediction: just pay with cash
# 750 / 800
# title: Magazine responds to backlash against Melissa McCarthy cover
# prediction: Vogue UK
# 751 / 800
# title: Here's what happens if you never wash your jeans
# prediction: there is nothing to worry about from a health perspective
# 752 / 800
# title: Why some people think Trump snorted cocaine or Adderall before Monday’s presidential debate
# prediction: Trump wasn’t on coke
# 753 / 800
# title: Rubbing These Two Things on Your Teeth Will Make Them Whiter in Minutes
# prediction: coconut oil with a pinch of turmeric
# 754 / 800
# title: Why You Should Drink Milk Before A Road Trip
# prediction: It’s chock-full of nutrients and electrolytes like potassium
# 755 / 800
# title: This woman was rejected from a job interview with a savage emoji message
# prediction: Megan
# 756 / 800
# title: Look which formerly infamous Internet star is the new face of @AmericanApparel
# prediction: Chris Crocker
# 757 / 800
# title: Read this before you go out to shovel your driveway
# prediction: Talk to a doctor
# 758 / 800
# title: Her Daddy Died Before She Was Born. But Watch What They Capture On Camera...
# prediction: motorcycle gloves, next to a colorful, shiny motorcycle helmet
# 759 / 800
# title: You'll never believe what Selena Gomez orders at McDonalds
# prediction: A number 7 with medium fries and a Coke
# 760 / 800
# title: This state wants to legalize medical marijuana. Police agencies won't let it
# prediction: Minnesota
# 761 / 800
# title: Parents Who Bring Forgotten Lunch to School See Shocking Orders Posted on Door
# prediction: TURN AROUND and exit the building
# 762 / 800
# title: How to fix lag in SSB4 on 3DS
# prediction: Now that the game's out in our country
# 763 / 800
# title: Two Strangers Hug a Woman After Asking for Directions, but Watch What the Lady in Purple Does
# prediction: hugged her, and ended up stealing her jewelry
# 764 / 800
# title: The next #SNL Weekend Update anchor is...
# prediction: Cecily Strong
# 765 / 800
# title: 19 things you’ll only get if you’re low AND high maintenance
# prediction: 19
# 766 / 800
# title: State senators want to make it easier to legislate behind closed doors
# prediction: Barr
# 767 / 800
# title: The Real Reason Airplane Windows Don't Always Align With Your Seat
# prediction: airline greed
# 768 / 800
# title: Here's A New Clue About Where 'The Simpsons' Actually Takes Place
# prediction: Springfield, Oregon
# 769 / 800
# title: A Pregnant Dog Lays Lifelessly In A Field, But Seconds Later, I Gasped
# prediction: amazing dog
# 770 / 800
# title: Here’s Sony’s Response To Microsoft’s Invite to Connect Xbox One and PS4 Networks
# prediction: PlayStation 4
# 771 / 800
# title: The 'Batman v Superman' Easter Egg Almost Everybody Missed
# prediction: Batman was able to weaken Superman
# 772 / 800
# title: If You've Ever Shivered After Peeing, THIS Is What's Happening
# prediction: post-micturition convulsion syndrome
# 773 / 800
# title: NASA Warns Massive Asteroid Is Heading Towards Earth TODAY
# prediction: NASA has just confirmed that a gargantuan mile-long asteroid
# 774 / 800
# title: A woman who interviewed over 100 people at Goldman Sachs says there's one question she always hoped candidates would ask her, but they never did
# prediction: "Where do you see yourself in five years?"
# 775 / 800
# title: Boris Johnson's Brexit speech was uploaded to Pornhub with a new title
# prediction: "Dumb British blond fucks 15 million people at once."
# 776 / 800
# title: WATCH: Wrestling legend comes out of the closet at 73
# prediction: Patterson
# 777 / 800
# title: Hey, what's that thing *you* did to succeed?
# prediction: bullshitting
# 778 / 800
# title: Former "Community" star tweets importance of "Arsenio Hall Show"
# prediction: diversity
# 779 / 800
# title: 11 of the nation's 100 most dangerous cities are in this state
# prediction: Florida
# 780 / 800
# title: J.K. Rowling has revealed a heartbreaking truth about Hagrid
# prediction: Hagrid couldn't produce a Patronus
# 781 / 800
# title: Perhaps the most shocking result so far is in Missouri. #ElectionNight
# prediction: Democrat Jason Kander
# 782 / 800
# title: How long does sex normally last?
# prediction: 5.4 minutes
# 783 / 800
# title: People are very worried by this video of Donald Trump
# prediction: there's Rudy
# 784 / 800
# title: The antibodies that were invented to help immunologists find GOD
# prediction: how well they bound to their antigen
# 785 / 800
# title: 6 transcendental festivals out in the middle of nowhere
# prediction: portable toilet
# 786 / 800
# title: KFC’s secret ingredient is 'the most under-appreciated spice' in the world
# prediction: white pepper
# 787 / 800
# title: Sex experts think that more straight men are exploring a formerly taboo hot spot
# prediction: prostate and anal play
# 788 / 800
# title: Things in the Olsen twins' lives that make no sense
# prediction: their strange dating preferences, to some questionable business practices
# 789 / 800
# title: 13 Pokémon The Designers Just Gave Up On
# prediction: evolves into some coconut tree
# 790 / 800
# title: 9 things Elizabeth Taylor taught us about the art of love
# prediction: there are plenty of fish in the sea
# 791 / 800
# title: Both Campaigns Stunned After Houston Chronicle Makes VERY Surprising Endorsement
# prediction: That’s not Donald Trump
# 792 / 800
# title: One Guy Decided To Explore This Abandoned Building... And Instantly Regretted It.
# prediction: Dan Bell
# 793 / 800
# title: Here's a controversial idea about China's economy that no one wants to hear
# prediction: the transition to the service sector
# 794 / 800
# title: Dog Dies One Hour After Hiking With His Owner, Veterinarian Gives Shocking Reason Why
# prediction: chewed on some plants
# 795 / 800
# title: This is what happens when you leave a hotel cleaner a $500 tip
# prediction: refusing to accept the tip
# 796 / 800
# title: This Texas GOP elector announces that he won't vote for Trump
# prediction: Christopher Suprun
# 797 / 800
# title: This beauty queen cured her acne with one diet change
# prediction: Rachel Crawley
# 798 / 800
# title: WikiLeaks' Julian Assange Reported Dead
# prediction: dead
# 799 / 800
# title: Original "Law &amp; Order: SVU" cast member leaving the show
# prediction: Richard Belzer

# %%
import pickle
with open('roberta_predictions_test_data.dat', 'wb') as f:
    pickle.dump(spoilers_from_qa, f)

# %%
 # Example of fine-tuning BLOOM https://www.kaggle.com/code/julianschelb/finetune-bloom-token-classification

# %%
entry['spoiler'][0]
context.find('how about that morning we go throw?')
# Out:
# 772

# %%
context[772:807]
# Out:
# 'how about that morning we go throw?'

# %%
len(train)
# Out:
# 25600

# %%
import pandas as pd
df = pd.read_json('validation.jsonl', lines=True)

# %%
spoilers = df[["uuid","postId"]]
spoilers['spoiler'] = spoilers_from_qa

json_output = spoilers.to_json(orient='records', lines=True)

with open(f"roberta_test_predictions.jsonl", 'w') as f:
    f.write(json_output)
# Out:
# /tmp/ipykernel_3383/3779011217.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spoilers['spoiler'] = spoilers_from_qa

# %%
json_output
# Out:
# '{"uuid":"2f3e30d7-972c-4812-b727-6b582de52137","postId":"420585068076101633","spoiler":"chai tea soap"}\n{"uuid":"45425f74-4c0e-420c-aea8-6337ea91e107","postId":"4km87q","spoiler":"Gwyneth Paltrow"}\n{"uuid":"2fb84020-cfdb-4b7f-9cfc-b891c306c946","postId":"4s4f3b","spoiler":"rubbish"}\n{"uuid":"7cc8b816-a3fe-4b3f-9568-b353f87a3161","postId":"429398501613895680","spoiler":"JaVale McGee"}\n{"uuid":"b90a7343-ab27-4750-8e12-43f3f03fc9e5","postId":"828292353706176512","spoiler":"Alex Owens-Sarno"}\n{"uuid":"1b83a7b8-72fa-4b21-8dd3-a5cff484d791","postId":"832816169686069248","spoiler":"They just weren\\u2019t quite as intense"}\n{"uuid":"b63a63ce-38be-498d-8eca-f571d713e05c","postId":"4t7tae","spoiler":"insecurity"}\n{"uuid":"fd5ef1e7-63ce-499c-9fc3-00d5209ccef6","postId":"5195lx","spoiler":"crazy, but after you watch this video from Allrecipes"}\n{"uuid":"3802f457-cee5-4324-80a0-161cc387785b","postId":"812568310223175681","spoiler":""}\n{"uuid":"2be7bbfb-5c97-4b1e-925d-8d76fff2d9da","postId":"815698310644297729","spoiler":"12"}\n{"uuid":"92de48d8-4b48-40b9-a0dd-83c28fb3da58","postId":"4jjc12","spoiler":"The iPhone\'s got a crazy-long battery life"}\n{"uuid":"1de9243c-3882-42f1-84ef-21c3b4176f36","postId":"4ql312","spoiler":"dog walker"}\n{"uuid":"c11945bb-a85e-4859-a0e0-0234eb264a91","postId":"4oksvg","spoiler":"San Francisco"}\n{"uuid":"1c3dd966-ea40-405a-bf79-f5f2e168c316","postId":"1100188040002123_1128754710478789","spoiler":"lingered just a bit too long on the hot coals"}\n{"uuid":"86b42431-580a-4d72-9fea-a38d6f22df31","postId":"376464499949461504","spoiler":"iTunes Festival"}\n{"uuid":"1b9a73dc-7cad-40fc-b6b2-4d00f8a9acdd","postId":"4mddgc","spoiler":"need to be brought along to the future"}\n{"uuid":"7148ecbd-3f7c-4fd7-9823-f13313c0565a","postId":"817092913024958464","spoiler":"over the top"}\n{"uuid":"959e09d8-dfeb-418f-84b2-e275591c27eb","postId":"1100188040002123_1127323553955238","spoiler":"fish belong in the wild and not in tanks"}\n{"uuid":"da622918-67fe-4fa2-8c6b-2f333435a8f3","postId":"844109892399324_851643894979257","spoiler":"asthma inhaler"}\n{"uuid":"9655c81a-5274-45c9-9b74-392d67f3593d","postId":"390496891076501504","spoiler":"Duhon"}\n{"uuid":"68d52ec0-c6ee-4b7e-bf24-05f9d072e86a","postId":"51hk71","spoiler":"Olivia Key first visited her doctor with a painfully bloated belly"}\n{"uuid":"ee49c35c-b7b9-4620-963a-522bb5431dcc","postId":"170016066732231_171165349950636","spoiler":"trains"}\n{"uuid":"80d065e0-1fc2-48f4-86f5-62aed2362811","postId":"385791412941242368","spoiler":"Charlotte Ronson\'s amazing house is not only beautiful but, well, real"}\n{"uuid":"22e03c59-1b7d-43d2-94bb-909f467582bc","postId":"4o2wrr","spoiler":"Catholic vote"}\n{"uuid":"2a0614ba-89c4-49b0-b5e4-ae5d7b525d30","postId":"573573175935692800","spoiler":"Austin"}\n{"uuid":"0205df72-0760-4304-beb8-a16a4a7c4516","postId":"50bkpb","spoiler":"Chinese billionaire Cecil Chao is man who has it all."}\n{"uuid":"8376c5b3-f8fe-4a73-8aa5-357d3a9c94d8","postId":"806651624907227137","spoiler":"Dr Salam"}\n{"uuid":"99d3b936-f0b8-42b6-ab1d-c72d5924a076","postId":"4wqqlu","spoiler":"hardcore leveling curve"}\n{"uuid":"cb44150c-1d2b-4fea-93d2-7b9dd17dfd68","postId":"545691143774953472","spoiler":"Could you actually kill someone with farts"}\n{"uuid":"14495598-3373-451b-ace7-4fe67d843a2d","postId":"4womxg","spoiler":"dropped him"}\n{"uuid":"2b52037f-938c-4b6c-8caf-9688c1d8f9e0","postId":"50pcjp","spoiler":"a thinner design, better water-resistance"}\n{"uuid":"1683bceb-c41d-4872-8938-3f1f10d11911","postId":"812287348365004801","spoiler":"Beyonce"}\n{"uuid":"d5d050a3-9dcd-416d-9732-0e4543142ca8","postId":"4o1wha","spoiler":"pooped it into a strainer"}\n{"uuid":"2b9c532d-b04e-4ece-810f-b3d86da7391c","postId":"388364120904331264","spoiler":"We Are Men"}\n{"uuid":"07eff9a5-e3df-4511-a12d-c39bab519b93","postId":"844109892399324_847100628766917","spoiler":"Pharaoh\\u2019s Serpent\\u2019, for obvious reasons."}\n{"uuid":"64686ee3-eb4e-406e-a426-7a91821092bd","postI ...
